# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm
# ### Evaluation of all of the attacks (Fang, LIE, and our SOTA AGR-tailored and AGR-agnstic) on Bulyan

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp

sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *
from adam import Adam
from sgd import SGD

# %% [markdown]
# ## Get cifar10 data and split it in IID fashion

# %%
import torchvision.transforms as transforms
import torchvision.datasets as datasets
data_loc='/mnt/nfs/work1/amir/vshejwalkar/cifar10_data/'
# load the train dataset

train_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

cifar10_train = datasets.CIFAR10(root=data_loc, train=True, download=True, transform=train_transform)

cifar10_test = datasets.CIFAR10(root=data_loc, train=False, download=True, transform=train_transform)

X=[]
Y=[]
for i in range(len(cifar10_train)):
    X.append(cifar10_train[i][0].numpy())
    Y.append(cifar10_train[i][1])

for i in range(len(cifar10_test)):
    X.append(cifar10_test[i][0].numpy())
    Y.append(cifar10_test[i][1])

X=np.array(X)
Y=np.array(Y)

print('total data len: ',len(X))

if not os.path.isfile('./cifar10_shuffle.pkl'):
    all_indices = np.arange(len(X))
    np.random.shuffle(all_indices)
    pickle.dump(all_indices,open('./cifar10_shuffle.pkl','wb'))
else:
    all_indices=pickle.load(open('./cifar10_shuffle.pkl','rb'))

X=X[all_indices]
Y=Y[all_indices]
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Divide cifar10 data among 50 clients in IID fashion

# %%
# data loading

nusers=50
user_tr_len=1000

total_tr_len=user_tr_len*nusers
val_len=5000
te_len=5000

print('total data len: ',len(X))

if not os.path.isfile('./cifar10_shuffle.pkl'):
    all_indices = np.arange(len(X))
    np.random.shuffle(all_indices)
    pickle.dump(all_indices,open('./cifar10_shuffle.pkl','wb'))
else:
    all_indices=pickle.load(open('./cifar10_shuffle.pkl','rb'))

total_tr_data=X[:total_tr_len]
total_tr_label=Y[:total_tr_len]

val_data=X[total_tr_len:(total_tr_len+val_len)]
val_label=Y[total_tr_len:(total_tr_len+val_len)]

te_data=X[(total_tr_len+val_len):(total_tr_len+val_len+te_len)]
te_label=Y[(total_tr_len+val_len):(total_tr_len+val_len+te_len)]

total_tr_data_tensor=torch.from_numpy(total_tr_data).type(torch.FloatTensor)
total_tr_label_tensor=torch.from_numpy(total_tr_label).type(torch.LongTensor)

val_data_tensor=torch.from_numpy(val_data).type(torch.FloatTensor)
val_label_tensor=torch.from_numpy(val_label).type(torch.LongTensor)

te_data_tensor=torch.from_numpy(te_data).type(torch.FloatTensor)
te_label_tensor=torch.from_numpy(te_label).type(torch.LongTensor)

print('total tr len %d | val len %d | test len %d'%(len(total_tr_data_tensor),len(val_data_tensor),len(te_data_tensor)))

#==============================================================================================================

user_tr_data_tensors=[]
user_tr_label_tensors=[]

for i in range(nusers):
    
    user_tr_data_tensor=torch.from_numpy(total_tr_data[user_tr_len*i:user_tr_len*(i+1)]).type(torch.FloatTensor)
    user_tr_label_tensor=torch.from_numpy(total_tr_label[user_tr_len*i:user_tr_len*(i+1)]).type(torch.LongTensor)

    user_tr_data_tensors.append(user_tr_data_tensor)
    user_tr_label_tensors.append(user_tr_label_tensor)
    print('user %d tr len %d'%(i,len(user_tr_data_tensor)))
# Out:
# total data len:  60000
# total tr len 50000 | val len 5000 | test len 5000
# user 0 tr len 1000
# user 1 tr len 1000
# user 2 tr len 1000
# user 3 tr len 1000
# user 4 tr len 1000
# user 5 tr len 1000
# user 6 tr len 1000
# user 7 tr len 1000
# user 8 tr len 1000
# user 9 tr len 1000
# user 10 tr len 1000
# user 11 tr len 1000
# user 12 tr len 1000
# user 13 tr len 1000
# user 14 tr len 1000
# user 15 tr len 1000
# user 16 tr len 1000
# user 17 tr len 1000
# user 18 tr len 1000
# user 19 tr len 1000
# user 20 tr len 1000
# user 21 tr len 1000
# user 22 tr len 1000
# user 23 tr len 1000
# user 24 tr len 1000
# user 25 tr len 1000
# user 26 tr len 1000
# user 27 tr len 1000
# user 28 tr len 1000
# user 29 tr len 1000
# user 30 tr len 1000
# user 31 tr len 1000
# user 32 tr len 1000
# user 33 tr len 1000
# user 34 tr len 1000
# user 35 tr len 1000
# user 36 tr len 1000
# user 37 tr len 1000
# user 38 tr len 1000
# user 39 tr len 1000
# user 40 tr len 1000
# user 41 tr len 1000
# user 42 tr len 1000
# user 43 tr len 1000
# user 44 tr len 1000
# user 45 tr len 1000
# user 46 tr len 1000
# user 47 tr len 1000
# user 48 tr len 1000
# user 49 tr len 1000

# %% [markdown]
# ## Code for Bulyan aggregation algorithm

# %%
def bulyan(all_updates, n_attackers):
    nusers = all_updates.shape[0]
    bulyan_cluster = []
    candidate_indices = []
    remaining_updates = all_updates
    all_indices = np.arange(len(all_updates))

    while len(bulyan_cluster) < (nusers - 2 * n_attackers):
        torch.cuda.empty_cache()
        distances = []
        for update in remaining_updates:
            distance = []
            for update_ in remaining_updates:
                distance.append(torch.norm((update - update_)) ** 2)
            distance = torch.Tensor(distance).float()
            distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)
        # print(distances)

        distances = torch.sort(distances, dim=1)[0]

        scores = torch.sum(distances[:, :len(remaining_updates) - 2 - n_attackers], dim=1)
        indices = torch.argsort(scores)[:len(remaining_updates) - 2 - n_attackers]
        if not len(indices):
            break
        candidate_indices.append(all_indices[indices[0].cpu().numpy()])
        all_indices = np.delete(all_indices, indices[0].cpu().numpy())
        bulyan_cluster = remaining_updates[indices[0]][None, :] if not len(bulyan_cluster) else torch.cat((bulyan_cluster, remaining_updates[indices[0]][None, :]), 0)
        remaining_updates = torch.cat((remaining_updates[:indices[0]], remaining_updates[indices[0] + 1:]), 0)

    # print('dim of bulyan cluster ', bulyan_cluster.shape)

    n, d = bulyan_cluster.shape
    param_med = torch.median(bulyan_cluster, dim=0)[0]
    sort_idx = torch.argsort(torch.abs(bulyan_cluster - param_med), dim=0)
    sorted_params = bulyan_cluster[sort_idx, torch.arange(d)[None, :]]

    return torch.mean(sorted_params[:n - 2 * n_attackers], dim=0), np.array(candidate_indices)

# %% [markdown]
# ## Code for fang attack on Bulyan
# ### Note that Fang attacks on Multi-krum and Bulyan are the same

# %%
def compute_lambda_fang(all_updates, model_re, n_attackers):

    distances = []
    n_benign, d = all_updates.shape
    for update in all_updates:
        distance = torch.norm((all_updates - update), dim=1)
        distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)

    distances[distances == 0] = 10000
    distances = torch.sort(distances, dim=1)[0]
    scores = torch.sum(distances[:, :n_benign - 2 - n_attackers], dim=1)
    min_score = torch.min(scores)
    term_1 = min_score / ((n_benign - n_attackers - 1) * torch.sqrt(torch.Tensor([d]))[0])
    max_wre_dist = torch.max(torch.norm((all_updates - model_re), dim=1)) / (torch.sqrt(torch.Tensor([d]))[0])

    return (term_1 + max_wre_dist)


def get_malicious_updates_fang(all_updates, model_re, deviation, n_attackers):

    lamda = compute_lambda_fang(all_updates, model_re, n_attackers)
    threshold = 1e-5

    mal_updates = []
    while lamda > threshold:
        mal_update = (- lamda * deviation)

        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

        agg_grads, krum_candidate = multi_krum(mal_updates, n_attackers, multi_k=False)
        
        if krum_candidate < n_attackers:
            return mal_updates
        
        lamda *= 0.5

    if not len(mal_updates):
        print(lamda, threshold)
        mal_update = (model_re - lamda * deviation)
        
        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

    return mal_updates

# %% [markdown]
# ## Execute Fang attack on Bulyan

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='fang'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    fed_file='%s_checkpoint_%s_%d.pth.tar'%(arch, at_type, n_attacker)
    fed_best_file='%s_best_%s_%d.pth.tar'%(arch, at_type, n_attacker)
    
    if resume:
        fed_checkpoint = chkpt+'/'+fed_file
        assert os.path.isfile(fed_checkpoint), 'Error: no user checkpoint at %s'%(fed_checkpoint)
        checkpoint = torch.load(fed_checkpoint, map_location='cuda:%d'%torch.cuda.current_device())
        fed_model.load_state_dict(checkpoint['state_dict'])
        optimizer_fed.load_state_dict(checkpoint['optimizer'])
        resume = 0
        best_global_acc=checkpoint['best_acc']
        best_global_te_acc=checkpoint['best_te_acc']
        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        epoch_num += checkpoint['epoch']
        print('resuming from epoch %d | val acc %.4f | best acc %.3f | best te acc %.3f'%(epoch_num, val_acc, best_global_acc, best_global_te_acc))

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'paf':
                malicious_grads=get_malicious_predictions_poison_all_far_sign(malicious_grads,nusers,n_attacker)
            elif at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our':
                agg_grads = torch.mean(malicious_grads, 0)
                malicious_grads = our_attack_krum(malicious_grads, agg_grads, n_attacker, compression, q_level, norm)

        if not epoch_num:
            print(malicious_grads.shape)
            
        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':

            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0:
                print('multi krum is ', multi_k)

            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)


        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d val loss %.4f val acc %.4f best val_acc %f te_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc,best_global_te_acc))

        epoch_num+=1
# Out:
# torch.Size([50, 2472266])
# /home/vshejwalkar/fed-quant-robustness/code/cifar10/sgd.py:108: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729138878/work/torch/csrc/utils/python_arg_parser.cpp:882.)
#   p.data.add_(-group['lr'], d_p)
# bulyan: at fang n_at 10 n_mal_sel 10 e 0 val loss 2.3032 val acc 10.0041 best val_acc 10.004058 te_acc 9.760552
# bulyan: at fang n_at 10 n_mal_sel 10 e 1 val loss 2.3029 val acc 9.9635 best val_acc 10.004058 te_acc 9.760552
# bulyan: at fang n_at 10 n_mal_sel 10 e 2 val loss 2.3027 val acc 9.9635 best val_acc 10.004058 te_acc 9.760552
# bulyan: at fang n_at 10 n_mal_sel 9 e 3 val loss 2.3023 val acc 10.0041 best val_acc 10.004058 te_acc 9.760552
# bulyan: at fang n_at 10 n_mal_sel 10 e 4 val loss 2.3021 val acc 10.0244 best val_acc 10.024351 te_acc 9.882305
# bulyan: at fang n_at 10 n_mal_sel 10 e 5 val loss 2.3018 val acc 10.0041 best val_acc 10.024351 te_acc 9.882305
# bulyan: at fang n_at 10 n_mal_sel 10 e 6 val loss 2.3015 val acc 10.0446 best val_acc 10.044643 te_acc 9.902597
# bulyan: at fang n_at 10 n_mal_sel 9 e 7 val loss 2.3012 val acc 10.2273 best val_acc 10.227273 te_acc 10.004058
# bulyan: at fang n_at 10 n_mal_sel 10 e 8 val loss 2.3009 val acc 10.3084 best val_acc 10.308442 te_acc 10.064935
# bulyan: at fang n_at 10 n_mal_sel 10 e 9 val loss 2.3005 val acc 10.3693 best val_acc 10.369318 te_acc 10.186688
# bulyan: at fang n_at 10 n_mal_sel 10 e 10 val loss 2.3002 val acc 10.4708 best val_acc 10.470779 te_acc 10.450487
# bulyan: at fang n_at 10 n_mal_sel 9 e 11 val loss 2.2998 val acc 10.9375 best val_acc 10.937500 te_acc 10.856331
# bulyan: at fang n_at 10 n_mal_sel 10 e 12 val loss 2.2995 val acc 11.0998 best val_acc 11.099838 te_acc 11.018669
# bulyan: at fang n_at 10 n_mal_sel 10 e 13 val loss 2.2990 val acc 11.2825 best val_acc 11.282468 te_acc 11.201299
# bulyan: at fang n_at 10 n_mal_sel 10 e 14 val loss 2.2985 val acc 11.4245 best val_acc 11.424513 te_acc 11.262175
# bulyan: at fang n_at 10 n_mal_sel 8 e 15 val loss 2.2979 val acc 11.9927 best val_acc 11.992695 te_acc 11.627435
# bulyan: at fang n_at 10 n_mal_sel 10 e 16 val loss 2.2973 val acc 12.0739 best val_acc 12.073864 te_acc 11.749188
# bulyan: at fang n_at 10 n_mal_sel 9 e 17 val loss 2.2965 val acc 12.3580 best val_acc 12.357955 te_acc 11.931818
# bulyan: at fang n_at 10 n_mal_sel 9 e 18 val loss 2.2956 val acc 12.4188 best val_acc 12.418831 te_acc 11.911526
# bulyan: at fang n_at 10 n_mal_sel 10 e 19 val loss 2.2946 val acc 12.7232 best val_acc 12.723214 te_acc 12.236201
# bulyan: at fang n_at 10 n_mal_sel 9 e 20 val loss 2.2934 val acc 12.6623 best val_acc 12.723214 te_acc 12.236201
# bulyan: at fang n_at 10 n_mal_sel 8 e 21 val loss 2.2916 val acc 13.5552 best val_acc 13.555195 te_acc 13.108766
# bulyan: at fang n_at 10 n_mal_sel 9 e 22 val loss 2.2897 val acc 13.3523 best val_acc 13.555195 te_acc 13.108766
# bulyan: at fang n_at 10 n_mal_sel 9 e 23 val loss 2.2873 val acc 13.9813 best val_acc 13.981331 te_acc 13.879870
# bulyan: at fang n_at 10 n_mal_sel 9 e 24 val loss 2.2844 val acc 13.5755 best val_acc 13.981331 te_acc 13.879870
# bulyan: at fang n_at 10 n_mal_sel 8 e 25 val loss 2.2800 val acc 15.0974 best val_acc 15.097403 te_acc 14.630682
# bulyan: at fang n_at 10 n_mal_sel 8 e 26 val loss 2.2747 val acc 14.9351 best val_acc 15.097403 te_acc 14.630682
# bulyan: at fang n_at 10 n_mal_sel 8 e 27 val loss 2.2679 val acc 16.2135 best val_acc 16.213474 te_acc 16.477273
# bulyan: at fang n_at 10 n_mal_sel 9 e 28 val loss 2.2595 val acc 17.4513 best val_acc 17.451299 te_acc 16.659903
# bulyan: at fang n_at 10 n_mal_sel 8 e 29 val loss 2.2484 val acc 19.8255 best val_acc 19.825487 te_acc 19.724026
# bulyan: at fang n_at 10 n_mal_sel 9 e 30 val loss 2.2371 val acc 18.4050 best val_acc 19.825487 te_acc 19.724026
# bulyan: at fang n_at 10 n_mal_sel 9 e 31 val loss 2.2248 val acc 20.6169 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 9 e 32 val loss 2.2140 val acc 19.1964 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 8 e 33 val loss 2.2041 val acc 20.5560 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 7 e 34 val loss 2.3958 val acc 12.3782 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 3 e 35 val loss 2.3094 val acc 10.9375 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 7 e 36 val loss 2.2823 val acc 10.2881 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 8 e 37 val loss 2.2760 val acc 10.6534 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 9 e 38 val loss 2.2702 val acc 10.8360 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 9 e 39 val loss 2.2644 val acc 11.1201 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 40 val loss 2.2595 val acc 11.3028 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 9 e 41 val loss 2.2540 val acc 11.4854 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 42 val loss 2.2491 val acc 11.4448 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 43 val loss 2.2448 val acc 11.5666 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 44 val loss 2.2409 val acc 11.6680 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 45 val loss 2.2367 val acc 11.8709 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 46 val loss 2.2326 val acc 16.1526 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 47 val loss 2.2287 val acc 17.3701 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 48 val loss 2.2249 val acc 16.7817 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 49 val loss 2.2209 val acc 16.9846 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 50 val loss 2.2172 val acc 16.8222 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 51 val loss 2.2140 val acc 17.0049 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 52 val loss 2.2106 val acc 17.3093 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 53 val loss 2.2067 val acc 17.3498 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 54 val loss 2.2035 val acc 17.1672 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 55 val loss 2.2010 val acc 17.3295 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 56 val loss 2.1983 val acc 17.8571 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 57 val loss 2.1945 val acc 17.9789 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 58 val loss 2.1920 val acc 17.5933 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 59 val loss 2.1898 val acc 17.9992 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 60 val loss 2.1874 val acc 18.6688 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 61 val loss 2.1839 val acc 18.7094 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 62 val loss 2.1819 val acc 18.5674 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 63 val loss 2.1798 val acc 18.6282 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 64 val loss 2.1776 val acc 19.1964 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 65 val loss 2.1745 val acc 18.9935 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 66 val loss 2.1726 val acc 18.8515 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 67 val loss 2.1707 val acc 19.1558 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 68 val loss 2.1688 val acc 19.5008 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 69 val loss 2.1657 val acc 19.6023 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 70 val loss 2.1640 val acc 19.5211 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 71 val loss 2.1621 val acc 19.8458 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 72 val loss 2.1600 val acc 19.9472 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 73 val loss 2.1570 val acc 20.1502 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 74 val loss 2.1550 val acc 20.2516 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 75 val loss 2.1530 val acc 20.5763 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 76 val loss 2.1507 val acc 20.6169 best val_acc 20.616883 te_acc 20.921266
# bulyan: at fang n_at 10 n_mal_sel 10 e 77 val loss 2.1470 val acc 20.8198 best val_acc 20.819805 te_acc 19.602273
# bulyan: at fang n_at 10 n_mal_sel 10 e 78 val loss 2.1446 val acc 20.9213 best val_acc 20.921266 te_acc 19.521104
# bulyan: at fang n_at 10 n_mal_sel 10 e 79 val loss 2.1418 val acc 21.3880 best val_acc 21.387987 te_acc 19.987825
# bulyan: at fang n_at 10 n_mal_sel 10 e 80 val loss 2.1385 val acc 21.3068 best val_acc 21.387987 te_acc 19.987825
# bulyan: at fang n_at 10 n_mal_sel 10 e 81 val loss 2.1336 val acc 21.6721 best val_acc 21.672078 te_acc 20.454545
# bulyan: at fang n_at 10 n_mal_sel 10 e 82 val loss 2.1297 val acc 21.5503 best val_acc 21.672078 te_acc 20.454545
# bulyan: at fang n_at 10 n_mal_sel 10 e 83 val loss 2.1248 val acc 21.7127 best val_acc 21.712662 te_acc 20.190747
# bulyan: at fang n_at 10 n_mal_sel 10 e 84 val loss 2.1188 val acc 22.0982 best val_acc 22.098214 te_acc 20.495130
# bulyan: at fang n_at 10 n_mal_sel 10 e 85 val loss 2.1103 val acc 22.9099 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 86 val loss 2.1021 val acc 22.7881 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 87 val loss 2.0936 val acc 22.8084 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 88 val loss 2.0825 val acc 22.2403 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 89 val loss 2.0719 val acc 22.8287 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 90 val loss 2.0602 val acc 22.5041 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 91 val loss 2.0544 val acc 22.5649 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 92 val loss 2.0483 val acc 22.5446 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 93 val loss 2.0430 val acc 22.5041 best val_acc 22.909903 te_acc 20.982143
# bulyan: at fang n_at 10 n_mal_sel 10 e 94 val loss 2.0383 val acc 22.9505 best val_acc 22.950487 te_acc 21.956169
# bulyan: at fang n_at 10 n_mal_sel 10 e 95 val loss 2.0367 val acc 22.8693 best val_acc 22.950487 te_acc 21.956169
# bulyan: at fang n_at 10 n_mal_sel 10 e 96 val loss 2.0313 val acc 23.0519 best val_acc 23.051948 te_acc 22.118506
# bulyan: at fang n_at 10 n_mal_sel 10 e 97 val loss 2.0297 val acc 22.8693 best val_acc 23.051948 te_acc 22.118506
# bulyan: at fang n_at 10 n_mal_sel 10 e 98 val loss 2.0293 val acc 22.8490 best val_acc 23.051948 te_acc 22.118506
# bulyan: at fang n_at 10 n_mal_sel 10 e 99 val loss 2.0294 val acc 23.0722 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 100 val loss 2.0294 val acc 20.9821 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 101 val loss 2.1886 val acc 20.7386 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 5 e 102 val loss 2.7179 val acc 10.5317 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 2 e 103 val loss 2.3138 val acc 11.6477 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 7 e 104 val loss 2.3018 val acc 13.2711 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 7 e 105 val loss 2.2878 val acc 15.4221 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 7 e 106 val loss 2.2706 val acc 17.2890 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 8 e 107 val loss 2.2552 val acc 17.5122 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 8 e 108 val loss 2.2399 val acc 17.4919 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 9 e 109 val loss 2.2264 val acc 18.0601 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 8 e 110 val loss 2.2118 val acc 17.8571 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 111 val loss 2.2010 val acc 17.9586 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 9 e 112 val loss 2.1895 val acc 18.1209 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 113 val loss 2.1791 val acc 18.5674 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 114 val loss 2.1707 val acc 18.6080 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 115 val loss 2.1644 val acc 19.1761 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 9 e 116 val loss 2.1568 val acc 20.0081 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 117 val loss 2.1497 val acc 21.0633 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 118 val loss 2.1447 val acc 21.5097 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 119 val loss 2.1415 val acc 20.9416 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 120 val loss 2.1371 val acc 21.2662 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 121 val loss 2.1327 val acc 22.2808 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 122 val loss 2.1294 val acc 22.0576 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 123 val loss 2.1260 val acc 21.8750 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 124 val loss 2.1218 val acc 22.0982 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 125 val loss 2.1181 val acc 22.9302 best val_acc 23.072240 te_acc 22.869318
# bulyan: at fang n_at 10 n_mal_sel 10 e 126 val loss 2.1158 val acc 23.0925 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 127 val loss 2.1132 val acc 22.6461 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 128 val loss 2.1089 val acc 22.8084 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 129 val loss 2.1214 val acc 22.5446 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 130 val loss 2.2683 val acc 17.2078 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 3 e 131 val loss 2.3547 val acc 9.9026 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 132 val loss 2.3384 val acc 11.0390 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 133 val loss 2.3259 val acc 13.8190 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 6 e 134 val loss 2.3535 val acc 10.4099 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 4 e 135 val loss 2.3502 val acc 10.7143 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 136 val loss 2.3434 val acc 9.9229 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 137 val loss 2.3386 val acc 10.2881 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 138 val loss 2.3344 val acc 10.2881 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 139 val loss 2.3309 val acc 10.5519 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 140 val loss 2.3277 val acc 10.5722 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 141 val loss 2.3247 val acc 11.0795 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 142 val loss 2.3221 val acc 11.0187 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 143 val loss 2.3196 val acc 11.2216 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 144 val loss 2.3173 val acc 11.0795 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 145 val loss 2.3150 val acc 10.8563 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 146 val loss 2.3128 val acc 10.8360 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 147 val loss 2.3105 val acc 10.7549 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 148 val loss 2.3079 val acc 10.6128 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 149 val loss 2.3054 val acc 12.5203 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 150 val loss 2.3018 val acc 12.4188 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 151 val loss 2.2987 val acc 11.7492 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 152 val loss 2.2946 val acc 12.8044 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 153 val loss 2.2920 val acc 10.3490 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 154 val loss 2.2849 val acc 12.4391 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 155 val loss 2.2799 val acc 10.4505 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 156 val loss 2.2766 val acc 10.3896 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 6 e 157 val loss 2.2581 val acc 11.6477 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 158 val loss 2.2451 val acc 13.0073 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 159 val loss 2.2693 val acc 11.1810 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 5 e 160 val loss 2.3054 val acc 9.5373 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 5 e 161 val loss 2.2824 val acc 10.2881 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 6 e 162 val loss 2.2489 val acc 12.0942 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 163 val loss 2.2345 val acc 13.5146 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 164 val loss 2.2250 val acc 15.1786 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 165 val loss 2.2137 val acc 14.6104 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 166 val loss 2.2004 val acc 15.1786 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 167 val loss 2.1879 val acc 15.8685 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 168 val loss 2.1722 val acc 16.8831 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 169 val loss 2.1537 val acc 15.1177 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 170 val loss 2.1339 val acc 16.7817 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 171 val loss 2.1159 val acc 20.2719 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 172 val loss 2.1003 val acc 21.4692 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 173 val loss 2.0980 val acc 21.0633 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 6 e 174 val loss 3.0206 val acc 12.3580 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 2 e 175 val loss 2.8632 val acc 9.9432 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 3 e 176 val loss 2.3044 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 177 val loss 2.3044 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 178 val loss 2.3043 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 179 val loss 2.3043 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 180 val loss 2.3042 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 181 val loss 2.3042 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 182 val loss 2.3042 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 183 val loss 2.3041 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 184 val loss 2.3041 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 185 val loss 2.3040 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 186 val loss 2.3039 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 187 val loss 2.3038 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 188 val loss 2.3038 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 189 val loss 2.3037 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 190 val loss 2.3036 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 191 val loss 2.3035 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 192 val loss 2.3034 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 193 val loss 2.3032 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 194 val loss 2.3031 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 195 val loss 2.3029 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 196 val loss 2.3027 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 197 val loss 2.3024 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 198 val loss 2.3020 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 199 val loss 2.3016 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 200 val loss 2.3011 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 201 val loss 2.3003 val acc 9.5576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 202 val loss 2.2994 val acc 9.5170 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 203 val loss 2.2981 val acc 9.5982 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 204 val loss 2.2970 val acc 10.1867 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 205 val loss 2.2958 val acc 11.2622 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 206 val loss 2.2949 val acc 11.9521 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 207 val loss 2.2936 val acc 12.9058 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 208 val loss 2.2931 val acc 12.9870 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 209 val loss 2.2922 val acc 12.9058 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 210 val loss 2.2915 val acc 12.9464 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 211 val loss 2.2905 val acc 12.9870 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 212 val loss 2.2899 val acc 13.0073 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 213 val loss 2.2892 val acc 13.0682 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 214 val loss 2.2885 val acc 13.1088 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 215 val loss 2.2875 val acc 13.2914 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 216 val loss 2.2867 val acc 13.2305 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 217 val loss 2.2857 val acc 13.3523 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 218 val loss 2.2845 val acc 13.5146 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 219 val loss 2.2831 val acc 13.9205 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 220 val loss 2.2817 val acc 14.3060 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 221 val loss 2.2803 val acc 14.4278 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 222 val loss 2.2787 val acc 14.4683 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 223 val loss 2.2767 val acc 14.4278 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 224 val loss 2.2748 val acc 13.9610 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 225 val loss 2.2727 val acc 14.2451 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 226 val loss 2.2701 val acc 13.6972 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 227 val loss 2.2670 val acc 13.6567 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 228 val loss 2.2635 val acc 13.7784 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 229 val loss 2.2589 val acc 15.1583 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 230 val loss 2.2538 val acc 16.6396 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 231 val loss 2.2476 val acc 17.3498 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 232 val loss 2.2398 val acc 18.2630 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 233 val loss 2.2304 val acc 18.4253 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 234 val loss 2.2217 val acc 18.6485 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 235 val loss 2.2120 val acc 18.9123 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 236 val loss 2.2008 val acc 19.5008 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 237 val loss 2.1898 val acc 17.9586 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 238 val loss 2.1802 val acc 18.9732 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 239 val loss 2.1724 val acc 17.4716 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 240 val loss 2.1740 val acc 19.5414 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 241 val loss 2.3913 val acc 12.1753 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 3 e 242 val loss 2.2958 val acc 11.4245 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 243 val loss 2.2870 val acc 12.5609 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 244 val loss 2.2844 val acc 12.7435 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 245 val loss 2.2814 val acc 12.6218 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 246 val loss 2.2792 val acc 12.7029 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 247 val loss 2.2770 val acc 12.7029 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 248 val loss 2.2745 val acc 12.7435 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 249 val loss 2.2718 val acc 12.7841 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 250 val loss 2.2698 val acc 12.8653 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 251 val loss 2.2679 val acc 12.7638 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 252 val loss 2.2658 val acc 12.9261 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 253 val loss 2.2639 val acc 13.0073 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 254 val loss 2.2623 val acc 12.9464 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 255 val loss 2.2603 val acc 12.8247 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 256 val loss 2.2579 val acc 12.9870 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 257 val loss 2.2563 val acc 12.9667 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 258 val loss 2.2548 val acc 12.9261 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 259 val loss 2.2528 val acc 12.9464 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 260 val loss 2.2501 val acc 12.9464 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 261 val loss 2.2485 val acc 12.9667 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 262 val loss 2.2466 val acc 13.0276 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 263 val loss 2.2445 val acc 13.0682 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 264 val loss 2.2413 val acc 13.1696 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 265 val loss 2.2393 val acc 12.8450 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 266 val loss 2.2366 val acc 13.2305 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 267 val loss 2.2347 val acc 13.0073 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 268 val loss 2.2415 val acc 13.3929 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 5 e 269 val loss 2.9124 val acc 10.1055 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 2 e 270 val loss 2.3306 val acc 10.4505 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 271 val loss 2.3280 val acc 11.0998 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 272 val loss 2.3261 val acc 9.9229 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 273 val loss 2.3238 val acc 11.3231 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 274 val loss 2.3220 val acc 11.0187 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 275 val loss 2.3204 val acc 10.9375 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 276 val loss 2.3192 val acc 9.9635 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 277 val loss 2.3177 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 278 val loss 2.3165 val acc 11.6274 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 279 val loss 2.3155 val acc 11.7289 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 280 val loss 2.3148 val acc 11.7492 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 281 val loss 2.3138 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 282 val loss 2.3129 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 283 val loss 2.3123 val acc 10.3287 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 284 val loss 2.3118 val acc 10.4708 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 285 val loss 2.3108 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 286 val loss 2.3101 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 287 val loss 2.3094 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 288 val loss 2.3089 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 289 val loss 2.3079 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 290 val loss 2.3071 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 291 val loss 2.3062 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 292 val loss 2.3049 val acc 9.8011 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 293 val loss 2.3028 val acc 9.9229 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 294 val loss 2.3000 val acc 10.7752 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 295 val loss 2.2957 val acc 12.7232 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 296 val loss 2.2888 val acc 14.7727 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 6 e 297 val loss 2.2774 val acc 16.4773 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 6 e 298 val loss 2.2612 val acc 15.6250 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 7 e 299 val loss 2.2431 val acc 15.7468 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 8 e 300 val loss 2.2293 val acc 17.4107 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 301 val loss 2.2218 val acc 17.1266 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 302 val loss 2.2165 val acc 18.1412 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 303 val loss 2.2109 val acc 17.5731 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 304 val loss 2.2068 val acc 16.9237 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 305 val loss 2.2032 val acc 17.4919 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 306 val loss 2.2002 val acc 17.1672 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 307 val loss 2.1972 val acc 17.3701 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 308 val loss 2.1943 val acc 17.8571 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 309 val loss 2.1914 val acc 17.8774 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 310 val loss 2.1891 val acc 18.1818 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 311 val loss 2.1866 val acc 18.3239 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 312 val loss 2.1839 val acc 18.3036 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 313 val loss 2.1813 val acc 18.5268 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 314 val loss 2.1792 val acc 18.5674 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 315 val loss 2.1770 val acc 19.1761 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 316 val loss 2.1743 val acc 18.9732 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 317 val loss 2.1715 val acc 19.2573 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 318 val loss 2.1695 val acc 19.3588 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 319 val loss 2.1671 val acc 19.8255 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 320 val loss 2.1638 val acc 19.5820 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 321 val loss 2.1602 val acc 19.9472 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 322 val loss 2.1569 val acc 20.1502 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 323 val loss 2.1532 val acc 21.7938 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 324 val loss 2.1470 val acc 20.4748 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 325 val loss 2.1396 val acc 20.5763 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 326 val loss 2.1320 val acc 20.6981 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 327 val loss 2.1243 val acc 21.9765 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 328 val loss 2.1282 val acc 20.9010 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 6 e 329 val loss 2.6666 val acc 9.7808 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 2 e 330 val loss 2.1928 val acc 18.0195 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 331 val loss 2.1823 val acc 18.3036 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 332 val loss 2.1793 val acc 18.3847 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 333 val loss 2.1763 val acc 18.5268 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 334 val loss 2.1746 val acc 18.6282 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 335 val loss 2.1734 val acc 18.2833 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 336 val loss 2.1710 val acc 18.2224 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 337 val loss 2.1690 val acc 18.3239 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 338 val loss 2.1676 val acc 18.4659 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 339 val loss 2.1670 val acc 18.2630 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 340 val loss 2.1647 val acc 18.2630 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 341 val loss 2.1630 val acc 18.1209 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 342 val loss 2.1618 val acc 18.2021 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 343 val loss 2.1616 val acc 18.2224 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 344 val loss 2.1594 val acc 18.0804 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 345 val loss 2.1581 val acc 18.1818 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 346 val loss 2.1571 val acc 18.2630 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 347 val loss 2.1571 val acc 18.0601 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 348 val loss 2.1553 val acc 18.0601 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 349 val loss 2.1542 val acc 18.1006 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 350 val loss 2.1528 val acc 18.0195 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 351 val loss 2.1529 val acc 18.3036 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 9 e 352 val loss 2.1500 val acc 18.1615 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 353 val loss 2.1485 val acc 18.3239 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 354 val loss 2.1478 val acc 18.4050 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 355 val loss 2.1479 val acc 18.4253 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 356 val loss 2.1448 val acc 18.5674 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 357 val loss 2.1431 val acc 18.5268 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 358 val loss 2.1428 val acc 18.7500 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 359 val loss 2.1429 val acc 19.0138 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 360 val loss 2.1393 val acc 18.9123 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 361 val loss 2.1382 val acc 19.0544 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 362 val loss 2.1379 val acc 19.3182 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 363 val loss 2.1382 val acc 20.1299 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 364 val loss 2.1345 val acc 19.6023 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 365 val loss 2.1334 val acc 19.9675 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 366 val loss 2.1332 val acc 20.4343 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 367 val loss 2.1336 val acc 21.2662 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 368 val loss 2.1295 val acc 19.9878 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 369 val loss 2.1285 val acc 20.5154 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 370 val loss 2.1281 val acc 21.1445 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 371 val loss 2.1279 val acc 21.4083 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 372 val loss 2.1253 val acc 21.0633 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 373 val loss 2.1235 val acc 20.8604 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 374 val loss 2.1240 val acc 21.2865 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 375 val loss 2.1237 val acc 22.1591 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 376 val loss 2.1206 val acc 21.1851 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 377 val loss 2.1186 val acc 21.3474 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 378 val loss 2.1192 val acc 21.6315 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 379 val loss 2.1188 val acc 22.3417 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 380 val loss 2.1164 val acc 22.1388 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 381 val loss 2.1143 val acc 21.8953 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 382 val loss 2.1141 val acc 22.0576 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 383 val loss 2.1145 val acc 22.6055 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 384 val loss 2.1117 val acc 22.5852 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 385 val loss 2.1109 val acc 21.9359 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 386 val loss 2.1085 val acc 22.2606 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 387 val loss 2.1089 val acc 22.0779 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 388 val loss 2.1068 val acc 22.2403 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 389 val loss 2.1058 val acc 22.3620 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 396 val loss 2.0965 val acc 22.8287 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 397 val loss 2.0959 val acc 23.0519 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 398 val loss 2.0933 val acc 22.9302 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 399 val loss 2.0956 val acc 22.9302 best val_acc 23.092532 te_acc 21.976461
# bulyan: at fang n_at 10 n_mal_sel 10 e 400 val loss 2.0912 val acc 23.1940 best val_acc 23.193994 te_acc 22.422890
# bulyan: at fang n_at 10 n_mal_sel 10 e 401 val loss 2.0882 val acc 23.4172 best val_acc 23.417208 te_acc 22.808442
# bulyan: at fang n_at 10 n_mal_sel 10 e 402 val loss 2.0874 val acc 23.5998 best val_acc 23.599838 te_acc 22.646104
# bulyan: at fang n_at 10 n_mal_sel 10 e 403 val loss 2.0890 val acc 23.1128 best val_acc 23.599838 te_acc 22.646104
# bulyan: at fang n_at 10 n_mal_sel 10 e 404 val loss 2.0854 val acc 23.5187 best val_acc 23.599838 te_acc 22.646104
# bulyan: at fang n_at 10 n_mal_sel 9 e 405 val loss 2.0829 val acc 23.7216 best val_acc 23.721591 te_acc 23.092532
# bulyan: at fang n_at 10 n_mal_sel 10 e 406 val loss 2.0815 val acc 23.8839 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 10 e 407 val loss 2.0832 val acc 23.3766 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 10 e 408 val loss 2.0805 val acc 23.8636 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 10 e 409 val loss 2.0902 val acc 21.7330 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 9 e 410 val loss 2.1909 val acc 21.2459 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 5 e 411 val loss 2.4251 val acc 10.2476 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 5 e 412 val loss 2.3854 val acc 12.6420 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 7 e 413 val loss 2.3580 val acc 13.1899 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 7 e 414 val loss 2.3311 val acc 15.5235 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 7 e 415 val loss 2.3007 val acc 16.2744 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 7 e 416 val loss 2.2752 val acc 17.2687 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 8 e 417 val loss 2.2526 val acc 16.6802 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 5 e 418 val loss 2.2862 val acc 13.4537 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 3 e 419 val loss 2.3949 val acc 9.9026 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 3 e 420 val loss 2.3595 val acc 9.9229 best val_acc 23.883929 te_acc 22.909903
# bulyan: at fang n_at 10 n_mal_sel 3 e 421 val loss 2.2984 val acc 10.7549 best val_acc 23.883929 te_acc 22.909903
# ...
# bulyan: at fang n_at 10 n_mal_sel 10 e 928 val loss 1.9951 val acc 21.9156 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 929 val loss 1.9943 val acc 21.9968 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 930 val loss 1.9930 val acc 22.1997 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 931 val loss 1.9930 val acc 22.3214 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 932 val loss 1.9896 val acc 21.8953 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 933 val loss 1.9871 val acc 21.9156 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 934 val loss 1.9871 val acc 22.0373 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 935 val loss 1.9871 val acc 22.1997 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 936 val loss 1.9848 val acc 22.2808 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 937 val loss 1.9849 val acc 21.9562 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 938 val loss 1.9839 val acc 22.1591 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 939 val loss 1.9838 val acc 22.1997 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 940 val loss 1.9815 val acc 22.3214 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 941 val loss 1.9818 val acc 21.8344 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 942 val loss 1.9801 val acc 21.9765 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 943 val loss 1.9805 val acc 22.1591 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 944 val loss 1.9788 val acc 22.0170 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 945 val loss 1.9798 val acc 22.0373 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 946 val loss 1.9773 val acc 22.2200 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 947 val loss 1.9779 val acc 22.4026 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 948 val loss 1.9762 val acc 22.3620 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 949 val loss 1.9764 val acc 22.3620 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 950 val loss 1.9743 val acc 22.4229 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 951 val loss 1.9749 val acc 22.7273 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 952 val loss 1.9730 val acc 22.5852 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 953 val loss 1.9736 val acc 22.5446 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 954 val loss 1.9711 val acc 22.4026 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 955 val loss 1.9732 val acc 22.8693 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 9 e 956 val loss 1.9778 val acc 22.0170 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 957 val loss 2.1026 val acc 21.4083 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 5 e 958 val loss 3.7527 val acc 9.7808 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 2 e 959 val loss 2.3744 val acc 9.7200 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 4 e 960 val loss 2.2619 val acc 14.9959 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 5 e 961 val loss 2.2022 val acc 15.3612 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 6 e 962 val loss 2.1633 val acc 18.2630 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 8 e 963 val loss 2.1470 val acc 18.5471 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 964 val loss 2.1361 val acc 18.6688 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 965 val loss 2.1293 val acc 19.0138 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 966 val loss 2.1248 val acc 19.0544 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 967 val loss 2.1214 val acc 19.2167 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 968 val loss 2.1167 val acc 19.6834 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 969 val loss 2.1129 val acc 19.8864 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 970 val loss 2.1103 val acc 20.1705 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 971 val loss 2.1085 val acc 20.2110 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 972 val loss 2.1050 val acc 20.5763 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 973 val loss 2.1024 val acc 20.6981 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 974 val loss 2.1005 val acc 20.7386 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 975 val loss 2.0986 val acc 20.7589 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 976 val loss 2.0963 val acc 20.5560 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 977 val loss 2.0946 val acc 20.5763 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 978 val loss 2.0922 val acc 21.0633 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 979 val loss 2.0903 val acc 20.9619 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 980 val loss 2.0874 val acc 21.2054 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 981 val loss 2.0850 val acc 21.3677 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 982 val loss 2.0809 val acc 21.1445 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 983 val loss 2.0791 val acc 21.4894 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 984 val loss 2.0778 val acc 21.3271 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 985 val loss 2.0774 val acc 21.5097 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 986 val loss 2.0746 val acc 21.5909 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 987 val loss 2.0740 val acc 21.8953 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 988 val loss 2.0744 val acc 22.1388 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 989 val loss 2.0723 val acc 22.4838 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 990 val loss 2.0719 val acc 22.4432 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 9 e 991 val loss 2.0817 val acc 21.7938 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 992 val loss 2.1570 val acc 19.1964 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 5 e 993 val loss 2.2805 val acc 13.0885 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 5 e 994 val loss 2.2093 val acc 15.6047 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 6 e 995 val loss 2.1516 val acc 16.7614 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 7 e 996 val loss 2.1034 val acc 19.5008 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 997 val loss 2.0826 val acc 21.1242 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 998 val loss 2.0699 val acc 22.0373 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 999 val loss 2.0645 val acc 22.4026 best val_acc 25.182630 te_acc 24.715909
# New learnin rate  0.25
# bulyan: at fang n_at 10 n_mal_sel 10 e 1000 val loss 2.0622 val acc 22.7679 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1001 val loss 2.0612 val acc 22.7679 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1002 val loss 2.0599 val acc 22.6258 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1003 val loss 2.0591 val acc 22.7273 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1004 val loss 2.0581 val acc 22.9505 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1005 val loss 2.0574 val acc 22.9708 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1006 val loss 2.0558 val acc 23.1940 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1007 val loss 2.0545 val acc 22.9099 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1008 val loss 2.0538 val acc 23.0722 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1009 val loss 2.0532 val acc 23.1128 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1010 val loss 2.0515 val acc 22.9099 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1011 val loss 2.0502 val acc 22.9708 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1012 val loss 2.0498 val acc 23.0925 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1013 val loss 2.0494 val acc 23.0114 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1014 val loss 2.0478 val acc 23.0519 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1015 val loss 2.0466 val acc 22.8084 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1016 val loss 2.0463 val acc 22.9099 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1017 val loss 2.0460 val acc 23.2346 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1018 val loss 2.0448 val acc 23.2752 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1019 val loss 2.0439 val acc 22.9911 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1020 val loss 2.0442 val acc 23.0519 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1021 val loss 2.0436 val acc 23.0519 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1022 val loss 2.0432 val acc 22.8693 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1023 val loss 2.0426 val acc 22.8693 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1024 val loss 2.0434 val acc 23.0317 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1025 val loss 2.0424 val acc 23.1128 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1026 val loss 2.0418 val acc 22.9505 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1027 val loss 2.0413 val acc 22.8693 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1028 val loss 2.0423 val acc 22.9911 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1029 val loss 2.0418 val acc 22.7476 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1030 val loss 2.0419 val acc 22.7070 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1031 val loss 2.0413 val acc 22.7881 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1032 val loss 2.0404 val acc 22.7476 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1033 val loss 2.0391 val acc 22.7070 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1034 val loss 2.0394 val acc 22.5649 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1035 val loss 2.0384 val acc 22.7476 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1036 val loss 2.0386 val acc 22.6461 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1037 val loss 2.0359 val acc 22.9302 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1038 val loss 2.0356 val acc 22.9708 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1039 val loss 2.0355 val acc 22.7679 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1040 val loss 2.0370 val acc 22.6664 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1041 val loss 2.0343 val acc 22.7679 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1042 val loss 2.0344 val acc 22.6664 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1043 val loss 2.0333 val acc 22.6055 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1044 val loss 2.0342 val acc 22.6664 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1045 val loss 2.0319 val acc 22.9911 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1046 val loss 2.0315 val acc 22.8896 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1047 val loss 2.0302 val acc 22.7476 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1048 val loss 2.0324 val acc 22.6664 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1049 val loss 2.0296 val acc 22.5244 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1050 val loss 2.0302 val acc 22.6461 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1051 val loss 2.0269 val acc 22.8490 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1052 val loss 2.0285 val acc 22.6055 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1053 val loss 2.0258 val acc 22.9099 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1054 val loss 2.0247 val acc 22.8896 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1055 val loss 2.0249 val acc 22.8084 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1056 val loss 2.0245 val acc 22.8287 best val_acc 25.182630 te_acc 24.715909
# bulyan: at fang n_at 10 n_mal_sel 10 e 1057 val loss 2.0239 val acc 22.7881 best val_acc 25.182630 te_acc 24.715909
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-7f3258e2e5ff> in <module>
#     114
#     115         elif aggregation=='bulyan':
# --> 116             agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)
#     117
#     118
#
# ~/fed-quant-robustness/code/cifar10/gradient_aggregation_rules.py in bulyan(all_updates, n_attackers)
#      81     param_med = torch.median(bulyan_cluster, dim=0)[0]
#      82     sort_idx = torch.argsort(torch.abs(bulyan_cluster - param_med), dim=0)
# ---> 83     sorted_params = bulyan_cluster[sort_idx, torch.arange(d)[None, :]]
#      84
#      85     return torch.mean(sorted_params[:n - 2 * n_attackers], dim=0), np.array(candidate_indices)
#
# RuntimeError: CUDA out of memory. Tried to allocate 566.00 MiB (GPU 0; 10.92 GiB total capacity; 2.14 GiB already allocated; 290.38 MiB free; 2.70 GiB reserved in total by PyTorch)

# %% [markdown]
# ## Code for LIE attack, followed by its execution on Bulyan

# %%
def lie_attack(all_updates, z):
    avg = torch.mean(all_updates, dim=0)
    std = torch.std(all_updates, dim=0)
    return avg + z * std

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='LIE'
z_values={3:0.69847, 5:0.7054, 8:0.71904, 10:0.72575, 12:0.73891}
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                mal_update = lie_attack(malicious_grads, z_values[n_attacker])
                malicious_grads = torch.cat((torch.stack([mal_update]*n_attacker), malicious_grads))
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang_trmean(malicious_grads, deviation, n_attacker, epoch_num)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                malicious_grads = our_attack_krum(malicious_grads, agg_grads, n_attacker, compression=compression, q_level=q_level, norm=norm)

        if not epoch_num : 
            print(malicious_grads.shape)

        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='trmean':
            agg_grads=tr_mean(malicious_grads, n_attacker)

        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%10==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d fed_model val loss %.4f val acc %.4f best val_acc %f te_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc,best_global_te_acc))

        if val_loss > 10:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# torch.Size([40, 2472266])
# /home/vshejwalkar/fed-quant-robustness/code/cifar10/sgd.py:108: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729138878/work/torch/csrc/utils/python_arg_parser.cpp:882.)
#   p.data.add_(-group['lr'], d_p)
# bulyan: at LIE n_at 10 n_mal_sel 5 e 0 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 10 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 20 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 30 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 40 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 50 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 60 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 70 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 80 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 90 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 100 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 110 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 120 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 130 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 140 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 150 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 160 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 170 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 180 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 190 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 200 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 210 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 220 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 230 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 240 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 250 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 260 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 270 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 280 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 290 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 300 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 310 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 320 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 330 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 340 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 350 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 360 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 370 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 380 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 390 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 400 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 410 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 420 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 430 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 440 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 450 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 460 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 470 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 480 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 490 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 500 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 510 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 520 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 530 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 540 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 550 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 560 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 570 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 580 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 590 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 600 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 610 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 620 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 630 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 640 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 650 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 660 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 670 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 680 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 690 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 700 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 710 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 720 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 730 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 740 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 750 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 760 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 770 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 780 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 790 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 800 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 810 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 820 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 830 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 840 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 850 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 860 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 870 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 880 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 890 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 900 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 910 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 920 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 930 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 940 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 950 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 960 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 970 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 980 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 990 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# New learnin rate  0.25
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1000 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1010 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1020 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1030 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1040 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1050 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1060 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1070 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1080 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1090 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1100 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1110 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1120 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1130 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1140 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1150 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1160 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1170 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1180 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1190 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1199 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091
# bulyan: at LIE n_at 10 n_mal_sel 0 e 1200 fed_model val loss nan val acc 9.6388 best val_acc 9.638799 te_acc 9.659091

# %% [markdown]
# ## Code for our AGR-tailored attack on Bulyan
# * Note that our attacks on multi-krum and Bulyan aggregations are the same

# %%
def our_attack_mkrum(all_updates, model_re, n_attackers, dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)

    lamda = torch.Tensor([3.0]).cuda()

    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

        agg_grads, krum_candidate = multi_krum(mal_updates, n_attackers, multi_k=True)
        if np.sum(krum_candidate < n_attackers) == n_attackers:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    mal_update = (model_re - lamda_succ * deviation)
    mal_updates = torch.stack([mal_update] * n_attackers)
    mal_updates = torch.cat((mal_updates, all_updates), 0)

    return mal_updates

# %% [markdown]
# ## Execute our AGR-tailored attack on Bulyan

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                malicious_grads = our_attack_mkrum(malicious_grads, agg_grads, n_attacker, dev_type=dev_type)

        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':

            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break
            
        epoch_num+=1
# Out:
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 0 | val loss 2.3018 val acc 10.0446 best val_acc 10.044643
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1 | val loss 2.3010 val acc 10.0446 best val_acc 10.044643
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 2 | val loss 2.3001 val acc 10.0446 best val_acc 10.044643
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 3 | val loss 2.2990 val acc 10.0446 best val_acc 10.044643
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 4 | val loss 2.2975 val acc 10.0446 best val_acc 10.044643
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 5 | val loss 2.2956 val acc 10.0446 best val_acc 10.044643
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 6 | val loss 2.2930 val acc 12.0333 best val_acc 12.033279
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 7 | val loss 2.2894 val acc 13.0682 best val_acc 13.068182
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 8 | val loss 2.2845 val acc 13.2711 best val_acc 13.271104
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 9 | val loss 2.2779 val acc 13.7378 best val_acc 13.737825
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 10 | val loss 2.2712 val acc 9.8214 best val_acc 13.737825
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 11 | val loss 2.2610 val acc 10.7752 best val_acc 13.737825
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 12 | val loss 2.2453 val acc 16.3149 best val_acc 16.314935
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 13 | val loss 2.2454 val acc 13.1899 best val_acc 16.314935
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 14 | val loss 2.2402 val acc 19.4602 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 15 | val loss 2.5809 val acc 11.2216 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 16 | val loss 2.3239 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 17 | val loss 2.3151 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 18 | val loss 2.3103 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 19 | val loss 2.3072 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 20 | val loss 2.3047 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 21 | val loss 2.3022 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 22 | val loss 2.2994 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 23 | val loss 2.2965 val acc 9.3141 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 24 | val loss 2.2934 val acc 9.0909 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 25 | val loss 2.2896 val acc 9.1518 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 26 | val loss 2.2847 val acc 8.7054 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 27 | val loss 2.2795 val acc 9.0097 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 28 | val loss 2.2732 val acc 8.5633 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 29 | val loss 2.2660 val acc 8.4821 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 30 | val loss 2.2571 val acc 9.9229 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 31 | val loss 2.2480 val acc 10.0852 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 32 | val loss 2.2384 val acc 10.6737 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 33 | val loss 2.2293 val acc 12.0130 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 34 | val loss 2.2196 val acc 15.3206 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 35 | val loss 2.2121 val acc 16.4570 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 36 | val loss 2.2120 val acc 15.9700 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 37 | val loss 2.2271 val acc 15.8685 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 38 | val loss 2.3187 val acc 13.7175 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 39 | val loss 2.3142 val acc 9.5982 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 40 | val loss 2.3113 val acc 9.3344 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 41 | val loss 2.3096 val acc 9.8823 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 42 | val loss 2.3077 val acc 9.0097 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 43 | val loss 2.3064 val acc 9.2532 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 44 | val loss 2.3049 val acc 9.9229 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 45 | val loss 2.3041 val acc 9.2532 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 46 | val loss 2.3018 val acc 10.6331 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 47 | val loss 2.3010 val acc 11.3433 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 48 | val loss 2.2982 val acc 11.7289 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 49 | val loss 2.2972 val acc 11.0390 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 50 | val loss 2.2941 val acc 12.7435 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 51 | val loss 2.2953 val acc 11.2622 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 52 | val loss 2.2861 val acc 11.0187 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 53 | val loss 2.2872 val acc 11.3433 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 54 | val loss 2.2834 val acc 13.1088 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 55 | val loss 2.2815 val acc 10.5722 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 56 | val loss 2.2652 val acc 14.6104 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 57 | val loss 2.2661 val acc 11.8506 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 58 | val loss 2.2638 val acc 13.2102 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 59 | val loss 2.2175 val acc 15.8685 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 60 | val loss 2.1760 val acc 19.3791 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 61 | val loss 2.2402 val acc 15.6047 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 62 | val loss 2.8450 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 63 | val loss 2.3232 val acc 9.6591 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 64 | val loss 2.3105 val acc 9.7403 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 65 | val loss 2.3012 val acc 9.7403 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 66 | val loss 2.2893 val acc 9.7606 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 67 | val loss 2.2757 val acc 9.7606 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 68 | val loss 2.2534 val acc 9.7808 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 69 | val loss 2.2421 val acc 9.9635 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 70 | val loss 2.2133 val acc 13.6769 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 71 | val loss 2.2397 val acc 14.6307 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 72 | val loss 2.2791 val acc 13.0885 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 73 | val loss 2.2314 val acc 16.7005 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 74 | val loss 2.3336 val acc 15.0365 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 75 | val loss 2.4479 val acc 11.8101 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 76 | val loss 2.3097 val acc 10.5519 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 77 | val loss 2.3086 val acc 10.4302 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 78 | val loss 2.3071 val acc 10.4708 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 79 | val loss 2.3060 val acc 10.2273 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 80 | val loss 2.3051 val acc 10.1664 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 81 | val loss 2.3044 val acc 10.3490 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 82 | val loss 2.3029 val acc 11.0795 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 83 | val loss 2.3018 val acc 12.5203 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 84 | val loss 2.3009 val acc 12.5406 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 85 | val loss 2.3006 val acc 12.6420 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 86 | val loss 2.2972 val acc 12.8653 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 87 | val loss 2.2953 val acc 13.5349 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 88 | val loss 2.2923 val acc 13.5552 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 89 | val loss 2.2918 val acc 13.0885 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 90 | val loss 2.2851 val acc 16.1932 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 91 | val loss 2.2874 val acc 11.7695 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 92 | val loss 2.2766 val acc 17.3498 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 93 | val loss 2.2922 val acc 11.6883 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 94 | val loss 2.2975 val acc 12.9261 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 95 | val loss 2.2808 val acc 13.9407 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 96 | val loss 2.2585 val acc 11.7898 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 97 | val loss 2.2523 val acc 11.5260 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 98 | val loss 2.2458 val acc 14.9351 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 99 | val loss 2.4144 val acc 11.1607 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 100 | val loss 2.3203 val acc 10.5519 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 101 | val loss 2.3159 val acc 10.8157 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 102 | val loss 2.3112 val acc 11.2216 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 103 | val loss 2.3070 val acc 12.2565 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 104 | val loss 2.3035 val acc 11.8304 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 105 | val loss 2.3012 val acc 11.8912 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 106 | val loss 2.2963 val acc 11.1201 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 107 | val loss 2.2955 val acc 11.3231 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 108 | val loss 2.2861 val acc 12.2768 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 109 | val loss 2.2855 val acc 12.0130 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 110 | val loss 2.2859 val acc 12.1347 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 111 | val loss 2.2908 val acc 12.6623 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 112 | val loss 2.2929 val acc 13.1088 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 113 | val loss 2.2717 val acc 14.0828 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 114 | val loss 2.2800 val acc 13.3929 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 115 | val loss 2.2942 val acc 11.9115 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 116 | val loss 2.2555 val acc 13.7987 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 117 | val loss 2.2460 val acc 14.6307 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 118 | val loss 2.2448 val acc 15.0568 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 119 | val loss 2.5938 val acc 14.1437 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 120 | val loss 2.3633 val acc 10.0649 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 121 | val loss 2.3475 val acc 9.9229 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 122 | val loss 2.3388 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 123 | val loss 2.3328 val acc 9.9432 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 124 | val loss 2.3282 val acc 9.9635 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 125 | val loss 2.3242 val acc 10.1461 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 126 | val loss 2.3203 val acc 10.2070 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 127 | val loss 2.3170 val acc 10.5925 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 128 | val loss 2.3143 val acc 10.6331 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 129 | val loss 2.3119 val acc 11.3028 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 130 | val loss 2.3089 val acc 11.5869 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 131 | val loss 2.3064 val acc 12.1347 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 132 | val loss 2.3038 val acc 12.2565 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 133 | val loss 2.3018 val acc 12.6420 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 134 | val loss 2.2984 val acc 12.5406 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 135 | val loss 2.2961 val acc 13.2305 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 136 | val loss 2.2919 val acc 13.4537 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 137 | val loss 2.2901 val acc 14.5292 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 138 | val loss 2.2855 val acc 14.8539 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 139 | val loss 2.2831 val acc 15.2800 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 140 | val loss 2.2764 val acc 15.0365 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 141 | val loss 2.2792 val acc 16.7817 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 142 | val loss 2.2671 val acc 14.8336 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 143 | val loss 2.2893 val acc 15.0568 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 144 | val loss 2.2975 val acc 10.4708 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 145 | val loss 2.2722 val acc 16.3961 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 146 | val loss 2.2654 val acc 17.8166 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 147 | val loss 2.2511 val acc 18.3442 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 148 | val loss 2.2834 val acc 15.6656 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 149 | val loss 2.3064 val acc 14.8539 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 150 | val loss 2.2848 val acc 15.9091 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 151 | val loss 2.2569 val acc 14.4278 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 152 | val loss 2.2281 val acc 16.9846 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 153 | val loss 2.3898 val acc 14.2857 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 154 | val loss 2.3342 val acc 11.7492 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 155 | val loss 2.3213 val acc 12.3377 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 156 | val loss 2.3092 val acc 12.6826 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 157 | val loss 2.2923 val acc 13.5958 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 158 | val loss 2.2682 val acc 17.5325 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 159 | val loss 2.2440 val acc 16.0308 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 160 | val loss 2.2378 val acc 17.5325 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 161 | val loss 2.2382 val acc 17.8369 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 162 | val loss 2.2381 val acc 17.8571 best val_acc 19.460227
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 163 | val loss 2.1876 val acc 19.7646 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 164 | val loss 2.3244 val acc 17.5325 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 165 | val loss 2.3867 val acc 11.9927 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 166 | val loss 2.3332 val acc 9.9635 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 167 | val loss 2.3257 val acc 9.9635 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 168 | val loss 2.3195 val acc 10.0649 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 169 | val loss 2.3136 val acc 10.8766 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 170 | val loss 2.3085 val acc 12.4594 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 171 | val loss 2.3030 val acc 14.5089 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 172 | val loss 2.2973 val acc 16.3352 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 173 | val loss 2.2913 val acc 17.1266 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 174 | val loss 2.2834 val acc 17.4107 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 175 | val loss 2.2745 val acc 17.5528 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 176 | val loss 2.2632 val acc 18.5268 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 177 | val loss 2.2516 val acc 18.7094 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 178 | val loss 2.2337 val acc 16.4976 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 179 | val loss 2.2096 val acc 17.4919 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 180 | val loss 2.1924 val acc 17.5933 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 181 | val loss 2.2888 val acc 16.4570 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 182 | val loss 2.2680 val acc 15.2192 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 183 | val loss 2.2500 val acc 15.7062 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 184 | val loss 2.2442 val acc 17.4107 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 185 | val loss 2.2285 val acc 14.1843 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 186 | val loss 2.2532 val acc 16.1120 best val_acc 19.764610
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 187 | val loss 2.1816 val acc 21.6518 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 188 | val loss 2.1925 val acc 18.3847 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 189 | val loss 2.1738 val acc 17.6339 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 190 | val loss 2.1411 val acc 20.0081 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 191 | val loss 2.4707 val acc 18.1412 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 192 | val loss 2.4342 val acc 9.4562 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 193 | val loss 2.3764 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 194 | val loss 2.3625 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 195 | val loss 2.3518 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 196 | val loss 2.3438 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 197 | val loss 2.3370 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 198 | val loss 2.3310 val acc 9.9229 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 199 | val loss 2.3260 val acc 9.8417 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 200 | val loss 2.3220 val acc 9.8011 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 201 | val loss 2.3185 val acc 9.4968 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 202 | val loss 2.3151 val acc 9.6794 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 203 | val loss 2.3120 val acc 9.9026 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 204 | val loss 2.3094 val acc 10.9172 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 205 | val loss 2.3069 val acc 11.3839 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 206 | val loss 2.3040 val acc 11.9927 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 207 | val loss 2.3014 val acc 12.0739 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 208 | val loss 2.2986 val acc 12.0130 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 209 | val loss 2.2959 val acc 12.1753 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 210 | val loss 2.2914 val acc 12.2565 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 211 | val loss 2.2875 val acc 11.6274 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 212 | val loss 2.2824 val acc 12.0739 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 213 | val loss 2.2796 val acc 12.7638 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 214 | val loss 2.2797 val acc 15.1177 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 215 | val loss 2.2848 val acc 15.2597 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 216 | val loss 2.2996 val acc 15.8482 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 217 | val loss 2.2883 val acc 16.1323 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 218 | val loss 2.2706 val acc 17.2484 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 219 | val loss 2.2577 val acc 15.9700 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 220 | val loss 2.2270 val acc 19.7849 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 221 | val loss 2.2729 val acc 16.7005 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 222 | val loss 2.5832 val acc 11.2622 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 223 | val loss 2.3215 val acc 15.6859 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 224 | val loss 2.2867 val acc 15.6859 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 225 | val loss 2.2456 val acc 16.3961 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 226 | val loss 2.2136 val acc 15.8888 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 227 | val loss 2.1959 val acc 17.7760 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 228 | val loss 2.1780 val acc 18.0398 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 229 | val loss 2.3168 val acc 14.6510 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 230 | val loss 2.3406 val acc 8.2589 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 231 | val loss 2.2999 val acc 15.1989 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 232 | val loss 2.2773 val acc 14.2857 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 233 | val loss 2.2515 val acc 14.7119 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 234 | val loss 2.2649 val acc 13.8190 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 235 | val loss 2.2544 val acc 15.7468 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 236 | val loss 2.2832 val acc 14.2248 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 237 | val loss 2.3168 val acc 10.3084 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 238 | val loss 2.2688 val acc 15.9903 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 239 | val loss 2.2394 val acc 15.0568 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 240 | val loss 2.2175 val acc 18.9529 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 241 | val loss 2.2496 val acc 15.5641 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 242 | val loss 2.3012 val acc 12.9261 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 243 | val loss 2.2317 val acc 16.5584 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 244 | val loss 2.1682 val acc 16.3352 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 245 | val loss 2.1677 val acc 16.3555 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 246 | val loss 2.1650 val acc 17.3295 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 247 | val loss 2.3450 val acc 19.6226 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 248 | val loss 2.3675 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 249 | val loss 2.3537 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 250 | val loss 2.3426 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 251 | val loss 2.3331 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 252 | val loss 2.3259 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 253 | val loss 2.3190 val acc 9.9838 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 254 | val loss 2.3117 val acc 10.1461 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 255 | val loss 2.3018 val acc 11.3839 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 256 | val loss 2.2866 val acc 16.0917 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 257 | val loss 2.2649 val acc 17.1672 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 258 | val loss 2.2372 val acc 16.5584 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 259 | val loss 2.2210 val acc 15.4424 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 260 | val loss 2.2035 val acc 18.2833 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 261 | val loss 2.3470 val acc 14.9959 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 262 | val loss 2.3358 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 263 | val loss 2.3285 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 264 | val loss 2.3229 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 265 | val loss 2.3182 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 266 | val loss 2.3145 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 267 | val loss 2.3109 val acc 9.9838 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 268 | val loss 2.3076 val acc 10.0852 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 269 | val loss 2.3042 val acc 10.5519 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 270 | val loss 2.3003 val acc 12.1550 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 271 | val loss 2.2945 val acc 16.8628 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 272 | val loss 2.2842 val acc 16.6396 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 273 | val loss 2.2648 val acc 13.6364 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 274 | val loss 2.2366 val acc 13.1494 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 275 | val loss 2.2165 val acc 15.1786 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 276 | val loss 2.1840 val acc 17.0252 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 277 | val loss 2.2333 val acc 15.4627 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 278 | val loss 2.2695 val acc 14.1843 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 279 | val loss 2.1881 val acc 17.0252 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 280 | val loss 2.1684 val acc 17.0252 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 281 | val loss 2.1959 val acc 17.0657 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 282 | val loss 2.1620 val acc 17.1672 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 283 | val loss 2.1821 val acc 17.0657 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 284 | val loss 2.1490 val acc 17.8166 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 285 | val loss 2.1267 val acc 16.9846 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 286 | val loss 2.1216 val acc 20.0893 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 287 | val loss 2.2515 val acc 16.7411 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 288 | val loss 2.3769 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 289 | val loss 2.3577 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 290 | val loss 2.3394 val acc 10.4505 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 291 | val loss 2.3196 val acc 12.7841 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 292 | val loss 2.3014 val acc 16.2135 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 293 | val loss 2.2829 val acc 16.0917 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 294 | val loss 2.2530 val acc 17.6136 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 295 | val loss 2.3304 val acc 13.3523 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 296 | val loss 2.3357 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 297 | val loss 2.3228 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 298 | val loss 2.3112 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 299 | val loss 2.2974 val acc 11.1607 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 300 | val loss 2.2779 val acc 13.7581 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 301 | val loss 2.2450 val acc 16.3352 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 302 | val loss 2.2186 val acc 15.7062 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 303 | val loss 2.1726 val acc 17.8571 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 304 | val loss 2.1501 val acc 17.6542 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 305 | val loss 2.1542 val acc 17.1875 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 306 | val loss 2.6825 val acc 15.6656 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 307 | val loss 2.4552 val acc 11.7086 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 308 | val loss 2.3920 val acc 11.7492 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 309 | val loss 2.3667 val acc 13.7378 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 310 | val loss 2.3608 val acc 14.7727 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 311 | val loss 2.3357 val acc 11.6680 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 312 | val loss 2.3082 val acc 15.1583 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 313 | val loss 2.2912 val acc 15.3206 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 314 | val loss 2.2609 val acc 16.6193 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 315 | val loss 2.3865 val acc 13.4537 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 316 | val loss 2.3399 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 317 | val loss 2.3297 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 318 | val loss 2.3216 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 319 | val loss 2.3151 val acc 9.8620 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 320 | val loss 2.3095 val acc 9.9229 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 321 | val loss 2.3047 val acc 10.8563 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 322 | val loss 2.2975 val acc 11.9115 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 323 | val loss 2.2906 val acc 14.2045 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 324 | val loss 2.2784 val acc 17.0657 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 325 | val loss 2.2569 val acc 13.6567 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 326 | val loss 2.2212 val acc 16.8425 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 327 | val loss 2.2709 val acc 11.1201 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 328 | val loss 2.3210 val acc 9.1315 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 329 | val loss 2.3046 val acc 10.2070 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 330 | val loss 2.2810 val acc 11.8304 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 331 | val loss 2.2285 val acc 17.0455 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 332 | val loss 2.2308 val acc 16.5584 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 333 | val loss 2.2561 val acc 15.8685 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 334 | val loss 2.1931 val acc 16.8425 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 335 | val loss 2.1833 val acc 18.1615 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 336 | val loss 2.1851 val acc 19.8661 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 337 | val loss 2.3294 val acc 14.4075 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 338 | val loss 2.3648 val acc 10.0852 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 339 | val loss 2.3411 val acc 11.5463 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 340 | val loss 2.3179 val acc 13.3523 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 341 | val loss 2.2892 val acc 12.4797 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 342 | val loss 2.2531 val acc 16.1932 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 343 | val loss 2.2387 val acc 16.2541 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 344 | val loss 2.2225 val acc 17.3904 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 345 | val loss 2.3444 val acc 14.9351 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 346 | val loss 2.3679 val acc 9.9432 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 347 | val loss 2.3480 val acc 9.9635 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 348 | val loss 2.3319 val acc 10.2273 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 349 | val loss 2.3147 val acc 11.4042 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 350 | val loss 2.2912 val acc 15.8888 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 351 | val loss 2.2594 val acc 14.1234 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 352 | val loss 2.2114 val acc 16.2135 best val_acc 21.651786
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 353 | val loss 2.1599 val acc 22.1794 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 354 | val loss 2.1558 val acc 17.9992 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 355 | val loss 2.2144 val acc 17.8369 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 356 | val loss 2.2551 val acc 16.7005 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 357 | val loss 2.2436 val acc 16.3555 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 358 | val loss 2.2476 val acc 15.1786 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 359 | val loss 2.3071 val acc 12.5203 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 360 | val loss 2.3311 val acc 10.1055 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 361 | val loss 2.2684 val acc 15.6453 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 362 | val loss 2.2682 val acc 15.7265 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 363 | val loss 2.2986 val acc 11.1607 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 364 | val loss 2.2223 val acc 19.0747 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 365 | val loss 2.2259 val acc 16.7005 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 366 | val loss 2.2776 val acc 13.8799 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 367 | val loss 2.2075 val acc 16.4367 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 368 | val loss 2.1588 val acc 18.8718 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 369 | val loss 2.1897 val acc 16.8628 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 370 | val loss 2.2835 val acc 10.9781 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 371 | val loss 2.1731 val acc 19.8255 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 372 | val loss 2.2420 val acc 17.1266 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 373 | val loss 2.3404 val acc 10.9781 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 374 | val loss 2.2859 val acc 13.2102 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 375 | val loss 2.2769 val acc 15.9294 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 376 | val loss 2.2150 val acc 14.4683 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 377 | val loss 2.1804 val acc 16.6396 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 378 | val loss 2.1853 val acc 14.6713 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 379 | val loss 2.7000 val acc 16.1526 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 380 | val loss 2.6144 val acc 11.3433 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 381 | val loss 2.4731 val acc 9.9432 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 382 | val loss 2.4441 val acc 9.9432 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 383 | val loss 2.4212 val acc 9.9229 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 384 | val loss 2.4029 val acc 10.0852 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 385 | val loss 2.3865 val acc 10.5317 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 386 | val loss 2.3691 val acc 11.3636 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 387 | val loss 2.3537 val acc 11.9724 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 388 | val loss 2.3378 val acc 12.6420 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 389 | val loss 2.3229 val acc 12.9870 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 390 | val loss 2.3044 val acc 13.1291 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 391 | val loss 2.2944 val acc 13.6567 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 392 | val loss 2.2726 val acc 15.5032 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 393 | val loss 2.2883 val acc 14.8133 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 394 | val loss 2.3168 val acc 9.9432 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 395 | val loss 2.2837 val acc 13.8596 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 396 | val loss 2.2488 val acc 15.2192 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 397 | val loss 2.2365 val acc 15.8888 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 398 | val loss 2.2681 val acc 15.0771 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 399 | val loss 2.3141 val acc 9.9432 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 400 | val loss 2.2908 val acc 11.6274 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 401 | val loss 2.2439 val acc 17.4107 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 402 | val loss 2.2310 val acc 17.1266 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 403 | val loss 2.2379 val acc 16.5584 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 404 | val loss 2.2968 val acc 15.6047 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 405 | val loss 2.3310 val acc 11.0998 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 406 | val loss 2.3120 val acc 14.1031 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 407 | val loss 2.2924 val acc 12.1144 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 408 | val loss 2.2787 val acc 11.7898 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 409 | val loss 2.2712 val acc 13.1494 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 410 | val loss 2.2534 val acc 13.7987 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 411 | val loss 2.2718 val acc 12.9464 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 412 | val loss 2.2836 val acc 14.8742 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 413 | val loss 2.2097 val acc 16.4976 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 414 | val loss 2.2296 val acc 15.1380 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 415 | val loss 2.2442 val acc 15.2192 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 416 | val loss 2.2341 val acc 15.2800 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 417 | val loss 2.3133 val acc 16.1323 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 418 | val loss 2.2765 val acc 15.4627 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 419 | val loss 2.2781 val acc 10.7752 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 420 | val loss 2.1913 val acc 17.6948 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 421 | val loss 2.1528 val acc 17.4107 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 422 | val loss 2.2567 val acc 16.0714 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 423 | val loss 2.3437 val acc 10.6331 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 424 | val loss 2.2570 val acc 16.7614 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 425 | val loss 2.1947 val acc 17.6745 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 426 | val loss 2.1454 val acc 18.7297 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 427 | val loss 2.3081 val acc 17.7963 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 428 | val loss 2.3506 val acc 13.3117 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 429 | val loss 2.2771 val acc 16.7005 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 430 | val loss 2.2875 val acc 15.7670 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 431 | val loss 2.3321 val acc 10.3693 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 432 | val loss 2.2908 val acc 12.1347 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 433 | val loss 2.2280 val acc 18.5674 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 434 | val loss 2.1775 val acc 18.1209 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 435 | val loss 2.1508 val acc 16.7817 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 436 | val loss 2.1602 val acc 18.1818 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 437 | val loss 2.1610 val acc 17.1875 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 438 | val loss 2.3915 val acc 16.8628 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 439 | val loss 2.4048 val acc 9.9838 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 440 | val loss 2.3588 val acc 10.3693 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 441 | val loss 2.3057 val acc 10.6128 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 442 | val loss 2.2399 val acc 14.5698 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 443 | val loss 2.1751 val acc 17.2687 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 444 | val loss 2.1653 val acc 16.7411 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 445 | val loss 2.1564 val acc 17.0252 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 446 | val loss 2.2778 val acc 17.4513 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 447 | val loss 2.3738 val acc 10.3287 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 448 | val loss 2.2954 val acc 12.9464 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 449 | val loss 2.2231 val acc 15.1380 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 450 | val loss 2.2244 val acc 16.3961 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 451 | val loss 2.3052 val acc 16.4976 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 452 | val loss 2.3451 val acc 10.4099 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 453 | val loss 2.3044 val acc 12.0130 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 454 | val loss 2.2501 val acc 15.9700 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 455 | val loss 2.1943 val acc 18.8920 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 456 | val loss 2.1585 val acc 18.3239 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 457 | val loss 2.1378 val acc 19.0544 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 458 | val loss 2.1390 val acc 19.0747 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 459 | val loss 2.1168 val acc 20.4748 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 460 | val loss 2.2180 val acc 18.7703 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 461 | val loss 2.3204 val acc 14.2045 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 462 | val loss 2.2358 val acc 17.1672 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 463 | val loss 2.1943 val acc 16.4367 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 464 | val loss 2.1962 val acc 16.4773 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 465 | val loss 2.4944 val acc 16.4773 best val_acc 22.179383
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 466 | val loss 2.4355 val acc 11.5666 best val_acc 22.179383
# ...
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1048 | val loss 2.3744 val acc 11.5666 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1049 | val loss 2.3051 val acc 17.1875 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1050 | val loss 2.2418 val acc 17.9180 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1051 | val loss 2.1935 val acc 17.0049 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1052 | val loss 2.1605 val acc 17.2078 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1053 | val loss 2.1558 val acc 17.4107 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1054 | val loss 2.1550 val acc 17.0049 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1055 | val loss 2.1699 val acc 17.2484 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1056 | val loss 2.2031 val acc 17.2281 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1057 | val loss 2.1212 val acc 18.0601 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1058 | val loss 2.1595 val acc 16.5179 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1059 | val loss 2.2452 val acc 17.7151 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1060 | val loss 2.1472 val acc 16.9643 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1061 | val loss 2.1331 val acc 17.1672 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1062 | val loss 2.2128 val acc 16.8628 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1063 | val loss 2.3674 val acc 12.1144 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1064 | val loss 2.2003 val acc 16.2338 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1065 | val loss 2.6636 val acc 15.4830 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1066 | val loss 2.5488 val acc 9.9432 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1067 | val loss 2.4607 val acc 9.9838 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1068 | val loss 2.4038 val acc 10.0041 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1069 | val loss 2.3655 val acc 10.0244 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1070 | val loss 2.3388 val acc 10.0446 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1071 | val loss 2.3207 val acc 10.5519 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1072 | val loss 2.3048 val acc 10.8766 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1073 | val loss 2.2886 val acc 10.2273 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1074 | val loss 2.2705 val acc 11.0998 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1075 | val loss 2.2541 val acc 12.5406 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1076 | val loss 2.2386 val acc 15.6250 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1077 | val loss 2.2231 val acc 15.8482 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1078 | val loss 2.2025 val acc 16.4164 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1079 | val loss 2.3490 val acc 11.5260 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1080 | val loss 2.3876 val acc 9.9432 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1081 | val loss 2.3368 val acc 9.9432 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1082 | val loss 2.3099 val acc 10.2070 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1083 | val loss 2.2908 val acc 10.9172 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1084 | val loss 2.2719 val acc 13.6972 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1085 | val loss 2.2592 val acc 15.5235 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1086 | val loss 2.2294 val acc 16.3149 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1087 | val loss 2.2183 val acc 15.8279 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1088 | val loss 2.1959 val acc 16.8019 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1089 | val loss 2.1863 val acc 16.6599 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1090 | val loss 2.1687 val acc 17.5325 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1091 | val loss 2.1736 val acc 16.9237 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1092 | val loss 2.2279 val acc 17.4107 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1093 | val loss 2.2200 val acc 17.6948 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1094 | val loss 2.1552 val acc 18.0398 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1095 | val loss 2.2422 val acc 14.8133 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1096 | val loss 2.3602 val acc 15.0771 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1097 | val loss 2.2235 val acc 17.9180 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1098 | val loss 2.1402 val acc 19.9067 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1099 | val loss 2.1531 val acc 17.6136 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1100 | val loss 2.1552 val acc 16.3555 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1101 | val loss 2.1951 val acc 16.8019 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1102 | val loss 2.2498 val acc 13.6972 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1103 | val loss 2.1670 val acc 17.3904 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1104 | val loss 2.2410 val acc 17.8977 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1105 | val loss 2.1522 val acc 17.5325 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1106 | val loss 2.1538 val acc 18.1412 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1107 | val loss 2.2009 val acc 16.7614 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1108 | val loss 2.2442 val acc 17.2484 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1109 | val loss 2.2207 val acc 17.6948 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1110 | val loss 2.2918 val acc 15.5641 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1111 | val loss 2.2005 val acc 17.1266 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1112 | val loss 2.2373 val acc 17.3701 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1113 | val loss 2.1983 val acc 17.8369 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1114 | val loss 2.2103 val acc 16.9237 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1115 | val loss 2.1681 val acc 17.6948 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1116 | val loss 2.2431 val acc 17.6542 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1117 | val loss 2.1794 val acc 18.1412 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1118 | val loss 2.1905 val acc 17.3498 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1119 | val loss 2.1617 val acc 19.1558 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1120 | val loss 2.2421 val acc 17.8369 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1121 | val loss 2.1694 val acc 18.3239 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1122 | val loss 2.2164 val acc 17.2281 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1123 | val loss 2.1568 val acc 20.2110 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1124 | val loss 2.2304 val acc 17.9383 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1125 | val loss 2.1765 val acc 18.2021 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1126 | val loss 2.2456 val acc 16.4570 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1127 | val loss 2.2007 val acc 19.2979 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1128 | val loss 2.2908 val acc 15.3206 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1129 | val loss 2.1821 val acc 17.6745 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1130 | val loss 2.1700 val acc 19.5008 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1131 | val loss 2.1768 val acc 20.7589 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1132 | val loss 2.2709 val acc 15.9497 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1133 | val loss 2.1669 val acc 18.0601 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1134 | val loss 2.1916 val acc 19.7240 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1135 | val loss 2.1971 val acc 20.9416 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1136 | val loss 2.3033 val acc 14.7524 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1137 | val loss 2.1639 val acc 17.9992 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1138 | val loss 2.1452 val acc 21.3880 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1139 | val loss 2.1721 val acc 20.9213 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1140 | val loss 2.2797 val acc 14.8945 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1141 | val loss 2.1551 val acc 18.0195 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1142 | val loss 2.2061 val acc 20.3125 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1143 | val loss 2.2413 val acc 20.2313 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1144 | val loss 2.3815 val acc 11.1607 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1145 | val loss 2.1807 val acc 17.6339 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1146 | val loss 2.0795 val acc 20.6981 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1147 | val loss 2.1277 val acc 20.5966 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1148 | val loss 2.1836 val acc 17.3093 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1149 | val loss 2.1639 val acc 21.1445 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1150 | val loss 2.2523 val acc 15.9091 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1151 | val loss 2.1515 val acc 18.2021 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1152 | val loss 2.2606 val acc 16.7614 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1153 | val loss 2.1647 val acc 20.6169 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1154 | val loss 2.1278 val acc 17.8571 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1155 | val loss 2.2368 val acc 22.1388 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1156 | val loss 2.3645 val acc 11.5869 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1157 | val loss 2.1082 val acc 18.4050 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1158 | val loss 2.0757 val acc 21.3068 best val_acc 22.605519
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1159 | val loss 2.0465 val acc 22.7273 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1160 | val loss 2.1251 val acc 21.9562 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1161 | val loss 2.3142 val acc 13.4740 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1162 | val loss 2.1081 val acc 20.5560 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1163 | val loss 2.1964 val acc 21.6518 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1164 | val loss 2.0679 val acc 22.1591 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1165 | val loss 2.0852 val acc 19.9878 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1166 | val loss 2.3192 val acc 21.3880 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1167 | val loss 2.5524 val acc 10.2679 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1168 | val loss 2.3605 val acc 12.0333 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1169 | val loss 2.1886 val acc 18.0195 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1170 | val loss 2.1007 val acc 22.3417 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1171 | val loss 2.0733 val acc 19.9067 best val_acc 22.727273
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1172 | val loss 2.1618 val acc 23.5593 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1173 | val loss 2.3294 val acc 16.9034 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1174 | val loss 2.1398 val acc 18.7703 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1175 | val loss 2.1035 val acc 21.0836 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1176 | val loss 2.1763 val acc 21.2054 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1177 | val loss 2.3484 val acc 15.0771 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1178 | val loss 2.2456 val acc 17.5933 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1179 | val loss 2.2669 val acc 12.6218 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1180 | val loss 2.1615 val acc 21.6518 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1181 | val loss 3.8618 val acc 14.4481 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1182 | val loss 3.5050 val acc 11.4448 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1183 | val loss 3.0788 val acc 8.2995 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1184 | val loss 2.8864 val acc 9.9432 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1185 | val loss 2.7995 val acc 9.9432 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1186 | val loss 2.7406 val acc 9.9432 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1187 | val loss 2.6946 val acc 12.1347 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1188 | val loss 2.6552 val acc 11.1607 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1189 | val loss 2.6219 val acc 13.2711 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1190 | val loss 2.5838 val acc 10.2476 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1191 | val loss 2.5483 val acc 11.2825 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1192 | val loss 2.5137 val acc 13.3726 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1193 | val loss 2.4812 val acc 15.3206 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1194 | val loss 2.4444 val acc 14.2248 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1195 | val loss 2.4421 val acc 9.6185 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1196 | val loss 2.3879 val acc 10.1258 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1197 | val loss 2.3618 val acc 11.7898 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1198 | val loss 2.3116 val acc 15.8279 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1199 | val loss 2.3901 val acc 11.2216 best val_acc 23.559253
# bulyan: at our-agr n_at 10 n_mal_sel 10 e 1200 | val loss 2.3479 val acc 9.9432 best val_acc 23.559253

# %% [markdown]
# ## Code for our first AGR-agnostic attack called Min-Max

# %%
'''
MIN-MAX attack
'''
def our_attack_dist(all_updates, model_re, n_attackers, dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)  # unit vector, dir opp to good dir
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)

    lamda = torch.Tensor([10.0]).float().cuda()
    # print(lamda)
    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0
    
    distances = []
    for update in all_updates:
        distance = torch.norm((all_updates - update), dim=1) ** 2
        distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)
    
    max_distance = torch.max(distances)
    del distances

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        distance = torch.norm((all_updates - mal_update), dim=1) ** 2
        max_d = torch.max(distance)
        
        if max_d <= max_distance:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    mal_update = (model_re - lamda_succ * deviation)
    
    return mal_update

# %% [markdown]
# ## Execute Min-max attack on Bulyan

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='min-max'
dev_type ='std'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    candidates = []

    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_median(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-max':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_dist(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-sum':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_score(malicious_grads, agg_grads, n_attacker, dev_type)

            mal_updates = torch.stack([mal_update] * n_attacker)
            malicious_grads = torch.cat((mal_updates, user_grads), 0)

        if epoch_num==0: print('malicious_grads shape ', malicious_grads.shape)

        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break
            
        epoch_num+=1
# Out:
# malicious_grads shape  torch.Size([50, 2472266])
# /home/vshejwalkar/fed-quant-robustness/code/cifar10/sgd.py:108: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729138878/work/torch/csrc/utils/python_arg_parser.cpp:882.)
#   p.data.add_(-group['lr'], d_p)
# bulyan: at min-max n_at 10 n_mal_sel 5 e 0 | val loss 2.3036 val acc 10.5519 best val_acc 10.551948
# bulyan: at min-max n_at 10 n_mal_sel 5 e 1 | val loss 2.3030 val acc 10.8563 best val_acc 10.856331
# bulyan: at min-max n_at 10 n_mal_sel 6 e 2 | val loss 2.3024 val acc 10.9375 best val_acc 10.937500
# bulyan: at min-max n_at 10 n_mal_sel 5 e 3 | val loss 2.3019 val acc 10.4302 best val_acc 10.937500
# bulyan: at min-max n_at 10 n_mal_sel 5 e 4 | val loss 2.3014 val acc 10.9172 best val_acc 10.937500
# bulyan: at min-max n_at 10 n_mal_sel 5 e 5 | val loss 2.3007 val acc 11.1404 best val_acc 11.140422
# bulyan: at min-max n_at 10 n_mal_sel 6 e 6 | val loss 2.2999 val acc 11.4042 best val_acc 11.404221
# bulyan: at min-max n_at 10 n_mal_sel 5 e 7 | val loss 2.2991 val acc 11.8506 best val_acc 11.850649
# bulyan: at min-max n_at 10 n_mal_sel 5 e 8 | val loss 2.2982 val acc 12.0333 best val_acc 12.033279
# bulyan: at min-max n_at 10 n_mal_sel 5 e 9 | val loss 2.2968 val acc 12.1550 best val_acc 12.155032
# bulyan: at min-max n_at 10 n_mal_sel 6 e 10 | val loss 2.2951 val acc 12.7841 best val_acc 12.784091
# bulyan: at min-max n_at 10 n_mal_sel 5 e 11 | val loss 2.2933 val acc 11.8101 best val_acc 12.784091
# bulyan: at min-max n_at 10 n_mal_sel 5 e 12 | val loss 2.2906 val acc 12.2768 best val_acc 12.784091
# bulyan: at min-max n_at 10 n_mal_sel 5 e 13 | val loss 2.2868 val acc 13.7378 best val_acc 13.737825
# bulyan: at min-max n_at 10 n_mal_sel 6 e 14 | val loss 2.2817 val acc 13.8799 best val_acc 13.879870
# bulyan: at min-max n_at 10 n_mal_sel 6 e 15 | val loss 2.2751 val acc 15.3815 best val_acc 15.381494
# bulyan: at min-max n_at 10 n_mal_sel 5 e 16 | val loss 2.2665 val acc 15.2394 best val_acc 15.381494
# bulyan: at min-max n_at 10 n_mal_sel 6 e 17 | val loss 2.2538 val acc 15.7468 best val_acc 15.746753
# bulyan: at min-max n_at 10 n_mal_sel 5 e 18 | val loss 2.2409 val acc 16.9440 best val_acc 16.943994
# bulyan: at min-max n_at 10 n_mal_sel 5 e 19 | val loss 2.2263 val acc 21.8344 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 20 | val loss 2.2652 val acc 16.0714 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 21 | val loss 2.3289 val acc 11.1404 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 22 | val loss 2.2795 val acc 14.4481 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 23 | val loss 2.2373 val acc 19.0950 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 24 | val loss 2.1963 val acc 21.8141 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 25 | val loss 2.1699 val acc 21.7938 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 26 | val loss 2.1518 val acc 20.6981 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 27 | val loss 2.2244 val acc 19.5820 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 28 | val loss 2.5834 val acc 15.3003 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 29 | val loss 2.3191 val acc 9.9432 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 30 | val loss 2.3104 val acc 9.9432 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 31 | val loss 2.3055 val acc 9.9432 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 32 | val loss 2.3010 val acc 9.9432 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 33 | val loss 2.2961 val acc 9.9432 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 34 | val loss 2.2909 val acc 10.0041 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 35 | val loss 2.2854 val acc 10.1055 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 36 | val loss 2.2796 val acc 10.1055 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 37 | val loss 2.2726 val acc 10.1461 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 38 | val loss 2.2647 val acc 10.5519 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 39 | val loss 2.2566 val acc 10.6331 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 40 | val loss 2.2483 val acc 11.4042 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 41 | val loss 2.2401 val acc 11.3636 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 42 | val loss 2.2308 val acc 11.8912 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 43 | val loss 2.2240 val acc 11.4854 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 7 e 44 | val loss 2.2238 val acc 12.6218 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 7 e 45 | val loss 2.2298 val acc 11.3028 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 46 | val loss 2.2698 val acc 14.4683 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 47 | val loss 2.2208 val acc 15.0365 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 48 | val loss 2.1978 val acc 15.9700 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 7 e 49 | val loss 2.1935 val acc 19.3994 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 50 | val loss 2.2041 val acc 16.6193 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 4 e 51 | val loss 2.2682 val acc 14.1843 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 52 | val loss 2.2142 val acc 15.7468 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 7 e 53 | val loss 2.1722 val acc 18.5877 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 54 | val loss 2.1816 val acc 20.7995 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 5 e 55 | val loss 2.2041 val acc 18.2224 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 56 | val loss 2.2915 val acc 12.9261 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 57 | val loss 2.2488 val acc 15.3003 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 6 e 58 | val loss 2.1871 val acc 15.9294 best val_acc 21.834416
# bulyan: at min-max n_at 10 n_mal_sel 7 e 59 | val loss 2.1536 val acc 22.4432 best val_acc 22.443182
# bulyan: at min-max n_at 10 n_mal_sel 6 e 60 | val loss 2.1481 val acc 20.2110 best val_acc 22.443182
# bulyan: at min-max n_at 10 n_mal_sel 7 e 61 | val loss 2.1380 val acc 22.9911 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 62 | val loss 2.1342 val acc 20.8604 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 63 | val loss 2.1340 val acc 22.9302 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 64 | val loss 2.2100 val acc 15.4830 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 65 | val loss 2.2963 val acc 18.1006 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 4 e 66 | val loss 2.3357 val acc 10.8157 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 67 | val loss 2.3316 val acc 10.8157 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 68 | val loss 2.3278 val acc 11.0593 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 69 | val loss 2.3247 val acc 10.5519 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 70 | val loss 2.3217 val acc 10.4099 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 71 | val loss 2.3190 val acc 10.1867 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 72 | val loss 2.3164 val acc 10.0041 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 73 | val loss 2.3139 val acc 9.6388 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 74 | val loss 2.3116 val acc 9.6388 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 75 | val loss 2.3094 val acc 9.7200 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 76 | val loss 2.3069 val acc 10.0244 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 77 | val loss 2.3042 val acc 10.5722 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 78 | val loss 2.3013 val acc 10.7346 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 79 | val loss 2.2996 val acc 12.2565 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 80 | val loss 2.2963 val acc 10.4505 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 81 | val loss 2.3017 val acc 11.4042 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 82 | val loss 2.2978 val acc 9.4968 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 83 | val loss 2.2871 val acc 10.5519 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 84 | val loss 2.2809 val acc 14.9148 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 85 | val loss 2.2729 val acc 10.5519 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 86 | val loss 2.2823 val acc 11.8912 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 87 | val loss 2.2910 val acc 9.6185 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 88 | val loss 2.2671 val acc 9.8620 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 89 | val loss 2.2504 val acc 9.5779 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 90 | val loss 2.2301 val acc 11.7898 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 4 e 91 | val loss 2.2070 val acc 15.1989 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 92 | val loss 2.1888 val acc 14.5901 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 93 | val loss 2.2620 val acc 14.2451 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 94 | val loss 2.6448 val acc 9.5779 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 95 | val loss 2.3285 val acc 10.4302 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 96 | val loss 2.3060 val acc 10.4099 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 97 | val loss 2.3049 val acc 10.1461 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 98 | val loss 2.3039 val acc 10.2070 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 99 | val loss 2.3030 val acc 10.3084 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 100 | val loss 2.3022 val acc 10.1258 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 101 | val loss 2.3009 val acc 10.2070 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 102 | val loss 2.2996 val acc 10.5519 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 103 | val loss 2.2982 val acc 12.4797 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 104 | val loss 2.2965 val acc 13.7175 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 105 | val loss 2.2941 val acc 14.4278 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 106 | val loss 2.2913 val acc 14.5495 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 107 | val loss 2.2886 val acc 15.8482 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 8 e 108 | val loss 2.2843 val acc 16.3555 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 109 | val loss 2.2788 val acc 16.4164 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 110 | val loss 2.2733 val acc 15.5844 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 8 e 111 | val loss 2.2689 val acc 14.3669 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 112 | val loss 2.2601 val acc 17.4310 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 8 e 113 | val loss 2.2603 val acc 13.4131 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 114 | val loss 2.2681 val acc 13.6972 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 115 | val loss 2.2339 val acc 16.5787 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 116 | val loss 2.2239 val acc 17.6136 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 8 e 117 | val loss 2.2081 val acc 17.1063 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 118 | val loss 2.2052 val acc 16.7614 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 119 | val loss 2.2308 val acc 13.1291 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 120 | val loss 2.2772 val acc 12.9870 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 121 | val loss 2.2845 val acc 14.3060 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 122 | val loss 2.2480 val acc 16.2541 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 123 | val loss 2.2212 val acc 15.1583 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 124 | val loss 2.2134 val acc 17.8571 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 7 e 125 | val loss 2.1954 val acc 18.7297 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 5 e 126 | val loss 2.2163 val acc 17.9383 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 127 | val loss 2.1537 val acc 20.0081 best val_acc 22.991071
# bulyan: at min-max n_at 10 n_mal_sel 6 e 128 | val loss 2.1389 val acc 23.4578 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 7 e 129 | val loss 2.1852 val acc 17.5731 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 130 | val loss 2.2833 val acc 13.1899 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 131 | val loss 2.2290 val acc 15.7670 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 132 | val loss 2.1798 val acc 15.8888 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 133 | val loss 2.1373 val acc 17.9992 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 134 | val loss 2.1275 val acc 19.3791 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 135 | val loss 2.2448 val acc 14.5901 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 136 | val loss 2.2937 val acc 13.7784 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 8 e 137 | val loss 2.2534 val acc 14.6307 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 138 | val loss 2.2010 val acc 16.9237 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 139 | val loss 2.1763 val acc 17.7354 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 140 | val loss 2.1583 val acc 17.8977 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 7 e 141 | val loss 2.1345 val acc 20.3125 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 142 | val loss 2.1442 val acc 18.5268 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 143 | val loss 2.1591 val acc 18.5268 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 144 | val loss 2.1311 val acc 19.0341 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 145 | val loss 2.1082 val acc 19.4399 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 146 | val loss 2.1421 val acc 20.0081 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 147 | val loss 2.0963 val acc 20.9010 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 148 | val loss 2.4836 val acc 12.3782 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 7 e 149 | val loss 2.2368 val acc 17.1266 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 150 | val loss 2.2110 val acc 17.4716 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 151 | val loss 2.2028 val acc 17.2890 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 152 | val loss 2.1731 val acc 18.4456 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 153 | val loss 2.1761 val acc 19.6834 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 154 | val loss 2.1220 val acc 21.4692 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 155 | val loss 2.1170 val acc 20.9213 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 156 | val loss 2.0911 val acc 22.3620 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 7 e 157 | val loss 2.0933 val acc 21.0836 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 158 | val loss 2.0981 val acc 21.5706 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 159 | val loss 2.2213 val acc 17.6745 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 160 | val loss 2.0826 val acc 21.2459 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 161 | val loss 2.0721 val acc 20.5763 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 162 | val loss 2.1959 val acc 16.9440 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 163 | val loss 2.0696 val acc 23.0317 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 164 | val loss 2.0501 val acc 22.6664 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 7 e 165 | val loss 2.1062 val acc 21.7532 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 166 | val loss 2.1259 val acc 22.8490 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 167 | val loss 2.2368 val acc 18.0195 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 8 e 168 | val loss 2.3687 val acc 9.7606 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 169 | val loss 2.2868 val acc 13.3320 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 170 | val loss 2.2410 val acc 14.6307 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 171 | val loss 2.2029 val acc 14.8336 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 172 | val loss 2.1726 val acc 16.8425 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 173 | val loss 2.1445 val acc 17.1266 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 174 | val loss 2.1461 val acc 18.7906 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 175 | val loss 2.1142 val acc 20.6169 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 176 | val loss 2.2498 val acc 14.1234 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 177 | val loss 2.0633 val acc 18.1209 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 178 | val loss 2.1722 val acc 17.8977 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 179 | val loss 2.2146 val acc 17.4716 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 180 | val loss 2.2570 val acc 11.3231 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 6 e 181 | val loss 2.1543 val acc 15.0771 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 182 | val loss 2.0811 val acc 18.9732 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 4 e 183 | val loss 2.0416 val acc 18.9732 best val_acc 23.457792
# bulyan: at min-max n_at 10 n_mal_sel 5 e 184 | val loss 2.0176 val acc 23.7419 best val_acc 23.741883
# bulyan: at min-max n_at 10 n_mal_sel 5 e 185 | val loss 2.0059 val acc 21.6315 best val_acc 23.741883
# bulyan: at min-max n_at 10 n_mal_sel 5 e 186 | val loss 2.0938 val acc 20.2313 best val_acc 23.741883
# bulyan: at min-max n_at 10 n_mal_sel 5 e 187 | val loss 2.2675 val acc 15.7468 best val_acc 23.741883
# bulyan: at min-max n_at 10 n_mal_sel 5 e 188 | val loss 2.1906 val acc 16.4773 best val_acc 23.741883
# bulyan: at min-max n_at 10 n_mal_sel 6 e 189 | val loss 2.1022 val acc 24.6347 best val_acc 24.634740
# bulyan: at min-max n_at 10 n_mal_sel 6 e 190 | val loss 2.0078 val acc 24.5130 best val_acc 24.634740
# bulyan: at min-max n_at 10 n_mal_sel 5 e 191 | val loss 1.9656 val acc 27.4351 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 192 | val loss 1.9906 val acc 26.7857 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 193 | val loss 2.2132 val acc 17.2484 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 194 | val loss 2.1450 val acc 18.1412 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 195 | val loss 2.1372 val acc 20.0690 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 196 | val loss 2.1753 val acc 18.2224 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 197 | val loss 2.0703 val acc 20.4140 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 198 | val loss 2.0083 val acc 20.8198 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 199 | val loss 1.9790 val acc 21.9156 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 200 | val loss 1.9799 val acc 23.3766 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 201 | val loss 1.9917 val acc 23.5998 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 202 | val loss 2.1356 val acc 20.7386 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 203 | val loss 2.3181 val acc 14.8133 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 204 | val loss 2.2080 val acc 17.6745 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 205 | val loss 2.1240 val acc 18.5877 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 206 | val loss 2.1006 val acc 23.1737 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 207 | val loss 2.1931 val acc 19.2979 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 208 | val loss 2.9036 val acc 16.7005 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 209 | val loss 2.2807 val acc 10.8157 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 210 | val loss 2.2364 val acc 13.0885 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 4 e 211 | val loss 2.2055 val acc 17.3295 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 212 | val loss 2.2095 val acc 18.1209 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 8 e 213 | val loss 2.1547 val acc 20.0690 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 214 | val loss 2.1755 val acc 17.0049 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 215 | val loss 2.0717 val acc 22.3011 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 216 | val loss 2.0495 val acc 24.5536 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 8 e 217 | val loss 2.0267 val acc 27.0292 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 218 | val loss 2.3030 val acc 15.1786 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 219 | val loss 2.1396 val acc 21.6518 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 220 | val loss 2.1056 val acc 20.2922 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 221 | val loss 2.1514 val acc 22.9911 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 222 | val loss 2.3078 val acc 11.1201 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 8 e 223 | val loss 2.2113 val acc 15.8685 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 4 e 224 | val loss 2.1751 val acc 18.6080 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 4 e 225 | val loss 2.1522 val acc 19.6226 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 226 | val loss 2.1615 val acc 21.5909 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 227 | val loss 2.2200 val acc 13.9205 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 228 | val loss 2.0807 val acc 22.1185 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 229 | val loss 2.0795 val acc 23.9448 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 230 | val loss 2.1914 val acc 13.1899 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 231 | val loss 2.0870 val acc 21.2662 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 232 | val loss 2.0372 val acc 24.8985 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 233 | val loss 2.0192 val acc 26.1972 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 234 | val loss 2.0869 val acc 19.9472 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 235 | val loss 2.1701 val acc 22.8693 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 236 | val loss 2.3072 val acc 12.1753 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 8 e 237 | val loss 2.1964 val acc 17.9992 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 238 | val loss 2.1855 val acc 17.7557 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 5 e 239 | val loss 2.1348 val acc 20.2516 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 4 e 240 | val loss 2.1088 val acc 20.7589 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 241 | val loss 2.0315 val acc 25.0203 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 6 e 242 | val loss 2.0175 val acc 22.1591 best val_acc 27.435065
# bulyan: at min-max n_at 10 n_mal_sel 7 e 243 | val loss 1.9835 val acc 27.5771 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 6 e 244 | val loss 2.0343 val acc 22.1997 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 7 e 245 | val loss 2.0062 val acc 25.9537 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 7 e 246 | val loss 2.1880 val acc 17.1672 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 7 e 247 | val loss 2.1239 val acc 22.2808 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 7 e 248 | val loss 2.1163 val acc 19.3791 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 7 e 249 | val loss 2.0355 val acc 24.1071 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 6 e 250 | val loss 2.0217 val acc 23.5998 best val_acc 27.577110
# bulyan: at min-max n_at 10 n_mal_sel 7 e 251 | val loss 1.9440 val acc 28.2265 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 7 e 252 | val loss 1.9875 val acc 23.7216 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 8 e 253 | val loss 2.1134 val acc 26.1364 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 254 | val loss 2.3707 val acc 16.8425 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 8 e 255 | val loss 2.1898 val acc 15.2192 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 4 e 256 | val loss 2.1322 val acc 18.3239 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 4 e 257 | val loss 2.0788 val acc 20.1096 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 258 | val loss 2.0521 val acc 22.7070 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 5 e 259 | val loss 2.0706 val acc 21.1242 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 7 e 260 | val loss 2.0360 val acc 23.3157 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 8 e 261 | val loss 2.1561 val acc 16.7411 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 262 | val loss 2.0171 val acc 26.4813 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 8 e 263 | val loss 2.0945 val acc 21.3677 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 264 | val loss 2.0358 val acc 23.1737 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 265 | val loss 2.0023 val acc 22.1997 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 266 | val loss 1.9524 val acc 26.5016 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 7 e 267 | val loss 1.9742 val acc 24.7971 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 7 e 268 | val loss 2.1098 val acc 25.1015 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 269 | val loss 2.5415 val acc 16.1729 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 270 | val loss 2.1452 val acc 23.3766 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 271 | val loss 2.0819 val acc 24.2898 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 272 | val loss 2.0256 val acc 25.9131 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 7 e 273 | val loss 1.9892 val acc 28.1453 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 7 e 274 | val loss 2.0547 val acc 26.8872 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 5 e 275 | val loss 2.2242 val acc 17.4107 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 276 | val loss 2.0190 val acc 24.3304 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 277 | val loss 1.9290 val acc 26.9278 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 7 e 278 | val loss 2.0138 val acc 24.3912 best val_acc 28.226461
# bulyan: at min-max n_at 10 n_mal_sel 6 e 279 | val loss 1.9380 val acc 28.9976 best val_acc 28.997565
# bulyan: at min-max n_at 10 n_mal_sel 7 e 280 | val loss 2.0596 val acc 26.2784 best val_acc 28.997565
# bulyan: at min-max n_at 10 n_mal_sel 7 e 281 | val loss 1.9787 val acc 28.1250 best val_acc 28.997565
# bulyan: at min-max n_at 10 n_mal_sel 8 e 282 | val loss 2.0096 val acc 23.9448 best val_acc 28.997565
# bulyan: at min-max n_at 10 n_mal_sel 6 e 283 | val loss 1.9741 val acc 24.4115 best val_acc 28.997565
# bulyan: at min-max n_at 10 n_mal_sel 6 e 284 | val loss 1.8782 val acc 31.7370 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 285 | val loss 1.9131 val acc 31.3109 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 286 | val loss 2.8358 val acc 17.4919 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 287 | val loss 2.1796 val acc 19.2370 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 288 | val loss 2.4891 val acc 12.9667 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 289 | val loss 2.5782 val acc 12.7638 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 290 | val loss 2.2974 val acc 12.7029 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 291 | val loss 2.3289 val acc 11.9318 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 292 | val loss 2.3524 val acc 9.9432 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 293 | val loss 2.3224 val acc 10.7752 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 294 | val loss 2.2561 val acc 15.1786 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 295 | val loss 2.2382 val acc 13.9205 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 296 | val loss 2.3132 val acc 11.1201 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 297 | val loss 2.2517 val acc 14.5089 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 298 | val loss 2.1559 val acc 20.0690 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 299 | val loss 2.1157 val acc 22.0576 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 300 | val loss 2.0920 val acc 22.1997 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 301 | val loss 2.4420 val acc 20.8807 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 302 | val loss 2.3697 val acc 9.9026 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 303 | val loss 2.3526 val acc 9.0503 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 304 | val loss 2.3179 val acc 10.1664 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 305 | val loss 2.3343 val acc 11.2825 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 306 | val loss 2.3292 val acc 10.0649 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 307 | val loss 2.2650 val acc 13.0276 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 308 | val loss 2.2423 val acc 15.1177 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 309 | val loss 2.2957 val acc 11.7086 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 310 | val loss 2.1762 val acc 17.2890 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 311 | val loss 2.2483 val acc 15.9294 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 312 | val loss 2.3516 val acc 9.6997 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 313 | val loss 2.3361 val acc 8.9286 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 314 | val loss 2.3258 val acc 9.3141 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 315 | val loss 2.3163 val acc 10.5317 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 316 | val loss 2.3157 val acc 10.0446 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 317 | val loss 2.3047 val acc 11.2419 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 318 | val loss 2.2990 val acc 10.2070 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 319 | val loss 2.2836 val acc 10.7549 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 320 | val loss 2.2580 val acc 11.2622 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 321 | val loss 2.2179 val acc 17.6136 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 322 | val loss 2.2745 val acc 15.3815 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 323 | val loss 2.3128 val acc 10.1055 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 324 | val loss 2.2626 val acc 14.0828 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 325 | val loss 2.2262 val acc 17.4716 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 326 | val loss 2.1633 val acc 18.4253 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 327 | val loss 2.0930 val acc 19.0138 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 328 | val loss 2.0470 val acc 19.5211 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 329 | val loss 2.0299 val acc 21.5097 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 330 | val loss 2.4978 val acc 15.2394 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 331 | val loss 5.0982 val acc 10.0446 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 332 | val loss 2.3002 val acc 11.0390 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 333 | val loss 2.2642 val acc 13.6161 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 334 | val loss 2.2391 val acc 15.1989 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 335 | val loss 2.2184 val acc 15.1786 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 336 | val loss 2.2070 val acc 16.2744 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 337 | val loss 2.2326 val acc 14.6916 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 338 | val loss 2.2277 val acc 15.9294 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 339 | val loss 2.2624 val acc 13.3117 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 340 | val loss 2.1941 val acc 16.2946 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 341 | val loss 2.2000 val acc 15.7062 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 342 | val loss 2.1868 val acc 16.3961 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 343 | val loss 2.1789 val acc 16.7208 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 344 | val loss 2.1724 val acc 16.9034 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 345 | val loss 2.1663 val acc 17.0049 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 346 | val loss 2.2677 val acc 18.1412 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 347 | val loss 2.3276 val acc 10.0649 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 348 | val loss 2.3055 val acc 10.9984 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 349 | val loss 2.2752 val acc 13.4537 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 350 | val loss 2.2337 val acc 14.8539 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 351 | val loss 2.1886 val acc 16.7614 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 352 | val loss 2.1759 val acc 17.3701 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 353 | val loss 2.1781 val acc 17.7963 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 354 | val loss 2.2530 val acc 12.6218 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 355 | val loss 2.1857 val acc 16.2946 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 356 | val loss 2.1474 val acc 19.0138 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 357 | val loss 2.1173 val acc 19.9472 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 358 | val loss 2.0989 val acc 20.0690 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 359 | val loss 2.0860 val acc 20.6372 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 360 | val loss 2.0756 val acc 21.0633 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 361 | val loss 2.0676 val acc 22.1997 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 362 | val loss 2.0994 val acc 20.1907 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 363 | val loss 2.1062 val acc 22.1997 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 364 | val loss 2.2300 val acc 15.4627 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 365 | val loss 2.1181 val acc 19.1356 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 366 | val loss 2.0779 val acc 20.9010 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 367 | val loss 2.0452 val acc 23.9042 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 368 | val loss 2.0290 val acc 24.6753 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 369 | val loss 2.0160 val acc 25.9537 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 370 | val loss 2.0437 val acc 23.3766 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 371 | val loss 2.2165 val acc 23.9854 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 372 | val loss 2.3299 val acc 11.3231 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 373 | val loss 2.2436 val acc 11.7289 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 374 | val loss 2.2464 val acc 15.4424 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 375 | val loss 2.2165 val acc 15.6047 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 376 | val loss 2.1954 val acc 16.8628 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 377 | val loss 2.1662 val acc 17.3701 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 378 | val loss 2.1646 val acc 17.5731 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 379 | val loss 2.1305 val acc 18.4050 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 380 | val loss 2.2160 val acc 14.2045 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 381 | val loss 2.1542 val acc 16.8425 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 382 | val loss 2.1067 val acc 21.1039 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 383 | val loss 2.1161 val acc 18.7906 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 384 | val loss 2.1062 val acc 23.1331 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 385 | val loss 2.2204 val acc 15.4627 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 386 | val loss 2.1657 val acc 18.1412 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 387 | val loss 2.1303 val acc 18.8920 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 388 | val loss 2.0708 val acc 20.9821 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 389 | val loss 2.0239 val acc 23.4781 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 390 | val loss 1.9899 val acc 24.9797 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 391 | val loss 1.9836 val acc 24.9594 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 392 | val loss 1.9929 val acc 24.3506 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 393 | val loss 1.9811 val acc 27.1713 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 394 | val loss 2.1338 val acc 18.9326 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 395 | val loss 2.0587 val acc 25.1623 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 396 | val loss 2.0946 val acc 18.9326 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 397 | val loss 1.9861 val acc 28.3888 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 398 | val loss 2.0793 val acc 21.6112 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 399 | val loss 1.9872 val acc 27.0089 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 400 | val loss 1.9463 val acc 26.5625 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 401 | val loss 2.0090 val acc 26.9683 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 402 | val loss 2.1366 val acc 17.3498 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 403 | val loss 2.0723 val acc 22.5244 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 404 | val loss 2.0960 val acc 20.4951 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 405 | val loss 2.1918 val acc 25.4261 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 406 | val loss 2.2797 val acc 15.0365 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 407 | val loss 2.2613 val acc 15.9903 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 408 | val loss 2.1958 val acc 17.3093 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 409 | val loss 2.1655 val acc 17.1672 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 410 | val loss 2.1481 val acc 18.5471 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 411 | val loss 2.0981 val acc 22.0170 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 412 | val loss 2.1460 val acc 18.4659 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 413 | val loss 2.0181 val acc 22.8896 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 414 | val loss 2.0018 val acc 25.7305 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 415 | val loss 2.0731 val acc 20.0284 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 416 | val loss 2.1048 val acc 23.2549 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 417 | val loss 2.2073 val acc 16.2135 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 418 | val loss 2.0245 val acc 26.4205 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 419 | val loss 1.9706 val acc 28.2062 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 420 | val loss 1.9457 val acc 26.9481 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 421 | val loss 1.9839 val acc 28.7946 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 422 | val loss 2.1345 val acc 18.1209 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 423 | val loss 2.0003 val acc 27.2524 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 424 | val loss 1.9609 val acc 26.3393 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 425 | val loss 1.9904 val acc 26.3393 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 426 | val loss 2.0635 val acc 24.8985 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 427 | val loss 2.0833 val acc 26.9481 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 428 | val loss 2.2507 val acc 17.8774 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 429 | val loss 2.2195 val acc 16.8425 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 430 | val loss 2.1706 val acc 22.7881 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 431 | val loss 2.1305 val acc 20.9213 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 432 | val loss 2.1890 val acc 17.5528 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 433 | val loss 2.0594 val acc 20.4140 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 434 | val loss 2.0527 val acc 21.4083 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 435 | val loss 2.1693 val acc 17.9383 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 436 | val loss 2.0213 val acc 24.4724 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 437 | val loss 1.9575 val acc 26.2987 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 438 | val loss 1.9248 val acc 28.2873 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 439 | val loss 1.9731 val acc 29.7890 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 440 | val loss 2.2226 val acc 18.9732 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 441 | val loss 2.0164 val acc 26.6437 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 442 | val loss 1.9420 val acc 30.9862 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 443 | val loss 1.9572 val acc 26.9683 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 444 | val loss 2.0708 val acc 23.9854 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 445 | val loss 2.0069 val acc 24.6956 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 446 | val loss 2.0414 val acc 29.0787 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 447 | val loss 2.3139 val acc 15.1786 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 448 | val loss 2.1506 val acc 20.2719 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 3 e 449 | val loss 2.1393 val acc 21.6721 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 450 | val loss 1.9932 val acc 26.0958 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 451 | val loss 1.9922 val acc 26.5016 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 452 | val loss 2.2103 val acc 23.5795 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 453 | val loss 2.2144 val acc 16.0714 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 454 | val loss 3.6941 val acc 14.8133 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 455 | val loss 2.1557 val acc 18.8109 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 456 | val loss 2.4429 val acc 12.2362 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 457 | val loss 2.3193 val acc 17.8977 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 458 | val loss 2.5830 val acc 10.4505 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 459 | val loss 2.3567 val acc 11.1404 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 460 | val loss 3.4671 val acc 15.6859 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 461 | val loss 2.4736 val acc 11.4245 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 462 | val loss 2.3082 val acc 13.5349 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 463 | val loss 2.9043 val acc 16.2338 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 464 | val loss 2.4231 val acc 11.6883 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 465 | val loss 2.4308 val acc 13.1291 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 466 | val loss 2.4599 val acc 11.2216 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 467 | val loss 2.5377 val acc 7.1226 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 468 | val loss 2.4123 val acc 9.6388 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 469 | val loss 2.3915 val acc 8.5633 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 470 | val loss 2.3921 val acc 9.9026 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 471 | val loss 2.3502 val acc 12.4594 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 472 | val loss 2.3550 val acc 10.4708 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 473 | val loss 2.3795 val acc 9.9026 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 474 | val loss 2.3679 val acc 9.9026 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 475 | val loss 2.3555 val acc 9.6591 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 476 | val loss 2.3435 val acc 10.9781 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 477 | val loss 2.3300 val acc 10.5519 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 478 | val loss 2.3143 val acc 10.3084 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 479 | val loss 2.2928 val acc 10.6128 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 480 | val loss 2.2636 val acc 14.4278 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 481 | val loss 2.2719 val acc 13.9002 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 482 | val loss 2.3297 val acc 9.9026 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 483 | val loss 2.3153 val acc 10.0446 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 484 | val loss 2.2892 val acc 10.5317 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 485 | val loss 2.2299 val acc 16.5990 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 486 | val loss 2.2220 val acc 19.6631 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 487 | val loss 2.2992 val acc 10.6331 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 488 | val loss 2.2321 val acc 14.4481 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 489 | val loss 2.1928 val acc 20.5357 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 490 | val loss 2.2611 val acc 13.1494 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 491 | val loss 2.1797 val acc 16.8628 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 492 | val loss 2.1314 val acc 18.8515 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 493 | val loss 2.1352 val acc 21.4894 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 494 | val loss 2.2853 val acc 11.9724 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 495 | val loss 2.1521 val acc 17.2890 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 496 | val loss 2.1313 val acc 21.0430 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 497 | val loss 2.2901 val acc 14.4278 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 498 | val loss 2.2282 val acc 18.6282 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 499 | val loss 2.1640 val acc 21.6518 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 500 | val loss 2.1125 val acc 22.2808 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 501 | val loss 2.1014 val acc 23.3766 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 502 | val loss 2.1187 val acc 19.6023 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 515 | val loss 2.1295 val acc 20.4140 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 516 | val loss 2.0997 val acc 18.3847 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 517 | val loss 2.0304 val acc 22.3823 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 518 | val loss 2.0659 val acc 21.3880 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 519 | val loss 2.0081 val acc 25.9334 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 520 | val loss 2.0941 val acc 18.8718 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 9 e 521 | val loss 1.9920 val acc 27.1916 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 522 | val loss 2.0060 val acc 27.5974 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 523 | val loss 2.1458 val acc 24.3506 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 524 | val loss 2.2425 val acc 15.5438 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 525 | val loss 2.3196 val acc 13.5349 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 526 | val loss 2.2571 val acc 13.7378 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 527 | val loss 2.1580 val acc 17.8571 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 528 | val loss 2.1196 val acc 18.1412 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 529 | val loss 2.0676 val acc 22.2403 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 530 | val loss 2.2298 val acc 22.7679 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 531 | val loss 2.3710 val acc 10.8360 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 532 | val loss 2.2506 val acc 13.5958 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 533 | val loss 2.1797 val acc 17.7557 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 534 | val loss 2.1144 val acc 20.3531 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 535 | val loss 2.0719 val acc 20.9416 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 536 | val loss 2.0810 val acc 21.4083 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 537 | val loss 2.0331 val acc 24.2086 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 538 | val loss 2.0444 val acc 24.1071 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 539 | val loss 2.0228 val acc 27.3742 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 540 | val loss 2.1404 val acc 21.4894 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 541 | val loss 2.0119 val acc 28.5308 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 542 | val loss 2.1050 val acc 23.1331 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 543 | val loss 2.0552 val acc 23.3563 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 544 | val loss 2.0457 val acc 22.4838 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 545 | val loss 1.9850 val acc 26.2784 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 8 e 546 | val loss 2.0041 val acc 27.0698 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 547 | val loss 2.2777 val acc 15.0568 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 548 | val loss 2.0887 val acc 21.3880 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 549 | val loss 2.0844 val acc 21.5909 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 550 | val loss 2.1108 val acc 18.4456 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 551 | val loss 1.9475 val acc 25.2638 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 552 | val loss 1.8864 val acc 27.7192 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 553 | val loss 1.9164 val acc 27.5162 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 554 | val loss 1.9448 val acc 28.7744 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 555 | val loss 2.6309 val acc 18.8109 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 556 | val loss 2.3734 val acc 13.0276 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 557 | val loss 2.2644 val acc 15.5844 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 558 | val loss 3.4068 val acc 10.8360 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 559 | val loss 2.5035 val acc 12.7029 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 560 | val loss 4.3044 val acc 9.0706 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 3 e 561 | val loss 2.8035 val acc 7.4675 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 7 e 562 | val loss 2.4723 val acc 9.6388 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 4 e 563 | val loss 2.3979 val acc 10.6534 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 564 | val loss 5.8308 val acc 9.8011 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 6 e 565 | val loss 189.7225 val acc 10.0446 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 566 | val loss 20.4436 val acc 9.9026 best val_acc 31.737013
# bulyan: at min-max n_at 10 n_mal_sel 5 e 567 | val loss 5177978.4838 val acc 9.9026 best val_acc 31.737013
# val loss 5177978.483766 too high

# %% [markdown]
# ## Code for our second AGR-agnostic attack called Min-Sum

# %%
'''
MIN-SUM attack
'''

def our_attack_score(all_updates, model_re, n_attackers, dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)  # unit vector, dir opp to good dir
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)
    
    lamda = torch.Tensor([10.0]).float().cuda()
    # print(lamda)
    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0
    
    distances = []
    for update in all_updates:
        distance = torch.norm((all_updates - update), dim=1) ** 2
        distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)
    
    scores = torch.sum(distances, dim=1)
    min_score = torch.min(scores)
    del distances

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        distance = torch.norm((all_updates - mal_update), dim=1) ** 2
        score = torch.sum(distance)
        
        if score <= min_score:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    # print(lamda_succ)
    mal_update = (model_re - lamda_succ * deviation)
    
    return mal_update

# %% [markdown]
# ## Execute Min-Sum attack on Bulyan

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='bulyan'
multi_k = False
candidates = []

at_type='min-sum'
dev_type ='std'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    candidates = []

    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_median(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-max':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_dist(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-sum':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_score(malicious_grads, agg_grads, n_attacker, dev_type)

            mal_updates = torch.stack([mal_update] * n_attacker)
            malicious_grads = torch.cat((mal_updates, user_grads), 0)

        if epoch_num==0: print('malicious_grads shape ', malicious_grads.shape)

        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break
            
        epoch_num+=1
# Out:
# malicious_grads shape  torch.Size([50, 2472266])
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 0 | val loss 2.3034 val acc 10.0244 best val_acc 10.024351
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 1 | val loss 2.3027 val acc 10.1055 best val_acc 10.105519
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 2 | val loss 2.3020 val acc 10.1664 best val_acc 10.166396
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 3 | val loss 2.3011 val acc 11.7898 best val_acc 11.789773
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 4 | val loss 2.3002 val acc 10.1664 best val_acc 11.789773
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 5 | val loss 2.2991 val acc 10.1664 best val_acc 11.789773
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 6 | val loss 2.2978 val acc 10.2679 best val_acc 11.789773
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 7 | val loss 2.2962 val acc 11.9521 best val_acc 11.952110
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 8 | val loss 2.2943 val acc 10.2476 best val_acc 11.952110
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 9 | val loss 2.2916 val acc 10.2679 best val_acc 11.952110
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 10 | val loss 2.2879 val acc 11.2825 best val_acc 11.952110
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 11 | val loss 2.2828 val acc 14.9351 best val_acc 14.935065
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 12 | val loss 2.2758 val acc 14.3872 best val_acc 14.935065
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 13 | val loss 2.2661 val acc 13.5552 best val_acc 14.935065
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 14 | val loss 2.2566 val acc 12.8856 best val_acc 14.935065
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 15 | val loss 2.2376 val acc 20.0284 best val_acc 20.028409
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 16 | val loss 2.2486 val acc 13.1494 best val_acc 20.028409
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 17 | val loss 2.4030 val acc 11.9927 best val_acc 20.028409
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 18 | val loss 2.2582 val acc 15.5844 best val_acc 20.028409
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 19 | val loss 2.2301 val acc 17.9180 best val_acc 20.028409
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 20 | val loss 2.2063 val acc 18.4253 best val_acc 20.028409
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 21 | val loss 2.1808 val acc 21.7127 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 22 | val loss 2.2013 val acc 18.8109 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 23 | val loss 2.3415 val acc 9.9432 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 24 | val loss 2.2987 val acc 10.5114 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 25 | val loss 2.2894 val acc 12.0739 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 26 | val loss 2.2703 val acc 15.3003 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 27 | val loss 2.2018 val acc 18.2224 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 28 | val loss 2.1936 val acc 19.2979 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 29 | val loss 2.3473 val acc 10.0041 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 30 | val loss 2.2760 val acc 12.8044 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 31 | val loss 2.2480 val acc 16.2338 best val_acc 21.712662
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 32 | val loss 2.1816 val acc 22.1185 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 33 | val loss 2.1102 val acc 21.7532 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 34 | val loss 2.1188 val acc 21.1242 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 35 | val loss 2.6492 val acc 12.4188 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 36 | val loss 3.0803 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 37 | val loss 2.3128 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 38 | val loss 2.3111 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 39 | val loss 2.3098 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 40 | val loss 2.3087 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 41 | val loss 2.3077 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 42 | val loss 2.3069 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 43 | val loss 2.3063 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 44 | val loss 2.3058 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 45 | val loss 2.3052 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 46 | val loss 2.3048 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 47 | val loss 2.3044 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 48 | val loss 2.3040 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 49 | val loss 2.3037 val acc 9.5576 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 50 | val loss 2.3033 val acc 9.5170 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 51 | val loss 2.3030 val acc 9.6997 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 52 | val loss 2.3027 val acc 9.7200 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 53 | val loss 2.3024 val acc 9.6997 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 54 | val loss 2.3021 val acc 10.2070 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 55 | val loss 2.3018 val acc 10.2070 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 56 | val loss 2.3014 val acc 10.2679 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 57 | val loss 2.3009 val acc 10.1664 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 58 | val loss 2.3005 val acc 11.7289 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 59 | val loss 2.2999 val acc 12.8247 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 60 | val loss 2.2993 val acc 12.1347 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 61 | val loss 2.2986 val acc 12.8856 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 62 | val loss 2.2978 val acc 10.9172 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 63 | val loss 2.2969 val acc 10.0041 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 64 | val loss 2.2957 val acc 11.1404 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 65 | val loss 2.2944 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 66 | val loss 2.2931 val acc 9.8417 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 67 | val loss 2.2916 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 68 | val loss 2.2893 val acc 10.5722 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 69 | val loss 2.2872 val acc 11.2622 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 70 | val loss 2.2850 val acc 11.9521 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 71 | val loss 2.2825 val acc 12.9464 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 72 | val loss 2.2789 val acc 14.5292 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 73 | val loss 2.2763 val acc 14.4075 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 74 | val loss 2.2718 val acc 14.8945 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 75 | val loss 2.2743 val acc 14.0422 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 76 | val loss 2.2864 val acc 13.2508 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 77 | val loss 2.2630 val acc 14.7321 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 78 | val loss 2.2568 val acc 15.7265 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 79 | val loss 2.2568 val acc 15.6656 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 80 | val loss 2.2789 val acc 13.4334 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 81 | val loss 2.2642 val acc 14.6104 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 82 | val loss 2.2994 val acc 11.6274 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 83 | val loss 2.2864 val acc 14.1843 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 84 | val loss 2.2662 val acc 16.2946 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 85 | val loss 2.2419 val acc 15.5844 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 86 | val loss 2.2235 val acc 20.0893 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 87 | val loss 2.2696 val acc 17.1469 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 88 | val loss 2.2983 val acc 14.1031 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 89 | val loss 2.2818 val acc 14.4683 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 90 | val loss 2.2712 val acc 13.3929 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 91 | val loss 2.2670 val acc 12.1550 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 92 | val loss 2.2606 val acc 14.3872 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 93 | val loss 2.2549 val acc 14.7930 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 94 | val loss 2.2486 val acc 15.3612 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 95 | val loss 2.2430 val acc 15.4830 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 96 | val loss 2.2358 val acc 15.5844 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 97 | val loss 2.2277 val acc 16.0511 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 98 | val loss 2.2213 val acc 16.2946 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 99 | val loss 2.2175 val acc 16.9237 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 100 | val loss 2.2126 val acc 16.3352 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 101 | val loss 2.2171 val acc 16.2338 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 102 | val loss 2.2200 val acc 15.8888 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 103 | val loss 2.2769 val acc 14.6104 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 104 | val loss 2.2129 val acc 16.0917 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 105 | val loss 2.1985 val acc 15.8888 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 106 | val loss 2.2373 val acc 14.0625 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 107 | val loss 2.1934 val acc 17.1672 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 108 | val loss 2.2133 val acc 16.0106 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 109 | val loss 2.2276 val acc 16.3352 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 110 | val loss 2.3538 val acc 10.1664 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 111 | val loss 2.3060 val acc 11.7898 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 112 | val loss 2.2670 val acc 13.5146 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 113 | val loss 2.2193 val acc 15.5032 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 114 | val loss 2.2062 val acc 16.6396 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 115 | val loss 2.2265 val acc 15.4221 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 116 | val loss 2.1729 val acc 16.6396 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 117 | val loss 2.1632 val acc 18.0195 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 118 | val loss 2.1439 val acc 19.3588 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 119 | val loss 2.1534 val acc 16.2946 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 120 | val loss 2.3106 val acc 17.8166 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 121 | val loss 4.2602 val acc 9.9026 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 122 | val loss 2.3814 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 123 | val loss 2.3608 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 124 | val loss 2.3466 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 125 | val loss 2.3368 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 126 | val loss 2.3288 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 127 | val loss 2.3226 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 128 | val loss 2.3173 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 129 | val loss 2.3129 val acc 9.8417 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 130 | val loss 2.3085 val acc 10.1664 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 131 | val loss 2.3046 val acc 11.2013 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 132 | val loss 2.3010 val acc 12.2768 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 133 | val loss 2.2976 val acc 12.8247 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 134 | val loss 2.2934 val acc 12.9464 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 135 | val loss 2.2909 val acc 13.2305 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 136 | val loss 2.2862 val acc 13.3523 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 137 | val loss 2.2837 val acc 13.6567 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 138 | val loss 2.2788 val acc 13.3117 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 139 | val loss 2.2784 val acc 13.3117 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 140 | val loss 2.2720 val acc 15.6047 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 141 | val loss 2.2751 val acc 15.2394 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 142 | val loss 2.2763 val acc 13.2914 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 143 | val loss 2.2605 val acc 15.6453 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 144 | val loss 2.2494 val acc 14.6916 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 145 | val loss 2.2476 val acc 14.5292 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 146 | val loss 2.2492 val acc 16.2135 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 147 | val loss 2.2447 val acc 13.5958 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 148 | val loss 2.2484 val acc 16.3758 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 149 | val loss 2.2169 val acc 15.7670 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 150 | val loss 2.2182 val acc 16.6802 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 151 | val loss 2.2068 val acc 15.4830 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 152 | val loss 2.2205 val acc 16.6599 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 153 | val loss 2.1902 val acc 16.5584 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 154 | val loss 2.1974 val acc 16.3758 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 155 | val loss 2.1901 val acc 15.8076 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 156 | val loss 2.2036 val acc 15.3815 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 157 | val loss 2.1860 val acc 16.5381 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 158 | val loss 2.1935 val acc 16.1323 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 159 | val loss 2.2035 val acc 16.7411 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 160 | val loss 2.2361 val acc 13.8596 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 161 | val loss 2.1934 val acc 16.1729 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 162 | val loss 2.1832 val acc 17.8369 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 163 | val loss 2.1847 val acc 16.0511 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 164 | val loss 2.2270 val acc 14.8945 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 165 | val loss 2.3142 val acc 14.0219 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 166 | val loss 2.3125 val acc 10.0244 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 167 | val loss 2.2592 val acc 18.4862 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 168 | val loss 2.2640 val acc 13.1696 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 169 | val loss 2.2276 val acc 15.6859 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 170 | val loss 2.2164 val acc 16.9237 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 171 | val loss 2.2103 val acc 16.0714 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 172 | val loss 2.2472 val acc 17.8369 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 173 | val loss 2.3033 val acc 13.2914 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 174 | val loss 2.2909 val acc 13.2102 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 175 | val loss 2.2808 val acc 13.2914 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 176 | val loss 2.2119 val acc 16.6193 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 177 | val loss 2.1876 val acc 18.0601 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 178 | val loss 2.1727 val acc 19.2573 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 179 | val loss 2.1626 val acc 20.4748 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 180 | val loss 2.1522 val acc 20.5154 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 181 | val loss 2.1991 val acc 19.0747 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 182 | val loss 2.2591 val acc 14.1234 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 183 | val loss 2.2004 val acc 17.8774 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 184 | val loss 2.1879 val acc 16.7005 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 185 | val loss 2.1652 val acc 17.8166 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 186 | val loss 2.1793 val acc 17.2890 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 187 | val loss 2.2008 val acc 18.1818 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 188 | val loss 2.3125 val acc 11.3636 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 189 | val loss 2.2669 val acc 15.9294 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 190 | val loss 2.2785 val acc 12.2768 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 191 | val loss 2.1978 val acc 15.7468 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 192 | val loss 2.1710 val acc 17.9789 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 193 | val loss 2.1710 val acc 18.8515 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 194 | val loss 2.1832 val acc 19.0544 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 195 | val loss 2.2796 val acc 13.2102 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 196 | val loss 2.1936 val acc 18.3847 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 197 | val loss 2.1305 val acc 21.0227 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 198 | val loss 2.1382 val acc 21.5706 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 199 | val loss 2.2950 val acc 17.9586 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 200 | val loss 2.3712 val acc 10.0446 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 201 | val loss 2.3585 val acc 8.5633 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 202 | val loss 2.3371 val acc 10.6331 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 203 | val loss 2.3321 val acc 10.4302 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 204 | val loss 2.3139 val acc 10.4505 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 205 | val loss 2.2737 val acc 12.6015 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 206 | val loss 2.2765 val acc 13.9813 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 207 | val loss 2.2584 val acc 14.8742 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 208 | val loss 2.2461 val acc 16.7411 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 209 | val loss 2.2835 val acc 11.4651 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 210 | val loss 2.2594 val acc 13.6769 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 211 | val loss 2.1986 val acc 15.5438 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 212 | val loss 2.1905 val acc 18.0195 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 213 | val loss 2.1888 val acc 18.2021 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 214 | val loss 2.2472 val acc 17.1063 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 215 | val loss 2.3389 val acc 10.3693 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 216 | val loss 2.3008 val acc 12.8450 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 217 | val loss 2.2630 val acc 15.2597 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 218 | val loss 2.2115 val acc 17.4919 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 219 | val loss 2.3437 val acc 14.9148 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 220 | val loss 2.3426 val acc 10.1664 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 221 | val loss 2.3610 val acc 10.5317 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 222 | val loss 2.3313 val acc 9.9635 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 223 | val loss 2.2686 val acc 13.9205 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 224 | val loss 2.2862 val acc 13.3929 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 225 | val loss 2.2769 val acc 13.2305 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 226 | val loss 2.2301 val acc 14.5698 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 227 | val loss 2.2156 val acc 15.6250 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 228 | val loss 2.2212 val acc 16.3555 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 229 | val loss 2.2040 val acc 16.9643 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 230 | val loss 2.2361 val acc 14.0219 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 231 | val loss 2.1903 val acc 16.8425 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 232 | val loss 2.2280 val acc 16.1932 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 233 | val loss 2.1994 val acc 15.9700 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 234 | val loss 2.2171 val acc 15.7873 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 235 | val loss 2.1987 val acc 17.9383 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 236 | val loss 2.2541 val acc 14.5495 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 237 | val loss 2.2128 val acc 17.3093 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 238 | val loss 2.1752 val acc 17.9586 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 239 | val loss 2.3013 val acc 18.4050 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 240 | val loss 2.3659 val acc 10.1055 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 241 | val loss 2.3756 val acc 8.3401 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 242 | val loss 2.3168 val acc 12.0130 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 243 | val loss 2.2945 val acc 12.3782 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 244 | val loss 2.2591 val acc 13.1088 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 245 | val loss 2.2186 val acc 17.5528 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 246 | val loss 2.3047 val acc 12.4188 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 247 | val loss 2.2576 val acc 13.7581 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 248 | val loss 2.2325 val acc 16.1323 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 249 | val loss 2.2601 val acc 12.1956 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 250 | val loss 2.1952 val acc 16.4367 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 251 | val loss 2.2108 val acc 14.8742 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 252 | val loss 2.1838 val acc 17.6136 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 253 | val loss 2.1790 val acc 16.7411 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 254 | val loss 2.2652 val acc 14.3872 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 255 | val loss 2.1616 val acc 16.4570 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 256 | val loss 2.1568 val acc 21.5706 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 257 | val loss 2.1914 val acc 16.6599 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 258 | val loss 2.2490 val acc 18.7906 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 259 | val loss 2.3751 val acc 10.1867 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 260 | val loss 2.3469 val acc 10.6534 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 261 | val loss 2.3371 val acc 10.7752 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 262 | val loss 2.3115 val acc 10.9375 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 263 | val loss 2.2871 val acc 13.0276 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 264 | val loss 2.3104 val acc 11.0795 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 265 | val loss 2.2372 val acc 14.5089 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 266 | val loss 2.1935 val acc 17.7354 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 267 | val loss 2.2391 val acc 15.4627 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 268 | val loss 2.1856 val acc 16.7208 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 269 | val loss 2.2015 val acc 17.7963 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 270 | val loss 2.1831 val acc 17.6136 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 271 | val loss 2.2362 val acc 18.7906 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 272 | val loss 2.2081 val acc 14.9756 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 273 | val loss 2.2219 val acc 17.2078 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 274 | val loss 2.1609 val acc 20.8807 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 275 | val loss 2.1957 val acc 15.8279 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 276 | val loss 2.3329 val acc 19.3588 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 277 | val loss 3.1729 val acc 10.1258 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 278 | val loss 2.6875 val acc 7.2443 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 279 | val loss 3.4611 val acc 9.7403 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 280 | val loss 2.5914 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 281 | val loss 2.4514 val acc 12.3377 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 282 | val loss 2.4249 val acc 10.5722 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 283 | val loss 2.3493 val acc 13.1696 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 284 | val loss 2.2932 val acc 14.1843 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 285 | val loss 2.2702 val acc 14.8539 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 286 | val loss 2.2613 val acc 14.1640 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 287 | val loss 2.2500 val acc 16.1120 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 288 | val loss 2.2668 val acc 14.1843 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 289 | val loss 2.2369 val acc 16.2744 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 290 | val loss 2.2517 val acc 14.2248 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 291 | val loss 2.2162 val acc 16.3961 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 292 | val loss 2.2071 val acc 14.8336 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 293 | val loss 2.3992 val acc 17.2078 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 294 | val loss 2.3638 val acc 11.5666 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 295 | val loss 2.3547 val acc 10.5722 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 296 | val loss 2.3841 val acc 6.9602 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 297 | val loss 2.4278 val acc 9.6388 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 298 | val loss 2.3398 val acc 9.9026 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 299 | val loss 2.3304 val acc 10.0244 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 300 | val loss 2.3316 val acc 8.3604 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 301 | val loss 2.3199 val acc 9.9229 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 302 | val loss 2.3607 val acc 7.2240 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 303 | val loss 2.2962 val acc 11.5869 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 304 | val loss 2.2767 val acc 11.8304 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 305 | val loss 2.2624 val acc 13.8190 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 306 | val loss 2.2612 val acc 13.9813 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 307 | val loss 2.2606 val acc 13.6567 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 308 | val loss 2.2685 val acc 14.4278 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 309 | val loss 2.2731 val acc 12.1347 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 310 | val loss 2.2539 val acc 13.9610 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 311 | val loss 2.2543 val acc 14.1031 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 312 | val loss 2.2503 val acc 14.1437 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 313 | val loss 2.2475 val acc 13.9407 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 314 | val loss 2.4380 val acc 12.2768 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 315 | val loss 2.2671 val acc 13.2508 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 316 | val loss 2.2608 val acc 14.7727 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 317 | val loss 2.2897 val acc 10.8157 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 318 | val loss 2.2516 val acc 13.5146 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 319 | val loss 2.2350 val acc 14.9351 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 320 | val loss 2.2433 val acc 14.4075 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 321 | val loss 2.2389 val acc 15.1583 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 322 | val loss 2.2492 val acc 13.6567 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 323 | val loss 2.2259 val acc 14.8539 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 324 | val loss 2.2413 val acc 12.5406 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 325 | val loss 2.2332 val acc 14.6104 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 326 | val loss 2.2634 val acc 15.6047 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 327 | val loss 2.2484 val acc 11.3231 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 328 | val loss 2.2197 val acc 16.1729 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 329 | val loss 2.2200 val acc 16.2541 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 330 | val loss 2.2157 val acc 15.4627 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 331 | val loss 2.2115 val acc 15.6250 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 332 | val loss 2.2320 val acc 16.6193 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 333 | val loss 2.2466 val acc 16.1729 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 334 | val loss 2.2072 val acc 16.2338 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 335 | val loss 2.9981 val acc 11.7289 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 336 | val loss 2.6753 val acc 7.0820 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 337 | val loss 3.7049 val acc 6.9602 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 338 | val loss 26.1331 val acc 9.9026 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 339 | val loss 4.1789 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 340 | val loss 4.1117 val acc 9.8011 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 341 | val loss 3.0173 val acc 7.4067 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 342 | val loss 2.8655 val acc 7.1834 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 343 | val loss 119.1017 val acc 9.7606 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 344 | val loss 42.9442 val acc 10.4099 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 10 e 345 | val loss 2.4049 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 346 | val loss 2.3391 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 4 e 347 | val loss 2.3311 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 348 | val loss 2.3269 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 349 | val loss 2.3236 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 350 | val loss 2.3210 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 4 e 351 | val loss 2.3190 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 352 | val loss 2.3171 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 353 | val loss 2.3154 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 354 | val loss 2.3140 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 355 | val loss 2.3129 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 356 | val loss 2.3118 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 357 | val loss 2.3108 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 358 | val loss 2.3099 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 359 | val loss 2.3093 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 360 | val loss 2.3087 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 361 | val loss 2.3081 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 362 | val loss 2.3076 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 363 | val loss 2.3072 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 364 | val loss 2.3068 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 365 | val loss 2.3064 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 366 | val loss 2.3061 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 367 | val loss 2.3059 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 368 | val loss 2.3056 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 369 | val loss 2.3054 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 370 | val loss 2.3052 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 371 | val loss 2.3050 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 372 | val loss 2.3048 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 373 | val loss 2.3047 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 374 | val loss 2.3045 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 375 | val loss 2.3045 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 376 | val loss 2.3043 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 377 | val loss 2.3042 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 378 | val loss 2.3041 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 379 | val loss 2.3041 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 380 | val loss 2.3040 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 381 | val loss 2.3039 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 382 | val loss 2.3039 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 383 | val loss 2.3038 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 384 | val loss 2.3038 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 385 | val loss 2.3037 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 386 | val loss 2.3037 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 387 | val loss 2.3037 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 388 | val loss 2.3036 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 389 | val loss 2.3036 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 390 | val loss 2.3036 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 391 | val loss 2.3036 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 392 | val loss 2.3035 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 393 | val loss 2.3035 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 394 | val loss 2.3035 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 395 | val loss 2.3035 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 396 | val loss 2.3035 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 397 | val loss 2.3035 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 398 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 399 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 400 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 401 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 402 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 403 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 404 | val loss 2.3034 val acc 9.9635 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 405 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 406 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 407 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 408 | val loss 2.3034 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 409 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 410 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 411 | val loss 2.3034 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 412 | val loss 2.3034 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 413 | val loss 2.3034 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 414 | val loss 2.3033 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 415 | val loss 2.3033 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 416 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 417 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 418 | val loss 2.3033 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 419 | val loss 2.3033 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 420 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 421 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 422 | val loss 2.3033 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 423 | val loss 2.3033 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 424 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 425 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 426 | val loss 2.3033 val acc 9.9432 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 427 | val loss 2.3033 val acc 9.9635 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 428 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 429 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 430 | val loss 2.3033 val acc 9.6388 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 431 | val loss 2.3033 val acc 9.6591 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 432 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 433 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 434 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 435 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 436 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 437 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 438 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 439 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 440 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 441 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 442 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 443 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 444 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 445 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 446 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 447 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 448 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 449 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 450 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 451 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 452 | val loss 2.3033 val acc 9.9838 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 453 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 454 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 455 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 456 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 457 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 458 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 459 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 460 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 461 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 462 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 463 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 464 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 465 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 466 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 467 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 468 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# ...
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1045 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1046 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1047 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1048 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1049 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1050 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1051 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1052 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1053 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1054 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1055 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1056 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1057 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1058 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1059 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1060 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1061 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1062 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1063 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1064 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1065 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1066 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1067 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1068 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1069 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1070 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1071 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1072 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1073 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1074 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1075 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1076 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1077 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1078 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1079 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1080 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1081 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1082 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1083 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1084 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1085 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1086 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1087 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1088 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1089 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1090 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1091 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1092 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1093 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1094 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1095 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1096 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1097 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1098 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1099 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1100 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1101 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1102 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1103 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1104 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1105 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1106 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1107 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1108 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1109 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1110 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1111 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1112 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1113 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1114 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1115 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1116 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1117 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1118 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1119 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1120 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1121 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1122 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1123 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1124 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1125 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1126 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1127 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1128 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1129 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1130 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1131 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1132 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1133 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1134 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1135 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1136 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1137 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1138 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1139 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1140 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1141 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1142 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1143 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1144 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1145 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1146 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1147 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1148 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1149 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1150 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1151 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1152 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1153 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1154 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1155 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1156 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1157 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1158 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1159 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1160 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1161 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1162 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1163 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1164 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1165 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1166 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1167 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1168 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1169 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1170 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1171 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1172 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1173 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1174 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1175 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1176 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1177 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1178 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1179 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1180 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1181 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1182 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1183 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1184 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1185 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1186 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1187 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1188 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1189 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1190 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1191 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1192 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1193 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1194 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1195 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1196 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1197 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1198 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 3 e 1199 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
# bulyan: at min-sum n_at 10 n_mal_sel 2 e 1200 | val loss 2.3033 val acc 9.6794 best val_acc 22.118506
