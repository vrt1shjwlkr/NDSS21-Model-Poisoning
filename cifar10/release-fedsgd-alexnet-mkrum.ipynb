# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp

sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from cifar10_normal_train import *
from cifar10_util import *

# %%
from adam import Adam
from sgd import SGD
from gradient_aggregation_rules import *
from poisoning_attacks import *

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import torchvision.transforms as transforms
import torchvision.datasets as datasets
data_loc='/mnt/nfs/work1/amir/vshejwalkar/cifar10_data/'
# load the train dataset

train_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

cifar10_train = datasets.CIFAR10(root=data_loc, train=True, download=True, transform=train_transform)

cifar10_test = datasets.CIFAR10(root=data_loc, train=False, download=True, transform=train_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
X=[]
Y=[]
for i in range(len(cifar10_train)):
    X.append(cifar10_train[i][0].numpy())
    Y.append(cifar10_train[i][1])

for i in range(len(cifar10_test)):
    X.append(cifar10_test[i][0].numpy())
    Y.append(cifar10_test[i][1])

X=np.array(X)
Y=np.array(Y)

print('total data len: ',len(X))

if not os.path.isfile('./cifar10_shuffle.pkl'):
    all_indices = np.arange(len(X))
    np.random.shuffle(all_indices)
    pickle.dump(all_indices,open('./cifar10_shuffle.pkl','wb'))
else:
    all_indices=pickle.load(open('./cifar10_shuffle.pkl','rb'))

X=X[all_indices]
Y=Y[all_indices]
# Out:
# total data len:  60000

# %%
# data loading

nusers=50
user_tr_len=1000

total_tr_len=user_tr_len*nusers
val_len=5000
te_len=5000

print('total data len: ',len(X))

if not os.path.isfile('./cifar10_shuffle.pkl'):
    all_indices = np.arange(len(X))
    np.random.shuffle(all_indices)
    pickle.dump(all_indices,open('./cifar10_shuffle.pkl','wb'))
else:
    all_indices=pickle.load(open('./cifar10_shuffle.pkl','rb'))

total_tr_data=X[:total_tr_len]
total_tr_label=Y[:total_tr_len]

val_data=X[total_tr_len:(total_tr_len+val_len)]
val_label=Y[total_tr_len:(total_tr_len+val_len)]

te_data=X[(total_tr_len+val_len):(total_tr_len+val_len+te_len)]
te_label=Y[(total_tr_len+val_len):(total_tr_len+val_len+te_len)]

total_tr_data_tensor=torch.from_numpy(total_tr_data).type(torch.FloatTensor)
total_tr_label_tensor=torch.from_numpy(total_tr_label).type(torch.LongTensor)

val_data_tensor=torch.from_numpy(val_data).type(torch.FloatTensor)
val_label_tensor=torch.from_numpy(val_label).type(torch.LongTensor)

te_data_tensor=torch.from_numpy(te_data).type(torch.FloatTensor)
te_label_tensor=torch.from_numpy(te_label).type(torch.LongTensor)

print('total tr len %d | val len %d | test len %d'%(len(total_tr_data_tensor),len(val_data_tensor),len(te_data_tensor)))

#==============================================================================================================

user_tr_data_tensors=[]
user_tr_label_tensors=[]

for i in range(nusers):
    
    user_tr_data_tensor=torch.from_numpy(total_tr_data[user_tr_len*i:user_tr_len*(i+1)]).type(torch.FloatTensor)
    user_tr_label_tensor=torch.from_numpy(total_tr_label[user_tr_len*i:user_tr_len*(i+1)]).type(torch.LongTensor)

    user_tr_data_tensors.append(user_tr_data_tensor)
    user_tr_label_tensors.append(user_tr_label_tensor)
    print('user %d tr len %d'%(i,len(user_tr_data_tensor)))
# Out:
# total data len:  60000
# total tr len 50000 | val len 5000 | test len 5000
# user 0 tr len 1000
# user 1 tr len 1000
# user 2 tr len 1000
# user 3 tr len 1000
# user 4 tr len 1000
# user 5 tr len 1000
# user 6 tr len 1000
# user 7 tr len 1000
# user 8 tr len 1000
# user 9 tr len 1000
# user 10 tr len 1000
# user 11 tr len 1000
# user 12 tr len 1000
# user 13 tr len 1000
# user 14 tr len 1000
# user 15 tr len 1000
# user 16 tr len 1000
# user 17 tr len 1000
# user 18 tr len 1000
# user 19 tr len 1000
# user 20 tr len 1000
# user 21 tr len 1000
# user 22 tr len 1000
# user 23 tr len 1000
# user 24 tr len 1000
# user 25 tr len 1000
# user 26 tr len 1000
# user 27 tr len 1000
# user 28 tr len 1000
# user 29 tr len 1000
# user 30 tr len 1000
# user 31 tr len 1000
# user 32 tr len 1000
# user 33 tr len 1000
# user 34 tr len 1000
# user 35 tr len 1000
# user 36 tr len 1000
# user 37 tr len 1000
# user 38 tr len 1000
# user 39 tr len 1000
# user 40 tr len 1000
# user 41 tr len 1000
# user 42 tr len 1000
# user 43 tr len 1000
# user 44 tr len 1000
# user 45 tr len 1000
# user 46 tr len 1000
# user 47 tr len 1000
# user 48 tr len 1000
# user 49 tr len 1000

# %%
def compute_lambda_fang(all_updates, model_re, n_attackers):

    distances = []
    n_benign, d = all_updates.shape
    for update in all_updates:
        distance = torch.norm((all_updates - update), dim=1)
        distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)

    distances[distances == 0] = 10000
    distances = torch.sort(distances, dim=1)[0]
    scores = torch.sum(distances[:, :n_benign - 2 - n_attackers], dim=1)
    min_score = torch.min(scores)
    term_1 = min_score / ((n_benign - n_attackers - 1) * torch.sqrt(torch.Tensor([d]))[0])
    max_wre_dist = torch.max(torch.norm((all_updates - model_re), dim=1)) / (torch.sqrt(torch.Tensor([d]))[0])

    return (term_1 + max_wre_dist)


def get_malicious_updates_fang(all_updates, model_re, deviation, n_attackers):

    lamda = compute_lambda_fang(all_updates, model_re, n_attackers)
    threshold = 1e-5

    mal_updates = []
    while lamda > threshold:
        mal_update = (- lamda * deviation)

        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

        agg_grads, krum_candidate = multi_krum(mal_updates, n_attackers, multi_k=False)
        
        if krum_candidate < n_attackers:
            return mal_updates
        
        lamda *= 0.5

    if not len(mal_updates):
        print(lamda, threshold)
        mal_update = (model_re - lamda * deviation)
        
        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

    return mal_updates

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='mkrum'
multi_k = False
candidates = []

at_type='fang'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    fed_file='%s_checkpoint_%s_%d.pth.tar'%(arch, at_type, n_attacker)
    fed_best_file='%s_best_%s_%d.pth.tar'%(arch, at_type, n_attacker)
    
    if resume:
        fed_checkpoint = chkpt+'/'+fed_file
        assert os.path.isfile(fed_checkpoint), 'Error: no user checkpoint at %s'%(fed_checkpoint)
        checkpoint = torch.load(fed_checkpoint, map_location='cuda:%d'%torch.cuda.current_device())
        fed_model.load_state_dict(checkpoint['state_dict'])
        optimizer_fed.load_state_dict(checkpoint['optimizer'])
        resume = 0
        best_global_acc=checkpoint['best_acc']
        best_global_te_acc=checkpoint['best_te_acc']
        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        epoch_num += checkpoint['epoch']
        print('resuming from epoch %d | val acc %.4f | best acc %.3f | best te acc %.3f'%(epoch_num, val_acc, best_global_acc, best_global_te_acc))

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'paf':
                malicious_grads=get_malicious_predictions_poison_all_far_sign(malicious_grads,nusers,n_attacker)
            elif at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our':
                agg_grads = torch.mean(malicious_grads, 0)
                malicious_grads = our_attack_krum(malicious_grads, agg_grads, n_attacker, compression, q_level, norm)

        if not epoch_num:
            print(malicious_grads.shape)
            
        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':

            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0:
                print('multi krum is ', multi_k)

            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

#             if n_attacker:
#                 if epoch_num > 0 and (epoch_num%50==0 or epoch_num == (nepochs-1)):
#                     try:
#                         print('number of malicious grads chosen are ', np.array(candidates).reshape(5, 10))
#                     except:
#                         print('number of malicious grads chosen are ', np.array(candidates))
#                     candidates = []
#                     candidates.append(np.sum(krum_candidate < n_attacker))
#                 else:
#                     candidates.append(np.sum(krum_candidate < n_attacker))

        elif aggregation=='bulyan':
            agg_grads,bulyan_candidate=bulyan(malicious_grads, n_attacker)

            print(np.sum(bulyan_candidate<n_attacker))

            if n_attacker:
                if epoch_num > 0 and (epoch_num%50==0 or epoch_num == (nepochs-1)):
                    try:
                        print('number of malicious grads chosen are ', np.array(candidates).reshape(5, 10))
                    except:
                        print('number of malicious grads chosen are ', np.array(candidates))
                    candidates = []
                    candidates.append(np.sum(bulyan_candidate<n_attacker))
                else:
                    candidates.append(np.sum(bulyan_candidate<n_attacker))

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d val loss %.4f val acc %.4f best val_acc %f te_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc,best_global_te_acc))

        epoch_num+=1
# Out:
# torch.Size([50, 2472266])
# multi krum is  True
# mkrum: at fang n_at 10 n_mal_sel 9 e 0 val loss 2.3026 val acc 9.9838 best val_acc 9.983766 te_acc 9.618506
# mkrum: at fang n_at 10 n_mal_sel 10 e 1 val loss 2.3024 val acc 10.3084 best val_acc 10.308442 te_acc 9.882305
# mkrum: at fang n_at 10 n_mal_sel 10 e 2 val loss 2.3022 val acc 10.7752 best val_acc 10.775162 te_acc 10.450487
# mkrum: at fang n_at 10 n_mal_sel 10 e 3 val loss 2.3019 val acc 10.5519 best val_acc 10.775162 te_acc 10.450487
# mkrum: at fang n_at 10 n_mal_sel 9 e 4 val loss 2.3017 val acc 11.7695 best val_acc 11.769481 te_acc 11.444805
# mkrum: at fang n_at 10 n_mal_sel 10 e 5 val loss 2.3015 val acc 12.4594 best val_acc 12.459416 te_acc 12.134740
# mkrum: at fang n_at 10 n_mal_sel 10 e 6 val loss 2.3013 val acc 13.2102 best val_acc 13.210227 te_acc 13.311688
# mkrum: at fang n_at 10 n_mal_sel 10 e 7 val loss 2.3010 val acc 13.1088 best val_acc 13.210227 te_acc 13.311688
# mkrum: at fang n_at 10 n_mal_sel 8 e 8 val loss 2.3007 val acc 14.2451 best val_acc 14.245130 te_acc 14.569805
# mkrum: at fang n_at 10 n_mal_sel 10 e 9 val loss 2.3004 val acc 12.3377 best val_acc 14.245130 te_acc 14.569805
# mkrum: at fang n_at 10 n_mal_sel 10 e 10 val loss 2.3001 val acc 14.3466 best val_acc 14.346591 te_acc 14.285714
# mkrum: at fang n_at 10 n_mal_sel 10 e 11 val loss 2.2998 val acc 14.4886 best val_acc 14.488636 te_acc 14.874188
# mkrum: at fang n_at 10 n_mal_sel 10 e 12 val loss 2.2994 val acc 14.7321 best val_acc 14.732143 te_acc 15.097403
# mkrum: at fang n_at 10 n_mal_sel 10 e 13 val loss 2.2990 val acc 13.0276 best val_acc 14.732143 te_acc 15.097403
# mkrum: at fang n_at 10 n_mal_sel 10 e 14 val loss 2.2985 val acc 13.9205 best val_acc 14.732143 te_acc 15.097403
# mkrum: at fang n_at 10 n_mal_sel 10 e 15 val loss 2.2979 val acc 15.3815 best val_acc 15.381494 te_acc 15.807630
# mkrum: at fang n_at 10 n_mal_sel 10 e 16 val loss 2.2973 val acc 14.4683 best val_acc 15.381494 te_acc 15.807630
# mkrum: at fang n_at 10 n_mal_sel 10 e 17 val loss 2.2967 val acc 14.0828 best val_acc 15.381494 te_acc 15.807630
# mkrum: at fang n_at 10 n_mal_sel 10 e 18 val loss 2.2959 val acc 14.9351 best val_acc 15.381494 te_acc 15.807630
# mkrum: at fang n_at 10 n_mal_sel 10 e 19 val loss 2.2950 val acc 16.7411 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 20 val loss 2.2939 val acc 15.3409 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 21 val loss 2.2927 val acc 15.9091 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 22 val loss 2.2911 val acc 16.7208 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 10 e 23 val loss 2.2893 val acc 15.8076 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 24 val loss 2.2869 val acc 13.9610 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 25 val loss 2.2840 val acc 14.0625 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 8 e 26 val loss 2.2802 val acc 14.6713 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 27 val loss 2.2758 val acc 13.7987 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 28 val loss 2.2707 val acc 12.6623 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 29 val loss 2.2647 val acc 13.0479 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 30 val loss 2.2581 val acc 14.1640 best val_acc 16.741071 te_acc 16.984578
# mkrum: at fang n_at 10 n_mal_sel 9 e 31 val loss 2.2509 val acc 16.7614 best val_acc 16.761364 te_acc 17.431006
# mkrum: at fang n_at 10 n_mal_sel 10 e 32 val loss 2.2443 val acc 15.8685 best val_acc 16.761364 te_acc 17.431006
# mkrum: at fang n_at 10 n_mal_sel 10 e 33 val loss 2.2360 val acc 17.9789 best val_acc 17.978896 te_acc 18.222403
# mkrum: at fang n_at 10 n_mal_sel 10 e 34 val loss 2.2291 val acc 20.2922 best val_acc 20.292208 te_acc 20.170455
# mkrum: at fang n_at 10 n_mal_sel 10 e 35 val loss 2.2198 val acc 20.7589 best val_acc 20.758929 te_acc 20.616883
# mkrum: at fang n_at 10 n_mal_sel 10 e 36 val loss 2.2139 val acc 18.3847 best val_acc 20.758929 te_acc 20.616883
# mkrum: at fang n_at 10 n_mal_sel 10 e 37 val loss 2.2018 val acc 22.1794 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 10 e 38 val loss 2.2092 val acc 18.9123 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 5 e 39 val loss 2.2866 val acc 12.5609 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 2 e 40 val loss 2.3299 val acc 13.8393 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 2 e 41 val loss 2.3020 val acc 10.8969 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 7 e 42 val loss 2.2998 val acc 10.9172 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 7 e 43 val loss 2.2971 val acc 11.0593 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 7 e 44 val loss 2.2938 val acc 11.0593 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 6 e 45 val loss 2.2892 val acc 11.7289 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 6 e 46 val loss 2.2830 val acc 13.0682 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 6 e 47 val loss 2.2741 val acc 13.7784 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 5 e 48 val loss 2.2601 val acc 14.8539 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 5 e 49 val loss 2.2388 val acc 16.9440 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 5 e 50 val loss 2.2081 val acc 18.4456 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 6 e 51 val loss 2.1694 val acc 21.0836 best val_acc 22.179383 te_acc 22.504058
# mkrum: at fang n_at 10 n_mal_sel 7 e 52 val loss 2.1325 val acc 22.5852 best val_acc 22.585227 te_acc 22.970779
# mkrum: at fang n_at 10 n_mal_sel 8 e 53 val loss 2.1007 val acc 23.7013 best val_acc 23.701299 te_acc 23.193994
# mkrum: at fang n_at 10 n_mal_sel 8 e 54 val loss 2.0748 val acc 23.7825 best val_acc 23.782468 te_acc 23.173701
# mkrum: at fang n_at 10 n_mal_sel 10 e 55 val loss 2.0542 val acc 24.6753 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 56 val loss 2.1301 val acc 23.4781 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 3 e 57 val loss 2.9794 val acc 9.9432 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 0 e 58 val loss 2.2984 val acc 10.8360 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 8 e 59 val loss 2.2965 val acc 10.9984 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 7 e 60 val loss 2.2939 val acc 11.5260 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 6 e 61 val loss 2.2899 val acc 11.9927 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 6 e 62 val loss 2.2836 val acc 13.4537 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 5 e 63 val loss 2.2722 val acc 15.4627 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 5 e 64 val loss 2.2513 val acc 16.4570 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 4 e 65 val loss 2.2209 val acc 16.0917 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 7 e 66 val loss 2.2013 val acc 15.5641 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 67 val loss 2.1916 val acc 15.7670 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 68 val loss 2.1844 val acc 15.7062 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 69 val loss 2.1779 val acc 18.8312 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 70 val loss 2.1722 val acc 18.7906 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 71 val loss 2.1660 val acc 18.3644 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 72 val loss 2.1619 val acc 18.5268 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 73 val loss 2.1576 val acc 19.8255 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 74 val loss 2.1515 val acc 19.8661 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 75 val loss 2.1457 val acc 21.4692 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 76 val loss 2.1443 val acc 19.2167 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 77 val loss 2.1479 val acc 20.3937 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 8 e 78 val loss 2.1449 val acc 17.9383 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 6 e 79 val loss 2.1624 val acc 18.2427 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 5 e 80 val loss 2.1635 val acc 17.6745 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 4 e 81 val loss 2.2458 val acc 16.5179 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 4 e 82 val loss 2.1678 val acc 18.8515 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 6 e 83 val loss 2.1201 val acc 21.0836 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 10 e 84 val loss 2.1056 val acc 22.8490 best val_acc 24.675325 te_acc 24.452110
# mkrum: at fang n_at 10 n_mal_sel 9 e 85 val loss 2.1015 val acc 24.9391 best val_acc 24.939123 te_acc 23.133117
# mkrum: at fang n_at 10 n_mal_sel 10 e 86 val loss 2.0929 val acc 25.0812 best val_acc 25.081169 te_acc 23.660714
# mkrum: at fang n_at 10 n_mal_sel 10 e 87 val loss 2.0899 val acc 25.2232 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 10 e 88 val loss 2.0849 val acc 23.2752 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 9 e 89 val loss 2.0867 val acc 23.7216 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 9 e 90 val loss 2.0851 val acc 23.9245 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 6 e 91 val loss 2.1042 val acc 22.6867 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 5 e 92 val loss 2.1948 val acc 17.1063 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 3 e 93 val loss 2.0868 val acc 22.6055 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 6 e 94 val loss 2.1378 val acc 20.7386 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 4 e 95 val loss 2.1262 val acc 20.1299 best val_acc 25.223214 te_acc 23.741883
# mkrum: at fang n_at 10 n_mal_sel 4 e
best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 239 val loss 2.0178 val acc 27.4148 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 240 val loss 2.2115 val acc 26.6437 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 1 e 241 val loss 2.4472 val acc 12.9870 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 242 val loss 2.3150 val acc 14.6104 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 243 val loss 2.2257 val acc 19.7443 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 244 val loss 2.1837 val acc 20.7995 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 6 e 245 val loss 2.1549 val acc 21.3474 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 6 e 246 val loss 2.1945 val acc 19.4602 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 4 e 247 val loss 2.1043 val acc 23.9448 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 5 e 248 val loss 2.1675 val acc 18.2630 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 249 val loss 2.0897 val acc 22.1185 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 5 e 250 val loss 2.1172 val acc 20.4343 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 5 e 251 val loss 2.0248 val acc 26.5422 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 252 val loss 2.0135 val acc 25.8929 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 5 e 253 val loss 2.0942 val acc 26.4002 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 254 val loss 2.2764 val acc 15.4830 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 4 e 255 val loss 2.1588 val acc 19.7240 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 5 e 256 val loss 2.0673 val acc 24.2492 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 8 e 257 val loss 2.0332 val acc 24.5130 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 258 val loss 2.0145 val acc 24.7971 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 259 val loss 2.0207 val acc 25.7102 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 4 e 260 val loss 2.0417 val acc 24.6144 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 4 e 261 val loss 2.1873 val acc 19.1964 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 262 val loss 2.0422 val acc 23.3157 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 263 val loss 1.9661 val acc 29.6875 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 264 val loss 1.9135 val acc 28.8555 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 8 e 265 val loss 1.8889 val acc 29.6469 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 8 e 266 val loss 1.8533 val acc 29.5455 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 267 val loss 1.8421 val acc 31.3312 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 268 val loss 1.8161 val acc 31.7979 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 269 val loss 1.8351 val acc 31.2297 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 270 val loss 1.7912 val acc 31.6964 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 271 val loss 1.8196 val acc 31.0065 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 6 e 272 val loss 2.0166 val acc 22.5852 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 1 e 273 val loss 2.6642 val acc 21.1445 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 1 e 274 val loss 2.9817 val acc 10.1867 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 0 e 275 val loss 2.3438 val acc 10.5722 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 5 e 276 val loss 2.3267 val acc 11.3231 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 5 e 277 val loss 2.3073 val acc 12.1347 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 6 e 278 val loss 2.2863 val acc 13.3117 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 279 val loss 2.2647 val acc 14.2654 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 6 e 280 val loss 2.2369 val acc 16.3961 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 281 val loss 2.2066 val acc 18.1412 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 7 e 282 val loss 2.1740 val acc 18.9326 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 8 e 283 val loss 2.1465 val acc 19.7240 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 284 val loss 2.1267 val acc 19.7849 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 8 e 285 val loss 2.1107 val acc 19.6834 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 286 val loss 2.0971 val acc 20.5357 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 287 val loss 2.0876 val acc 20.5966 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 288 val loss 2.0811 val acc 21.3068 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 289 val loss 2.0787 val acc 22.5446 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 8 e 290 val loss 2.0801 val acc 23.4375 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 6 e 291 val loss 2.1397 val acc 19.4196 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 292 val loss 2.1892 val acc 17.2687 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 293 val loss 2.3057 val acc 10.5317 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 294 val loss 2.2515 val acc 11.8709 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 2 e 295 val loss 2.1421 val acc 19.3994 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 3 e 296 val loss 2.0399 val acc 24.2492 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 297 val loss 2.0281 val acc 24.0869 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 298 val loss 2.0192 val acc 24.2898 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 299 val loss 2.0123 val acc 24.0463 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e 300 val loss 2.0078 val acc 23.2955 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 301 val loss 2.0008 val acc 24.8580 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 9 e 302 val loss 1.9942 val acc 24.7362 best val_acc 33.928571 te_acc 33.969156
# mkrum: at fang n_at 10 n_mal_sel 10 e
best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1162 val loss 1.3829 val acc 54.8093 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1163 val loss 1.4794 val acc 54.4034 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1164 val loss 1.3869 val acc 55.3977 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1165 val loss 1.5596 val acc 52.7800 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1166 val loss 1.4425 val acc 52.8815 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1167 val loss 1.4964 val acc 52.8003 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1168 val loss 1.4900 val acc 53.2265 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1169 val loss 1.6843 val acc 49.9188 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 9 e 1170 val loss 1.5741 val acc 47.9708 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1171 val loss 1.3517 val acc 53.1047 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1172 val loss 1.2847 val acc 56.8182 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1173 val loss 1.3120 val acc 56.6356 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1174 val loss 1.3482 val acc 56.7979 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1175 val loss 1.3286 val acc 56.5138 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1176 val loss 1.4254 val acc 56.4123 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1177 val loss 1.4774 val acc 51.7451 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1178 val loss 1.8028 val acc 49.9594 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 8 e 1179 val loss 1.7768 val acc 43.9732 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 9 e 1180 val loss 1.4699 val acc 49.8985 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1181 val loss 1.2867 val acc 54.4237 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1182 val loss 1.2971 val acc 56.4732 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1183 val loss 1.3013 val acc 56.6356 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1184 val loss 1.3251 val acc 56.8588 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1185 val loss 1.3431 val acc 56.5138 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1186 val loss 1.4613 val acc 54.6672 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1187 val loss 1.4588 val acc 53.4903 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1188 val loss 1.6131 val acc 50.8726 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1189 val loss 1.5824 val acc 48.7825 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 9 e 1190 val loss 1.7404 val acc 47.4838 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 9 e 1191 val loss 1.5277 val acc 49.5942 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1192 val loss 1.4142 val acc 52.7394 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1193 val loss 1.3976 val acc 56.2094 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1194 val loss 1.3834 val acc 54.2208 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1195 val loss 1.4134 val acc 55.7224 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1196 val loss 1.2921 val acc 57.0820 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1197 val loss 1.3603 val acc 56.9196 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1198 val loss 1.3403 val acc 56.7776 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1199 val loss 1.4104 val acc 56.4935 best val_acc 57.426948 te_acc 57.670455
# mkrum: at fang n_at 10 n_mal_sel 10 e 1200 val loss 1.3620 val acc 55.9456 best val_acc 57.426948 te_acc 57.670455

# %%
def lie_attack(all_updates, z):
    avg = torch.mean(all_updates, dim=0)
    std = torch.std(all_updates, dim=0)
    return avg + z * std

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='mkrum'
multi_k = False
candidates = []

at_type='LIE'
z_values={3:0.69847, 5:0.7054, 8:0.71904, 10:0.72575, 12:0.73891}
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                mal_update = lie_attack(malicious_grads, z_values[n_attacker])
                malicious_grads = torch.cat((torch.stack([mal_update]*n_attacker), malicious_grads))
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang_trmean(malicious_grads, deviation, n_attacker, epoch_num)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                malicious_grads = our_attack_krum(malicious_grads, agg_grads, n_attacker, compression=compression, q_level=q_level, norm=norm)

        if not epoch_num : 
            print(malicious_grads.shape)

        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='trmean':
            agg_grads=tr_mean(malicious_grads, n_attacker)

        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%10==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d fed_model val loss %.4f val acc %.4f best val_acc %f te_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc,best_global_te_acc))

        if val_loss > 10:
            print('val loss %f too high'%val_loss)
            break

        epoch_num+=1
# Out:
# torch.Size([40, 2472266])
# multi krum is  True
# /home/vshejwalkar/fed-quant-robustness/code/cifar10/sgd.py:108: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729138878/work/torch/csrc/utils/python_arg_parser.cpp:882.)
#   p.data.add_(-group['lr'], d_p)
# mkrum: at LIE n_at 10 n_mal_sel 3 e 0 fed_model val loss 2.3021 val acc 10.5925 best val_acc 10.592532 te_acc 10.146104
# mkrum: at LIE n_at 10 n_mal_sel 6 e 10 fed_model val loss 2.2930 val acc 12.2565 best val_acc 14.285714 te_acc 14.346591
# mkrum: at LIE n_at 10 n_mal_sel 2 e 20 fed_model val loss 2.2692 val acc 13.5146 best val_acc 20.596591 te_acc 20.211039
# mkrum: at LIE n_at 10 n_mal_sel 8 e 30 fed_model val loss 2.2304 val acc 12.1956 best val_acc 20.596591 te_acc 20.211039
# mkrum: at LIE n_at 10 n_mal_sel 4 e 40 fed_model val loss 2.2415 val acc 16.3149 best val_acc 21.895292 te_acc 21.043019
# mkrum: at LIE n_at 10 n_mal_sel 8 e 50 fed_model val loss 2.1699 val acc 20.0893 best val_acc 22.524351 te_acc 21.387987
# mkrum: at LIE n_at 10 n_mal_sel 5 e 60 fed_model val loss 2.0669 val acc 23.1128 best val_acc 23.112825 te_acc 22.605519
# mkrum: at LIE n_at 10 n_mal_sel 6 e 70 fed_model val loss 2.0266 val acc 23.7825 best val_acc 23.782468 te_acc 23.579545
# mkrum: at LIE n_at 10 n_mal_sel 4 e 80 fed_model val loss 1.9615 val acc 25.0406 best val_acc 25.040584 te_acc 24.715909
# mkrum: at LIE n_at 10 n_mal_sel 5 e 90 fed_model val loss 2.1122 val acc 20.5763 best val_acc 27.536526 te_acc 26.562500
# mkrum: at LIE n_at 10 n_mal_sel 3 e 100 fed_model val loss 2.0462 val acc 22.9099 best val_acc 27.536526 te_acc 26.562500
# mkrum: at LIE n_at 10 n_mal_sel 6 e 110 fed_model val loss 2.1086 val acc 17.8977 best val_acc 29.687500 te_acc 29.403409
# mkrum: at LIE n_at 10 n_mal_sel 5 e 120 fed_model val loss 2.0139 val acc 26.5016 best val_acc 29.687500 te_acc 29.403409
# mkrum: at LIE n_at 10 n_mal_sel 8 e 130 fed_model val loss 1.8182 val acc 30.7224 best val_acc 31.331169 te_acc 30.722403
# mkrum: at LIE n_at 10 n_mal_sel 5 e 140 fed_model val loss 1.9318 val acc 28.4903 best val_acc 31.331169 te_acc 30.722403
# mkrum: at LIE n_at 10 n_mal_sel 5 e 150 fed_model val loss 1.9101 val acc 27.9424 best val_acc 31.331169 te_acc 30.722403
# mkrum: at LIE n_at 10 n_mal_sel 5 e 160 fed_model val loss 1.9082 val acc 30.2354 best val_acc 31.331169 te_acc 30.722403
# mkrum: at LIE n_at 10 n_mal_sel 4 e 170 fed_model val loss 1.9011 val acc 27.3539 best val_acc 33.502435 te_acc 35.206981
# mkrum: at LIE n_at 10 n_mal_sel 5 e 180 fed_model val loss 1.9136 val acc 28.5714 best val_acc 33.502435 te_acc 35.206981
# mkrum: at LIE n_at 10 n_mal_sel 4 e 190 fed_model val loss 1.6902 val acc 35.5519 best val_acc 37.642045 te_acc 37.946429
# mkrum: at LIE n_at 10 n_mal_sel 3 e 200 fed_model val loss 1.7886 val acc 33.0357 best val_acc 37.642045 te_acc 37.946429
# mkrum: at LIE n_at 10 n_mal_sel 5 e 210 fed_model val loss 1.7416 val acc 35.1867 best val_acc 37.642045 te_acc 37.946429
# mkrum: at LIE n_at 10 n_mal_sel 6 e 220 fed_model val loss 1.6547 val acc 37.6623 best val_acc 37.763799 te_acc 37.540584
# mkrum: at LIE n_at 10 n_mal_sel 4 e 230 fed_model val loss 1.8528 val acc 29.9107 best val_acc 39.306006 te_acc 39.427760
# mkrum: at LIE n_at 10 n_mal_sel 5 e 240 fed_model val loss 1.6847 val acc 37.1753 best val_acc 39.306006 te_acc 39.427760
# mkrum: at LIE n_at 10 n_mal_sel 5 e 250 fed_model val loss 1.7467 val acc 34.7200 best val_acc 40.056818 te_acc 40.685877
# mkrum: at LIE n_at 10 n_mal_sel 3 e 260 fed_model val loss 1.5829 val acc 41.6396 best val_acc 42.715097 te_acc 43.547078
# mkrum: at LIE n_at 10 n_mal_sel 4 e 270 fed_model val loss 1.7584 val acc 35.0852 best val_acc 42.715097 te_acc 43.547078
# mkrum: at LIE n_at 10 n_mal_sel 5 e 280 fed_model val loss 1.6574 val acc 39.3060 best val_acc 43.039773 te_acc 42.187500
# mkrum: at LIE n_at 10 n_mal_sel 5 e 290 fed_model val loss 1.6842 val acc 37.9464 best val_acc 44.642857 te_acc 45.353084
# mkrum: at LIE n_at 10 n_mal_sel 2 e 300 fed_model val loss 1.5199 val acc 44.4805 best val_acc 44.642857 te_acc 45.353084
# mkrum: at LIE n_at 10 n_mal_sel 6 e 310 fed_model val loss 1.7418 val acc 35.8563 best val_acc 44.906656 te_acc 44.967532
# mkrum: at LIE n_at 10 n_mal_sel 4 e 320 fed_model val loss 1.4841 val acc 44.4196 best val_acc 44.906656 te_acc 44.967532
# mkrum: at LIE n_at 10 n_mal_sel 4 e 330 fed_model val loss 1.6334 val acc 41.6193 best val_acc 44.906656 te_acc 44.967532
# mkrum: at LIE n_at 10 n_mal_sel 3 e 340 fed_model val loss 1.5284 val acc 42.0049 best val_acc 46.814123 te_acc 46.793831
# mkrum: at LIE n_at 10 n_mal_sel 4 e 350 fed_model val loss 1.5463 val acc 43.1615 best val_acc 47.686688 te_acc 48.153409
# mkrum: at LIE n_at 10 n_mal_sel 4 e 360 fed_model val loss 1.6428 val acc 42.0252 best val_acc 47.686688 te_acc 48.153409
# mkrum: at LIE n_at 10 n_mal_sel 5 e 370 fed_model val loss 1.5245 val acc 44.1153 best val_acc 47.686688 te_acc 48.153409
# mkrum: at LIE n_at 10 n_mal_sel 3 e 380 fed_model val loss 1.5422 val acc 43.2630 best val_acc 48.031656 te_acc 49.208604
# mkrum: at LIE n_at 10 n_mal_sel 3 e 390 fed_model val loss 1.4704 val acc 46.5503 best val_acc 48.031656 te_acc 49.208604
# mkrum: at LIE n_at 10 n_mal_sel 4 e 400 fed_model val loss 1.5385 val acc 43.0601 best val_acc 48.031656 te_acc 49.208604
# mkrum: at LIE n_at 10 n_mal_sel 6 e 410 fed_model val loss 1.3882 val acc 49.1477 best val_acc 49.289773 te_acc 49.208604
# mkrum: at LIE n_at 10 n_mal_sel 4 e 420 fed_model val loss 1.4564 val acc 47.6055 best val_acc 49.289773 te_acc 49.208604
# mkrum: at LIE n_at 10 n_mal_sel 4 e 430 fed_model val loss 1.5000 val acc 44.0544 best val_acc 51.237825 te_acc 52.435065
# mkrum: at LIE n_at 10 n_mal_sel 4 e 440 fed_model val loss 1.4585 val acc 47.2808 best val_acc 51.237825 te_acc 52.435065
# mkrum: at LIE n_at 10 n_mal_sel 5 e 450 fed_model val loss 1.4106 val acc 48.0519 best val_acc 51.237825 te_acc 52.435065
# mkrum: at LIE n_at 10 n_mal_sel 4 e 460 fed_model val loss 1.4543 val acc 49.0260 best val_acc 51.562500 te_acc 51.136364
# mkrum: at LIE n_at 10 n_mal_sel 5 e 470 fed_model val loss 1.3418 val acc 51.5422 best val_acc 51.562500 te_acc 51.136364
# mkrum: at LIE n_at 10 n_mal_sel 3 e 480 fed_model val loss 1.6978 val acc 43.5268 best val_acc 51.562500 te_acc 51.136364
# mkrum: at LIE n_at 10 n_mal_sel 6 e 490 fed_model val loss 1.5676 val acc 44.6023 best val_acc 51.562500 te_acc 51.136364
# mkrum: at LIE n_at 10 n_mal_sel 3 e 500 fed_model val loss 1.4188 val acc 50.1218 best val_acc 52.130682 te_acc 52.516234
# mkrum: at LIE n_at 10 n_mal_sel 4 e 510 fed_model val loss 1.4460 val acc 46.3068 best val_acc 54.180195 te_acc 53.875812
# mkrum: at LIE n_at 10 n_mal_sel 3 e 520 fed_model val loss 1.3782 val acc 50.3653 best val_acc 54.180195 te_acc 53.875812
# mkrum: at LIE n_at 10 n_mal_sel 6 e 530 fed_model val loss 1.4505 val acc 48.8636 best val_acc 54.180195 te_acc 53.875812
# mkrum: at LIE n_at 10 n_mal_sel 5 e 540 fed_model val loss 1.3092 val acc 52.5568 best val_acc 54.606331 te_acc 54.626623
# mkrum: at LIE n_at 10 n_mal_sel 4 e 550 fed_model val loss 1.4646 val acc 47.7881 best val_acc 54.606331 te_acc 54.626623
# mkrum: at LIE n_at 10 n_mal_sel 5 e 560 fed_model val loss 1.3751 val acc 50.9740 best val_acc 54.606331 te_acc 54.626623
# mkrum: at LIE n_at 10 n_mal_sel 7 e 570 fed_model val loss 1.4548 val acc 47.7881 best val_acc 54.606331 te_acc 54.626623
# mkrum: at LIE n_at 10 n_mal_sel 3 e 580 fed_model val loss 1.5174 val acc 45.5966 best val_acc 54.606331 te_acc 54.626623
# mkrum: at LIE n_at 10 n_mal_sel 7 e 590 fed_model val loss 1.3096 val acc 53.8555 best val_acc 54.606331 te_acc 54.626623
# mkrum: at LIE n_at 10 n_mal_sel 4 e 600 fed_model val loss 1.3898 val acc 51.9683 best val_acc 54.606331 te_acc 54.626623
# mkrum: at LIE n_at 10 n_mal_sel 7 e 610 fed_model val loss 1.2803 val acc 54.7281 best val_acc 55.316558 te_acc 56.128247
# mkrum: at LIE n_at 10 n_mal_sel 3 e 620 fed_model val loss 1.4719 val acc 49.1477 best val_acc 55.742695 te_acc 56.432630
# mkrum: at LIE n_at 10 n_mal_sel 6 e 630 fed_model val loss 1.3593 val acc 52.8409 best val_acc 55.742695 te_acc 56.432630
# mkrum: at LIE n_at 10 n_mal_sel 4 e 640 fed_model val loss 1.2665 val acc 55.7021 best val_acc 55.742695 te_acc 56.432630
# mkrum: at LIE n_at 10 n_mal_sel 6 e 650 fed_model val loss 1.3132 val acc 53.4700 best val_acc 55.742695 te_acc 56.432630
# mkrum: at LIE n_at 10 n_mal_sel 4 e 660 fed_model val loss 1.5069 val acc 49.4115 best val_acc 55.742695 te_acc 56.432630
# mkrum: at LIE n_at 10 n_mal_sel 6 e 670 fed_model val loss 1.3014 val acc 54.3628 best val_acc 55.742695 te_acc 56.432630
# mkrum: at LIE n_at 10 n_mal_sel 4 e 680 fed_model val loss 1.5174 val acc 50.9537 best val_acc 55.905032 te_acc 55.661526
# mkrum: at LIE n_at 10 n_mal_sel 6 e 690 fed_model val loss 1.4842 val acc 49.3912 best val_acc 56.493506 te_acc 55.803571
# mkrum: at LIE n_at 10 n_mal_sel 4 e 700 fed_model val loss 1.2874 val acc 54.9919 best val_acc 56.493506 te_acc 55.803571
# mkrum: at LIE n_at 10 n_mal_sel 5 e 710 fed_model val loss 1.3465 val acc 53.3279 best val_acc 56.493506 te_acc 55.803571
# mkrum: at LIE n_at 10 n_mal_sel 4 e 720 fed_model val loss 1.3827 val acc 51.8060 best val_acc 56.493506 te_acc 55.803571
# mkrum: at LIE n_at 10 n_mal_sel 6 e 730 fed_model val loss 1.3784 val acc 51.0552 best val_acc 56.757305 te_acc 57.224026
# mkrum: at LIE n_at 10 n_mal_sel 5 e 740 fed_model val loss 1.7745 val acc 43.1209 best val_acc 56.757305 te_acc 57.224026
# mkrum: at LIE n_at 10 n_mal_sel 6 e 750 fed_model val loss 1.4053 val acc 53.0032 best val_acc 56.757305 te_acc 57.224026
# mkrum: at LIE n_at 10 n_mal_sel 3 e 760 fed_model val loss 1.4448 val acc 51.3596 best val_acc 56.757305 te_acc 57.224026
# mkrum: at LIE n_at 10 n_mal_sel 5 e 770 fed_model val loss 1.5330 val acc 46.8953 best val_acc 56.757305 te_acc 57.224026
# mkrum: at LIE n_at 10 n_mal_sel 4 e 780 fed_model val loss 1.4444 val acc 53.3888 best val_acc 57.913961 te_acc 58.218344
# mkrum: at LIE n_at 10 n_mal_sel 6 e 790 fed_model val loss 1.4145 val acc 54.1802 best val_acc 57.913961 te_acc 58.218344
# mkrum: at LIE n_at 10 n_mal_sel 4 e 800 fed_model val loss 1.4605 val acc 53.3888 best val_acc 57.913961 te_acc 58.218344
# mkrum: at LIE n_at 10 n_mal_sel 5 e 810 fed_model val loss 1.4792 val acc 51.7248 best val_acc 57.913961 te_acc 58.218344
# mkrum: at LIE n_at 10 n_mal_sel 3 e 820 fed_model val loss 1.5641 val acc 51.7857 best val_acc 57.913961 te_acc 58.218344
# mkrum: at LIE n_at 10 n_mal_sel 6 e 830 fed_model val loss 1.5755 val acc 50.8320 best val_acc 57.913961 te_acc 58.218344
# mkrum: at LIE n_at 10 n_mal_sel 3 e 840 fed_model val loss 1.5006 val acc 52.5568 best val_acc 57.913961 te_acc 58.218344
# mkrum: at LIE n_at 10 n_mal_sel 5 e 850 fed_model val loss 1.4800 val acc 57.0211 best val_acc 59.151786 te_acc 59.801136
# mkrum: at LIE n_at 10 n_mal_sel 4 e 860 fed_model val loss 1.5738 val acc 53.2670 best val_acc 59.151786 te_acc 59.801136
# mkrum: at LIE n_at 10 n_mal_sel 5 e 870 fed_model val loss 1.6082 val acc 54.7890 best val_acc 59.151786 te_acc 59.801136
# mkrum: at LIE n_at 10 n_mal_sel 4 e 880 fed_model val loss 1.4420 val acc 54.8701 best val_acc 59.151786 te_acc 59.801136
# mkrum: at LIE n_at 10 n_mal_sel 5 e 890 fed_model val loss 1.4478 val acc 57.4269 best val_acc 59.151786 te_acc 59.801136
# mkrum: at LIE n_at 10 n_mal_sel 4 e 900 fed_model val loss 1.4882 val acc 58.7662 best val_acc 59.314123 te_acc 59.557630
# mkrum: at LIE n_at 10 n_mal_sel 5 e 910 fed_model val loss 1.6446 val acc 55.3571 best val_acc 59.314123 te_acc 59.557630
# mkrum: at LIE n_at 10 n_mal_sel 4 e 920 fed_model val loss 1.9837 val acc 45.2719 best val_acc 59.314123 te_acc 59.557630
# mkrum: at LIE n_at 10 n_mal_sel 5 e 930 fed_model val loss 1.5180 val acc 53.4700 best val_acc 59.314123 te_acc 59.557630
# mkrum: at LIE n_at 10 n_mal_sel 4 e 940 fed_model val loss 1.7516 val acc 50.2841 best val_acc 59.314123 te_acc 59.557630
# mkrum: at LIE n_at 10 n_mal_sel 5 e 950 fed_model val loss 1.6612 val acc 54.4237 best val_acc 59.314123 te_acc 59.557630
# mkrum: at LIE n_at 10 n_mal_sel 4 e 960 fed_model val loss 1.4482 val acc 59.8417 best val_acc 59.841721 te_acc 59.517045
# mkrum: at LIE n_at 10 n_mal_sel 5 e 970 fed_model val loss 1.5679 val acc 59.5373 best val_acc 59.841721 te_acc 59.517045
# mkrum: at LIE n_at 10 n_mal_sel 4 e 980 fed_model val loss 1.8094 val acc 58.2183 best val_acc 59.841721 te_acc 59.517045
# mkrum: at LIE n_at 10 n_mal_sel 5 e 990 fed_model val loss 1.8364 val acc 59.4968 best val_acc 59.902597 te_acc 60.633117
# New learnin rate  0.25
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1000 fed_model val loss 1.9635 val acc 59.6997 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1010 fed_model val loss 2.0310 val acc 59.6794 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1020 fed_model val loss 2.0916 val acc 59.6997 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1030 fed_model val loss 2.1392 val acc 59.5779 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1040 fed_model val loss 2.1880 val acc 59.6185 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1050 fed_model val loss 2.2286 val acc 59.6591 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1060 fed_model val loss 2.2703 val acc 59.6591 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1070 fed_model val loss 2.3059 val acc 59.7403 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1080 fed_model val loss 2.3425 val acc 59.7808 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1090 fed_model val loss 2.3742 val acc 59.7200 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1100 fed_model val loss 2.4061 val acc 59.7403 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1110 fed_model val loss 2.4343 val acc 59.7403 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1120 fed_model val loss 2.4628 val acc 59.6997 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1130 fed_model val loss 2.4885 val acc 59.7808 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1140 fed_model val loss 2.5142 val acc 59.7403 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1150 fed_model val loss 2.5376 val acc 59.8417 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1160 fed_model val loss 2.5611 val acc 59.8011 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1170 fed_model val loss 2.5826 val acc 59.7808 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1180 fed_model val loss 2.6043 val acc 59.6997 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 5 e 1190 fed_model val loss 2.6241 val acc 59.7403 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 6 e 1199 fed_model val loss 2.6417 val acc 59.7808 best val_acc 59.943182 te_acc 60.470779
# mkrum: at LIE n_at 10 n_mal_sel 4 e 1200 fed_model val loss 2.6438 val acc 59.7808 best val_acc 59.943182 te_acc 60.470779

# %%
def our_attack_mkrum(all_updates, model_re, n_attackers, dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)

    lamda = torch.Tensor([3.0]).cuda()

    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

        agg_grads, krum_candidate = multi_krum(mal_updates, n_attackers, multi_k=True)
        if np.sum(krum_candidate < n_attackers) == n_attackers:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    mal_update = (model_re - lamda_succ * deviation)
    mal_updates = torch.stack([mal_update] * n_attackers)
    mal_updates = torch.cat((mal_updates, all_updates), 0)

    return mal_updates

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='mkrum'
multi_k = False
candidates = []

at_type='our-agr'
dev_type ='std'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation


for n_attacker in n_attackers:
    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                malicious_grads = our_attack_mkrum(malicious_grads, agg_grads, n_attacker, dev_type=dev_type)

        if not malicious_grads.shape[0]==50: print('malicious grads shape ', malicious_grads.shape)
        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':

            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))
        
        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break
            
        epoch_num+=1
# Out:
# multi krum is  True
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 0 | val loss 2.3026 val acc 10.3693 best val_acc 10.369318
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 1 | val loss 2.3021 val acc 10.3693 best val_acc 10.369318
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 2 | val loss 2.3017 val acc 10.9375 best val_acc 10.937500
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 3 | val loss 2.3012 val acc 13.9205 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 4 | val loss 2.3008 val acc 9.8011 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 5 | val loss 2.3002 val acc 10.5519 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 6 | val loss 2.2996 val acc 11.3231 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 7 | val loss 2.2990 val acc 9.7200 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 8 | val loss 2.2982 val acc 9.6388 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 9 | val loss 2.2973 val acc 9.6794 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 10 | val loss 2.2962 val acc 9.6794 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 11 | val loss 2.2949 val acc 9.6388 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 12 | val loss 2.2932 val acc 9.6388 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 13 | val loss 2.2909 val acc 9.6388 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 14 | val loss 2.2880 val acc 9.6591 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 15 | val loss 2.2841 val acc 9.7403 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 16 | val loss 2.2786 val acc 10.8766 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 17 | val loss 2.2704 val acc 13.7175 best val_acc 13.920455
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 18 | val loss 2.2589 val acc 16.5787 best val_acc 16.578734
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 19 | val loss 2.2431 val acc 16.1120 best val_acc 16.578734
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 20 | val loss 2.2243 val acc 18.4456 best val_acc 18.445617
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 21 | val loss 2.1965 val acc 21.2054 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 22 | val loss 2.2505 val acc 19.3994 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 23 | val loss 2.6619 val acc 9.9432 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 24 | val loss 2.3041 val acc 9.5576 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 25 | val loss 2.3038 val acc 9.5576 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 26 | val loss 2.3036 val acc 9.5576 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 27 | val loss 2.3033 val acc 9.5576 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 28 | val loss 2.3031 val acc 9.5576 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 29 | val loss 2.3029 val acc 9.5373 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 30 | val loss 2.3027 val acc 9.5170 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 31 | val loss 2.3024 val acc 9.4968 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 32 | val loss 2.3022 val acc 9.4562 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 33 | val loss 2.3020 val acc 12.4188 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 34 | val loss 2.3017 val acc 13.8393 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 35 | val loss 2.3014 val acc 12.9261 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 36 | val loss 2.3012 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 37 | val loss 2.3008 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 38 | val loss 2.3004 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 39 | val loss 2.2998 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 40 | val loss 2.2992 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 41 | val loss 2.2984 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 42 | val loss 2.2973 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 43 | val loss 2.2959 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 44 | val loss 2.2941 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 45 | val loss 2.2912 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 46 | val loss 2.2870 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 47 | val loss 2.2804 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 48 | val loss 2.2694 val acc 9.6388 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 49 | val loss 2.2509 val acc 10.1461 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 50 | val loss 2.2289 val acc 14.5089 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 51 | val loss 2.2091 val acc 15.1989 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 52 | val loss 2.1954 val acc 17.4107 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 53 | val loss 2.1745 val acc 19.8661 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 54 | val loss 2.1826 val acc 17.4716 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 55 | val loss 2.2594 val acc 13.2508 best val_acc 21.205357
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 56 | val loss 2.1618 val acc 21.3068 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 57 | val loss 2.2834 val acc 17.0455 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 58 | val loss 2.3099 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 59 | val loss 2.3083 val acc 9.9229 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 60 | val loss 2.3065 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 61 | val loss 2.3048 val acc 10.5722 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 62 | val loss 2.3034 val acc 9.7403 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 63 | val loss 2.3020 val acc 10.0244 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 64 | val loss 2.3004 val acc 10.6331 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 65 | val loss 2.2985 val acc 12.6015 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 66 | val loss 2.2965 val acc 14.3263 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 67 | val loss 2.2942 val acc 14.8742 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 68 | val loss 2.2920 val acc 15.3409 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 69 | val loss 2.2884 val acc 15.0771 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 70 | val loss 2.2844 val acc 15.6453 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 71 | val loss 2.2796 val acc 15.4221 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 72 | val loss 2.2760 val acc 14.3060 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 73 | val loss 2.2672 val acc 16.3555 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 74 | val loss 2.2791 val acc 10.5722 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 75 | val loss 2.3040 val acc 9.9635 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 76 | val loss 2.2944 val acc 10.7549 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 77 | val loss 2.2757 val acc 13.3523 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 78 | val loss 2.2391 val acc 16.8628 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 79 | val loss 2.2169 val acc 16.2135 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 80 | val loss 2.2117 val acc 15.0974 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 81 | val loss 2.3065 val acc 10.3896 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 82 | val loss 2.2386 val acc 14.9959 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 83 | val loss 2.1652 val acc 17.5122 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 84 | val loss 2.1300 val acc 16.9237 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 85 | val loss 2.6410 val acc 11.9521 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 86 | val loss 3.8455 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 87 | val loss 2.3176 val acc 9.5576 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 88 | val loss 2.3137 val acc 9.3344 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 89 | val loss 2.3100 val acc 9.8214 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 90 | val loss 2.3068 val acc 9.8011 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 91 | val loss 2.3038 val acc 9.8214 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 92 | val loss 2.3003 val acc 9.8011 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 93 | val loss 2.2941 val acc 9.8011 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 94 | val loss 2.2854 val acc 9.8011 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 95 | val loss 2.2734 val acc 9.8011 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 96 | val loss 2.2602 val acc 9.8011 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 97 | val loss 2.2391 val acc 14.5495 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 98 | val loss 2.3609 val acc 11.2013 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 99 | val loss 2.3047 val acc 9.8620 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 100 | val loss 2.3034 val acc 10.0649 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 101 | val loss 2.3022 val acc 10.9172 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 102 | val loss 2.3010 val acc 11.9724 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 103 | val loss 2.2999 val acc 12.3174 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 104 | val loss 2.2989 val acc 12.0942 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 105 | val loss 2.2976 val acc 11.9724 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 106 | val loss 2.2960 val acc 12.6218 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 107 | val loss 2.2942 val acc 12.9261 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 108 | val loss 2.2938 val acc 12.6623 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 109 | val loss 2.2899 val acc 12.5609 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 110 | val loss 2.2869 val acc 12.8247 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 111 | val loss 2.2839 val acc 13.0885 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 112 | val loss 2.2864 val acc 12.7232 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 113 | val loss 2.2750 val acc 13.8393 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 114 | val loss 2.2786 val acc 13.5755 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 115 | val loss 2.2694 val acc 14.8336 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 116 | val loss 2.3167 val acc 13.8799 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 117 | val loss 2.2922 val acc 11.5869 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 118 | val loss 2.2827 val acc 13.3117 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 119 | val loss 2.2711 val acc 14.7727 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 120 | val loss 2.2629 val acc 14.2654 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 121 | val loss 2.2482 val acc 14.7321 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 122 | val loss 2.2252 val acc 16.3149 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 123 | val loss 2.2012 val acc 16.5584 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 124 | val loss 2.1782 val acc 18.4253 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 125 | val loss 2.1901 val acc 19.8661 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 126 | val loss 2.7952 val acc 13.3320 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 127 | val loss 2.3225 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 128 | val loss 2.3200 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 129 | val loss 2.3178 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 130 | val loss 2.3160 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 131 | val loss 2.3143 val acc 9.9229 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 132 | val loss 2.3126 val acc 9.9838 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 133 | val loss 2.3110 val acc 10.1055 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 134 | val loss 2.3097 val acc 10.0041 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 135 | val loss 2.3084 val acc 10.2273 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 136 | val loss 2.3070 val acc 10.4099 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 137 | val loss 2.3056 val acc 10.9172 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 138 | val loss 2.3045 val acc 11.4854 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 139 | val loss 2.3033 val acc 11.6274 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 140 | val loss 2.3020 val acc 12.1753 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 141 | val loss 2.3004 val acc 12.5406 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 142 | val loss 2.2991 val acc 13.2711 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 143 | val loss 2.2973 val acc 13.7581 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 144 | val loss 2.2956 val acc 14.4683 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 145 | val loss 2.2923 val acc 14.4683 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 146 | val loss 2.2895 val acc 14.8945 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 147 | val loss 2.2852 val acc 15.0771 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 148 | val loss 2.2825 val acc 14.8133 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 149 | val loss 2.2723 val acc 17.8369 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 150 | val loss 2.2677 val acc 17.4310 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 151 | val loss 2.2573 val acc 16.8425 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 152 | val loss 2.2983 val acc 12.0333 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 153 | val loss 2.2897 val acc 13.1899 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 154 | val loss 2.2769 val acc 14.2248 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 155 | val loss 2.2693 val acc 14.3872 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 156 | val loss 2.2690 val acc 14.8336 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 157 | val loss 2.2534 val acc 17.1266 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 158 | val loss 2.2547 val acc 15.9294 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 159 | val loss 2.2589 val acc 15.6453 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 160 | val loss 2.2569 val acc 15.9497 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 161 | val loss 2.2700 val acc 15.1989 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 162 | val loss 2.2111 val acc 18.8718 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 163 | val loss 2.2003 val acc 18.8109 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 164 | val loss 2.3385 val acc 14.0219 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 165 | val loss 2.3020 val acc 10.6737 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 166 | val loss 2.2787 val acc 14.1843 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 167 | val loss 2.2668 val acc 14.8742 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 168 | val loss 2.2514 val acc 14.8742 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 169 | val loss 2.2820 val acc 15.5235 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 170 | val loss 2.3100 val acc 10.0852 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 171 | val loss 2.3024 val acc 10.5317 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 172 | val loss 2.2859 val acc 12.2971 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 173 | val loss 2.2449 val acc 16.6802 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 174 | val loss 2.2219 val acc 17.3093 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 175 | val loss 2.2118 val acc 17.4310 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 176 | val loss 2.3333 val acc 15.5844 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 177 | val loss 2.3152 val acc 9.9026 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 178 | val loss 2.3129 val acc 9.7606 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 179 | val loss 2.3107 val acc 9.8620 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 180 | val loss 2.3085 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 181 | val loss 2.3065 val acc 10.2679 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 182 | val loss 2.3048 val acc 10.4302 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 183 | val loss 2.3031 val acc 10.4302 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 184 | val loss 2.3015 val acc 10.7955 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 185 | val loss 2.2995 val acc 10.8360 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 186 | val loss 2.2977 val acc 11.1201 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 187 | val loss 2.2959 val acc 11.2825 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 188 | val loss 2.2943 val acc 11.1201 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 189 | val loss 2.2916 val acc 11.4854 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 190 | val loss 2.2894 val acc 11.3636 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 191 | val loss 2.2868 val acc 11.8506 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 192 | val loss 2.2849 val acc 11.1607 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 193 | val loss 2.2802 val acc 12.4797 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 194 | val loss 2.2770 val acc 12.2971 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 195 | val loss 2.2727 val acc 13.3523 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 196 | val loss 2.2752 val acc 11.1201 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 197 | val loss 2.2769 val acc 13.8393 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 198 | val loss 2.2639 val acc 11.7289 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 199 | val loss 2.2726 val acc 13.3320 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 200 | val loss 2.2500 val acc 13.5146 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 201 | val loss 2.2492 val acc 17.2078 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 202 | val loss 2.2774 val acc 11.5463 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 203 | val loss 2.3100 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 204 | val loss 2.3072 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 205 | val loss 2.3044 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 206 | val loss 2.3014 val acc 9.9838 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 207 | val loss 2.2976 val acc 10.4302 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 208 | val loss 2.2920 val acc 12.7435 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 209 | val loss 2.2835 val acc 14.6104 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 210 | val loss 2.2693 val acc 15.6656 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 211 | val loss 2.2453 val acc 15.8279 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 212 | val loss 2.2249 val acc 16.5990 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 213 | val loss 2.1870 val acc 20.0284 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 214 | val loss 2.2248 val acc 16.8831 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 215 | val loss 2.3639 val acc 9.9229 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 216 | val loss 2.2991 val acc 11.5463 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 217 | val loss 2.2947 val acc 13.2711 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 218 | val loss 2.2897 val acc 14.0016 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 219 | val loss 2.2840 val acc 14.8742 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 220 | val loss 2.2776 val acc 15.2192 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 221 | val loss 2.2708 val acc 15.0771 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 222 | val loss 2.2634 val acc 15.0162 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 223 | val loss 2.2546 val acc 15.5844 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 224 | val loss 2.2440 val acc 16.1120 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 225 | val loss 2.2251 val acc 16.1729 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 226 | val loss 2.1927 val acc 17.0657 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 227 | val loss 2.1451 val acc 17.9586 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 228 | val loss 2.1255 val acc 18.4862 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 229 | val loss 2.1264 val acc 19.2573 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 230 | val loss 2.7704 val acc 11.0390 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 231 | val loss 2.3205 val acc 11.3433 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 232 | val loss 2.2792 val acc 12.2971 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 233 | val loss 2.2581 val acc 11.3231 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 234 | val loss 2.2511 val acc 11.6274 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 235 | val loss 2.2458 val acc 12.2971 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 236 | val loss 2.2490 val acc 13.0682 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 237 | val loss 2.2400 val acc 12.1753 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 238 | val loss 2.2537 val acc 10.9984 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 239 | val loss 2.2257 val acc 12.1956 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 240 | val loss 2.2322 val acc 17.6745 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 241 | val loss 2.2131 val acc 16.6802 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 242 | val loss 2.2241 val acc 16.0308 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 243 | val loss 2.2135 val acc 16.4164 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 244 | val loss 2.2555 val acc 14.0828 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 245 | val loss 2.1967 val acc 18.0601 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 246 | val loss 2.1891 val acc 17.1063 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 247 | val loss 2.1985 val acc 16.4164 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 248 | val loss 2.1812 val acc 16.9237 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 249 | val loss 2.2180 val acc 17.2687 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 250 | val loss 2.1761 val acc 19.1558 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 251 | val loss 2.1885 val acc 16.1729 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 252 | val loss 2.1685 val acc 17.5731 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 253 | val loss 2.2225 val acc 15.4830 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 254 | val loss 2.1665 val acc 16.7614 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 255 | val loss 2.1677 val acc 17.9383 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 256 | val loss 2.1376 val acc 18.3644 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 257 | val loss 2.1497 val acc 16.8019 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 258 | val loss 2.2210 val acc 16.8425 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 259 | val loss 2.3478 val acc 11.2216 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 260 | val loss 2.3005 val acc 12.7638 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 261 | val loss 2.2606 val acc 13.2711 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 262 | val loss 2.2174 val acc 13.5552 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 263 | val loss 2.1897 val acc 16.2541 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 264 | val loss 2.1791 val acc 15.9091 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 265 | val loss 2.1633 val acc 16.1323 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 266 | val loss 2.1523 val acc 16.5787 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 267 | val loss 2.1395 val acc 16.2946 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 268 | val loss 2.1756 val acc 14.8742 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 269 | val loss 2.1378 val acc 14.7321 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 270 | val loss 2.4052 val acc 13.9205 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 271 | val loss 2.3570 val acc 9.9432 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 272 | val loss 2.2860 val acc 14.3263 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 273 | val loss 2.2633 val acc 12.2159 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 274 | val loss 2.2112 val acc 15.4221 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 275 | val loss 2.1730 val acc 16.3352 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 276 | val loss 2.1539 val acc 16.8019 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 277 | val loss 2.1381 val acc 17.7557 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 278 | val loss 2.1251 val acc 20.3328 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 279 | val loss 2.1090 val acc 19.4805 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 280 | val loss 2.1114 val acc 18.9732 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 281 | val loss 2.1293 val acc 17.2890 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 282 | val loss 2.0889 val acc 17.9789 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 283 | val loss 2.1593 val acc 20.0284 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 284 | val loss 2.6153 val acc 10.5722 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 285 | val loss 2.2546 val acc 10.3084 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 286 | val loss 2.2164 val acc 14.2857 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 287 | val loss 2.1997 val acc 14.7321 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 288 | val loss 2.1889 val acc 18.3442 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 289 | val loss 2.1751 val acc 19.5820 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 290 | val loss 2.1629 val acc 19.5008 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 291 | val loss 2.1597 val acc 19.4805 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 292 | val loss 2.1859 val acc 18.7906 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 293 | val loss 2.1450 val acc 20.1907 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 294 | val loss 2.1488 val acc 19.1761 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 295 | val loss 2.1610 val acc 19.6226 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 296 | val loss 2.2573 val acc 14.4481 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 297 | val loss 2.1761 val acc 18.1006 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 298 | val loss 2.1329 val acc 18.8515 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 299 | val loss 2.1158 val acc 20.5763 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 300 | val loss 2.1016 val acc 20.4748 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 301 | val loss 2.0909 val acc 20.0081 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 302 | val loss 2.0801 val acc 18.4862 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 303 | val loss 2.1252 val acc 17.3093 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 304 | val loss 2.1477 val acc 19.1558 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 305 | val loss 2.4936 val acc 9.9635 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 306 | val loss 2.2117 val acc 16.2541 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 307 | val loss 2.1442 val acc 19.1153 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 308 | val loss 2.1325 val acc 19.0138 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 309 | val loss 2.1316 val acc 20.7183 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 310 | val loss 2.2001 val acc 16.1729 best val_acc 21.306818
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 311 | val loss 2.1216 val acc 21.7735 best val_acc 21.773539
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 312 | val loss 2.1572 val acc 18.1615 best val_acc 21.773539
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 313 | val loss 2.1383 val acc 19.5820 best val_acc 21.773539
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 314 | val loss 2.1453 val acc 19.0747 best val_acc 21.773539
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 315 | val loss 2.1340 val acc 20.6372 best val_acc 21.773539
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 316 | val loss 2.2138 val acc 16.4773 best val_acc 21.773539
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 317 | val loss 2.1595 val acc 20.5763 best val_acc 21.773539
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 318 | val loss 2.1332 val acc 21.8953 best val_acc 21.895292
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 319 | val loss 2.1020 val acc 23.5593 best val_acc 23.559253
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 320 | val loss 2.1084 val acc 21.5706 best val_acc 23.559253
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 321 | val loss 2.0688 val acc 24.0666 best val_acc 24.066558
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 322 | val loss 2.1633 val acc 17.9383 best val_acc 24.066558
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 323 | val loss 2.1569 val acc 20.4748 best val_acc 24.066558
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 324 | val loss 2.2889 val acc 15.9294 best val_acc 24.066558
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 325 | val loss 2.1659 val acc 21.1039 best val_acc 24.066558
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 326 | val loss 2.0675 val acc 22.0170 best val_acc 24.066558
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 327 | val loss 2.0049 val acc 26.4610 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 328 | val loss 2.0165 val acc 24.1071 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 329 | val loss 2.6459 val acc 18.6891 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 330 | val loss 2.2029 val acc 12.9261 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 331 | val loss 2.1291 val acc 16.9440 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 332 | val loss 2.2342 val acc 13.4131 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 333 | val loss 2.0822 val acc 21.2865 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 334 | val loss 2.0293 val acc 22.5852 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 335 | val loss 2.0134 val acc 22.3214 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 336 | val loss 2.1043 val acc 19.3791 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 337 | val loss 2.2117 val acc 19.1761 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 338 | val loss 2.2297 val acc 14.1843 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 339 | val loss 2.1272 val acc 19.1356 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 340 | val loss 2.0957 val acc 19.0950 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 341 | val loss 2.0612 val acc 21.8141 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 342 | val loss 2.0716 val acc 19.5617 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 343 | val loss 2.0149 val acc 22.6461 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 344 | val loss 2.0505 val acc 20.2110 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 345 | val loss 2.1502 val acc 21.2256 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 346 | val loss 2.2758 val acc 15.2192 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 347 | val loss 2.1569 val acc 17.8774 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 348 | val loss 2.2394 val acc 14.5901 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 349 | val loss 2.0866 val acc 21.9359 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 350 | val loss 2.0576 val acc 23.9448 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 351 | val loss 2.0829 val acc 19.5414 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 352 | val loss 2.0713 val acc 23.5593 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 353 | val loss 2.0581 val acc 19.1558 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 354 | val loss 2.0244 val acc 23.9854 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 355 | val loss 2.1414 val acc 17.1266 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 356 | val loss 2.0977 val acc 23.3563 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 357 | val loss 2.3226 val acc 13.7175 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 358 | val loss 2.2298 val acc 18.0398 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 359 | val loss 2.2452 val acc 10.6128 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 360 | val loss 2.1030 val acc 22.2606 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 361 | val loss 2.0119 val acc 22.6461 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 362 | val loss 1.9763 val acc 25.8117 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 363 | val loss 1.9805 val acc 23.5390 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 364 | val loss 2.0140 val acc 23.4172 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 365 | val loss 2.1330 val acc 22.0576 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 366 | val loss 2.3177 val acc 16.1729 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 367 | val loss 2.3424 val acc 12.2768 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 368 | val loss 2.1406 val acc 17.4716 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 369 | val loss 2.1148 val acc 19.4399 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 370 | val loss 2.0516 val acc 21.1445 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 371 | val loss 2.0529 val acc 21.4489 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 372 | val loss 1.9838 val acc 24.9391 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 373 | val loss 2.0456 val acc 20.5763 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 374 | val loss 2.0941 val acc 22.3823 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 375 | val loss 2.3399 val acc 16.0106 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 376 | val loss 2.1392 val acc 20.0487 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 377 | val loss 2.1376 val acc 18.9529 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 378 | val loss 2.0407 val acc 21.7127 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 379 | val loss 1.9939 val acc 25.5479 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 380 | val loss 1.9425 val acc 26.1769 best val_acc 26.461039
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 381 | val loss 1.8985 val acc 29.0990 best val_acc 29.099026
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 382 | val loss 1.8824 val acc 29.1599 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 383 | val loss 1.9238 val acc 26.2581 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 384 | val loss 2.2304 val acc 22.3823 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 385 | val loss 3.8573 val acc 13.0885 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 386 | val loss 2.3462 val acc 13.6161 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 387 | val loss 2.2134 val acc 16.8222 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 388 | val loss 2.2278 val acc 15.0568 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 389 | val loss 2.3348 val acc 10.4099 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 390 | val loss 2.2982 val acc 11.6883 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 391 | val loss 2.2505 val acc 14.5901 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 392 | val loss 2.1958 val acc 17.9180 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 393 | val loss 2.1309 val acc 20.3328 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 394 | val loss 2.0939 val acc 20.8401 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 395 | val loss 2.0791 val acc 21.2459 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 396 | val loss 2.1433 val acc 19.1761 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 397 | val loss 2.1092 val acc 20.8807 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 398 | val loss 2.2275 val acc 14.1031 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 399 | val loss 2.0735 val acc 22.8693 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 400 | val loss 2.0296 val acc 23.3766 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 401 | val loss 2.0597 val acc 23.3766 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 402 | val loss 2.1798 val acc 21.0836 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 403 | val loss 2.1878 val acc 17.2281 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 404 | val loss 2.1702 val acc 17.2078 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 405 | val loss 2.2386 val acc 14.2045 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 406 | val loss 2.0843 val acc 18.9732 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 407 | val loss 2.0596 val acc 24.8377 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 408 | val loss 2.0728 val acc 25.1623 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 409 | val loss 2.0463 val acc 24.4521 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 410 | val loss 2.1024 val acc 23.8231 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 411 | val loss 2.0139 val acc 26.9481 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 412 | val loss 2.0362 val acc 25.6494 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 413 | val loss 2.0539 val acc 25.5479 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 414 | val loss 2.1987 val acc 20.6981 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 415 | val loss 2.1054 val acc 20.0487 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 416 | val loss 2.0758 val acc 22.4635 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 417 | val loss 2.0229 val acc 24.7362 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 418 | val loss 2.0922 val acc 19.8255 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 419 | val loss 2.0875 val acc 20.5560 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 420 | val loss 2.1729 val acc 17.7760 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 421 | val loss 2.0751 val acc 24.3709 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 422 | val loss 2.0607 val acc 23.3563 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 423 | val loss 2.1118 val acc 21.7127 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 424 | val loss 2.2334 val acc 15.8482 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 425 | val loss 2.1360 val acc 19.2573 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 426 | val loss 2.0853 val acc 20.1299 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 427 | val loss 2.0183 val acc 24.7565 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 428 | val loss 2.0819 val acc 23.6404 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 429 | val loss 2.1580 val acc 23.6607 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 430 | val loss 2.2346 val acc 20.1907 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 431 | val loss 2.4893 val acc 14.9148 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 432 | val loss 2.4109 val acc 10.6534 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 433 | val loss 2.3496 val acc 12.2565 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 434 | val loss 2.3104 val acc 11.3636 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 435 | val loss 2.2203 val acc 16.1120 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 436 | val loss 2.1670 val acc 17.3295 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 437 | val loss 2.1207 val acc 18.2833 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 438 | val loss 2.1187 val acc 18.5065 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 439 | val loss 2.1306 val acc 17.7557 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 440 | val loss 2.0726 val acc 19.5617 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 441 | val loss 2.1236 val acc 18.7500 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 442 | val loss 2.0832 val acc 19.5617 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 443 | val loss 2.1928 val acc 15.5844 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 444 | val loss 2.0843 val acc 19.5414 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 445 | val loss 2.0324 val acc 21.3068 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 446 | val loss 2.0139 val acc 23.3766 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 447 | val loss 2.0067 val acc 23.6201 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 448 | val loss 2.0001 val acc 25.0000 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 449 | val loss 2.1547 val acc 19.0544 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 450 | val loss 2.2265 val acc 21.2054 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 451 | val loss 2.4029 val acc 10.9578 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 452 | val loss 2.3332 val acc 11.8506 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 453 | val loss 2.2773 val acc 11.3636 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 454 | val loss 2.2084 val acc 13.7581 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 455 | val loss 2.1637 val acc 19.9472 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 456 | val loss 2.1550 val acc 17.1063 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 457 | val loss 2.0914 val acc 20.8401 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 458 | val loss 2.0525 val acc 23.8839 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 459 | val loss 2.0826 val acc 20.0284 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 460 | val loss 2.0110 val acc 23.7216 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 461 | val loss 2.0709 val acc 20.9619 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 462 | val loss 2.1780 val acc 21.2256 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 463 | val loss 2.3148 val acc 13.4334 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 464 | val loss 2.2257 val acc 16.6396 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 465 | val loss 2.1893 val acc 16.5787 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 466 | val loss 2.1773 val acc 16.7411 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 467 | val loss 2.1185 val acc 19.6631 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 468 | val loss 2.0859 val acc 20.5560 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 469 | val loss 2.0612 val acc 21.4894 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 470 | val loss 2.0819 val acc 21.2865 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 471 | val loss 2.2409 val acc 22.1185 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 472 | val loss 2.3370 val acc 16.4367 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 473 | val loss 3.2184 val acc 11.9927 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 474 | val loss 2.3429 val acc 11.5463 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 475 | val loss 2.3995 val acc 10.1055 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 476 | val loss 2.3343 val acc 11.3433 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 477 | val loss 2.2542 val acc 13.3726 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 478 | val loss 2.1722 val acc 16.4976 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 479 | val loss 2.2312 val acc 15.6047 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 480 | val loss 2.4583 val acc 9.6997 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 481 | val loss 2.5458 val acc 7.3255 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 482 | val loss 2.3071 val acc 12.5609 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 483 | val loss 2.2188 val acc 14.7524 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 484 | val loss 2.1408 val acc 19.5820 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 485 | val loss 2.1737 val acc 14.8336 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 486 | val loss 2.0823 val acc 18.6282 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 487 | val loss 2.1209 val acc 15.7468 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 488 | val loss 2.4431 val acc 16.5990 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 489 | val loss 2.9001 val acc 11.7492 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 490 | val loss 2.3138 val acc 13.9610 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 491 | val loss 2.1497 val acc 18.9123 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 492 | val loss 2.2393 val acc 13.9002 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 493 | val loss 2.1143 val acc 20.1502 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 494 | val loss 2.0546 val acc 23.0722 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 495 | val loss 2.0179 val acc 22.7476 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 496 | val loss 1.9778 val acc 23.8839 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 497 | val loss 1.9592 val acc 22.2200 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 498 | val loss 2.0072 val acc 23.8231 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 499 | val loss 2.7957 val acc 12.3985 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 500 | val loss 2.1366 val acc 22.0170 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 501 | val loss 2.1423 val acc 19.2370 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 502 | val loss 2.0355 val acc 25.7508 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 503 | val loss 2.0186 val acc 23.2752 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 504 | val loss 1.9729 val acc 27.0901 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 505 | val loss 2.0520 val acc 20.4140 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 506 | val loss 1.9962 val acc 23.9245 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 507 | val loss 1.9407 val acc 27.1713 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 508 | val loss 2.1812 val acc 18.5674 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 509 | val loss 2.1163 val acc 20.1299 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 510 | val loss 2.0886 val acc 20.2719 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 511 | val loss 1.9965 val acc 24.9594 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 512 | val loss 2.0865 val acc 20.5966 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 513 | val loss 1.9204 val acc 27.1510 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 514 | val loss 1.9412 val acc 24.1680 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 515 | val loss 1.9286 val acc 27.2930 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 516 | val loss 1.9792 val acc 24.5739 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 517 | val loss 2.0404 val acc 22.9099 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 518 | val loss 2.1268 val acc 18.5268 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 519 | val loss 2.4304 val acc 17.1672 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 520 | val loss 2.2391 val acc 21.3068 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 521 | val loss 2.3748 val acc 11.2419 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 522 | val loss 2.2446 val acc 13.4740 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 523 | val loss 2.1417 val acc 18.0601 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 524 | val loss 2.1205 val acc 18.0195 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 525 | val loss 2.0137 val acc 21.6924 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 526 | val loss 1.9582 val acc 21.7532 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 527 | val loss 1.9410 val acc 24.1071 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 528 | val loss 2.0852 val acc 19.6631 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 529 | val loss 2.0795 val acc 23.7419 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 530 | val loss 2.2854 val acc 15.1989 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 531 | val loss 2.0981 val acc 22.3417 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 532 | val loss 1.9982 val acc 25.3247 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 533 | val loss 1.9399 val acc 28.0641 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 534 | val loss 1.9166 val acc 27.9627 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 535 | val loss 1.9571 val acc 27.2930 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 536 | val loss 2.2097 val acc 20.7995 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 537 | val loss 2.0726 val acc 21.6924 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 538 | val loss 2.0178 val acc 23.7622 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 539 | val loss 2.1204 val acc 19.6023 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 540 | val loss 1.9611 val acc 23.9854 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 541 | val loss 1.9114 val acc 25.1015 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 542 | val loss 1.9291 val acc 24.4115 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 543 | val loss 1.9601 val acc 25.1420 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 544 | val loss 1.9718 val acc 24.9594 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 545 | val loss 2.0396 val acc 26.2784 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 546 | val loss 2.3239 val acc 21.3880 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 547 | val loss 3.2469 val acc 13.7784 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 548 | val loss 7.0111 val acc 9.6997 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 549 | val loss 10.5491 val acc 8.3604 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 550 | val loss 51.7920 val acc 10.5925 best val_acc 29.159903
# mkrum: at our-agr n_at 10 n_mal_sel 10 e 551 | val loss 40391.5267 val acc 10.3693 best val_acc 29.159903
# val loss 40391.526710 too high

# %%
'''
MIN-MAX attack
'''
def our_attack_dist(all_updates, model_re, n_attackers, dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)  # unit vector, dir opp to good dir
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)

    lamda = torch.Tensor([10.0]).float().cuda()
    # print(lamda)
    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0
    
    distances = []
    for update in all_updates:
        distance = torch.norm((all_updates - update), dim=1) ** 2
        distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)
    
    max_distance = torch.max(distances)
    del distances

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        distance = torch.norm((all_updates - mal_update), dim=1) ** 2
        max_d = torch.max(distance)
        
        if max_d <= max_distance:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    mal_update = (model_re - lamda_succ * deviation)
    
    return mal_update

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='mkrum'
multi_k = False
candidates = []

at_type='min-max'
dev_type ='std'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    candidates = []

    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_median(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-max':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_dist(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-sum':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_score(malicious_grads, agg_grads, n_attacker, dev_type)

            mal_updates = torch.stack([mal_update] * n_attacker)
            malicious_grads = torch.cat((mal_updates, user_grads), 0)

        if epoch_num==0: print('malicious_grads shape ', malicious_grads.shape)

        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break
            
        epoch_num+=1
# Out:
# malicious_grads shape  torch.Size([50, 2472266])
# multi krum is  True
# mkrum: at min-max n_at 10 n_mal_sel 5 e 0 | val loss 2.3030 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1 | val loss 2.3024 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 5 e 2 | val loss 2.3018 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 4 e 3 | val loss 2.3012 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 5 e 4 | val loss 2.3004 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 4 e 5 | val loss 2.2996 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 5 e 6 | val loss 2.2987 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 4 e 7 | val loss 2.2977 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 5 e 8 | val loss 2.2963 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 4 e 9 | val loss 2.2948 val acc 10.0446 best val_acc 10.044643
# mkrum: at min-max n_at 10 n_mal_sel 4 e 10 | val loss 2.2928 val acc 11.9115 best val_acc 11.911526
# mkrum: at min-max n_at 10 n_mal_sel 4 e 11 | val loss 2.2902 val acc 13.2305 best val_acc 13.230519
# mkrum: at min-max n_at 10 n_mal_sel 4 e 12 | val loss 2.2867 val acc 12.7232 best val_acc 13.230519
# mkrum: at min-max n_at 10 n_mal_sel 4 e 13 | val loss 2.2820 val acc 13.6567 best val_acc 13.656656
# mkrum: at min-max n_at 10 n_mal_sel 5 e 14 | val loss 2.2757 val acc 14.6307 best val_acc 14.630682
# mkrum: at min-max n_at 10 n_mal_sel 4 e 15 | val loss 2.2675 val acc 14.2248 best val_acc 14.630682
# mkrum: at min-max n_at 10 n_mal_sel 5 e 16 | val loss 2.2575 val acc 14.6916 best val_acc 14.691558
# mkrum: at min-max n_at 10 n_mal_sel 5 e 17 | val loss 2.2438 val acc 17.7760 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 5 e 18 | val loss 2.2311 val acc 17.2890 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 4 e 19 | val loss 2.2221 val acc 17.7557 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 3 e 20 | val loss 2.3697 val acc 14.0219 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 4 e 21 | val loss 2.3176 val acc 9.9432 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 6 e 22 | val loss 2.3017 val acc 10.1055 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 5 e 23 | val loss 2.2956 val acc 10.3896 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 5 e 24 | val loss 2.2899 val acc 10.5519 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 4 e 25 | val loss 2.2847 val acc 10.3896 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 6 e 26 | val loss 2.2789 val acc 10.8969 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 6 e 27 | val loss 2.2723 val acc 11.0187 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 5 e 28 | val loss 2.2646 val acc 11.1201 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 4 e 29 | val loss 2.2568 val acc 11.2216 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 5 e 30 | val loss 2.2479 val acc 11.6477 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 5 e 31 | val loss 2.2384 val acc 12.0942 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 4 e 32 | val loss 2.2274 val acc 12.9058 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 4 e 33 | val loss 2.2174 val acc 13.2305 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 5 e 34 | val loss 2.2058 val acc 14.1640 best val_acc 17.775974
# mkrum: at min-max n_at 10 n_mal_sel 4 e 35 | val loss 2.1929 val acc 21.6924 best val_acc 21.692370
# mkrum: at min-max n_at 10 n_mal_sel 4 e 36 | val loss 2.1792 val acc 22.7273 best val_acc 22.727273
# mkrum: at min-max n_at 10 n_mal_sel 4 e 37 | val loss 2.1679 val acc 23.3969 best val_acc 23.396916
# mkrum: at min-max n_at 10 n_mal_sel 5 e 38 | val loss 2.1585 val acc 23.5187 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 39 | val loss 2.2398 val acc 16.5990 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 40 | val loss 2.2571 val acc 20.2719 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 41 | val loss 2.3036 val acc 10.8360 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 42 | val loss 2.2931 val acc 12.0942 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 43 | val loss 2.2838 val acc 11.3433 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 44 | val loss 2.2702 val acc 13.5958 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 45 | val loss 2.2924 val acc 10.2881 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 46 | val loss 2.3081 val acc 9.7403 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 47 | val loss 2.2867 val acc 9.6388 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 48 | val loss 2.2688 val acc 9.4968 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 49 | val loss 2.2582 val acc 9.5779 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 50 | val loss 2.2436 val acc 9.6997 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 51 | val loss 2.2311 val acc 10.3693 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 52 | val loss 2.2172 val acc 11.6680 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 53 | val loss 2.2049 val acc 13.5349 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 54 | val loss 2.2230 val acc 13.0479 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 55 | val loss 2.3093 val acc 10.9578 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 56 | val loss 2.2548 val acc 14.9351 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 57 | val loss 2.2084 val acc 14.2045 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 58 | val loss 2.1747 val acc 17.5731 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 59 | val loss 2.2689 val acc 14.3060 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 60 | val loss 2.3450 val acc 10.5317 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 3 e 61 | val loss 2.2974 val acc 10.3287 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 62 | val loss 2.2869 val acc 11.7086 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 63 | val loss 2.2683 val acc 13.8596 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 64 | val loss 2.2363 val acc 17.1266 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 65 | val loss 2.1937 val acc 17.0455 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 7 e 66 | val loss 2.1446 val acc 21.4083 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 67 | val loss 2.2076 val acc 16.0917 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 68 | val loss 2.4425 val acc 10.6737 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 69 | val loss 2.2400 val acc 17.9180 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 70 | val loss 2.2160 val acc 17.6542 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 71 | val loss 2.2129 val acc 17.2890 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 72 | val loss 2.1768 val acc 17.8774 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 73 | val loss 2.1962 val acc 17.8166 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 74 | val loss 2.1100 val acc 18.6080 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 75 | val loss 2.0863 val acc 17.4919 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 76 | val loss 2.1098 val acc 17.9992 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 77 | val loss 2.1833 val acc 15.8076 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 78 | val loss 2.1284 val acc 17.2078 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 79 | val loss 2.1407 val acc 16.9846 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 80 | val loss 2.1197 val acc 19.4196 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 81 | val loss 2.1932 val acc 15.2192 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 82 | val loss 2.1223 val acc 15.6859 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 83 | val loss 2.0772 val acc 20.7792 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 84 | val loss 2.0738 val acc 20.4140 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 4 e 85 | val loss 2.2561 val acc 15.5235 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 86 | val loss 2.1991 val acc 17.2281 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 87 | val loss 2.1936 val acc 17.1875 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 88 | val loss 2.1416 val acc 16.8628 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 89 | val loss 2.1392 val acc 18.5877 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 90 | val loss 2.0774 val acc 18.8109 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 91 | val loss 2.1268 val acc 19.7849 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 3 e 92 | val loss 2.0798 val acc 22.1185 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 93 | val loss 2.1653 val acc 20.9213 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 94 | val loss 2.1463 val acc 20.0893 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 6 e 95 | val loss 2.2129 val acc 15.9497 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 96 | val loss 2.1138 val acc 19.9067 best val_acc 23.518669
# mkrum: at min-max n_at 10 n_mal_sel 5 e 97 | val loss 2.0378 val acc 26.2581 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 7 e 98 | val loss 2.0445 val acc 23.4578 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 99 | val loss 2.3062 val acc 15.5032 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 100 | val loss 2.3149 val acc 13.1088 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 101 | val loss 2.2398 val acc 10.5925 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 102 | val loss 2.1638 val acc 17.2687 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 103 | val loss 2.1115 val acc 20.4748 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 104 | val loss 2.0654 val acc 22.8084 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 4 e 105 | val loss 2.0589 val acc 22.0779 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 106 | val loss 2.2297 val acc 13.2508 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 107 | val loss 2.1051 val acc 17.4716 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 108 | val loss 2.0714 val acc 20.8401 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 4 e 109 | val loss 2.0498 val acc 21.2459 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 110 | val loss 2.0633 val acc 23.1737 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 111 | val loss 2.4032 val acc 11.0998 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 112 | val loss 2.2382 val acc 16.7817 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 7 e 113 | val loss 2.1845 val acc 16.5179 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 4 e 114 | val loss 2.1423 val acc 21.1851 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 115 | val loss 2.1427 val acc 19.1964 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 116 | val loss 2.1661 val acc 19.9472 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 4 e 117 | val loss 2.0838 val acc 20.0893 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 4 e 118 | val loss 2.1963 val acc 15.0365 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 4 e 119 | val loss 2.0568 val acc 20.2516 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 120 | val loss 2.0462 val acc 23.5795 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 121 | val loss 2.1524 val acc 19.5211 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 122 | val loss 1.9994 val acc 20.5560 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 123 | val loss 2.0684 val acc 23.0925 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 124 | val loss 2.0872 val acc 21.8344 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 5 e 125 | val loss 2.2652 val acc 15.9294 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 126 | val loss 2.1019 val acc 21.0227 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 127 | val loss 2.0075 val acc 23.4578 best val_acc 26.258117
# mkrum: at min-max n_at 10 n_mal_sel 6 e 128 | val loss 1.9417 val acc 26.6843 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 129 | val loss 1.9362 val acc 26.5016 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 130 | val loss 2.0858 val acc 19.0544 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 131 | val loss 2.4844 val acc 17.3498 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 132 | val loss 2.3025 val acc 10.6940 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 133 | val loss 2.2352 val acc 15.8685 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 134 | val loss 2.1740 val acc 16.5990 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 135 | val loss 2.2551 val acc 13.3929 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 136 | val loss 2.6345 val acc 15.7468 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 137 | val loss 2.3566 val acc 9.9432 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 138 | val loss 2.3080 val acc 9.9432 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 139 | val loss 2.2942 val acc 9.9432 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 140 | val loss 2.2721 val acc 9.9432 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 141 | val loss 2.2440 val acc 9.9635 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 142 | val loss 2.2180 val acc 10.2476 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 143 | val loss 2.1950 val acc 11.5463 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 144 | val loss 2.1763 val acc 11.7492 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 145 | val loss 2.1597 val acc 14.5698 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 146 | val loss 2.1417 val acc 18.9529 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 147 | val loss 2.1214 val acc 19.7646 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 148 | val loss 2.0955 val acc 19.6226 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 149 | val loss 2.1443 val acc 17.3701 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 150 | val loss 2.9213 val acc 9.6388 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 151 | val loss 2.2921 val acc 13.6972 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 152 | val loss 2.2763 val acc 17.0860 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 153 | val loss 2.2539 val acc 17.9992 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 154 | val loss 2.2243 val acc 17.6136 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 155 | val loss 2.1950 val acc 18.1412 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 156 | val loss 2.1698 val acc 18.3442 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 157 | val loss 2.1499 val acc 18.4659 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 158 | val loss 2.1601 val acc 17.3093 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 159 | val loss 2.2335 val acc 16.1120 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 160 | val loss 2.1808 val acc 17.2484 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 161 | val loss 2.1492 val acc 18.1818 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 162 | val loss 2.1258 val acc 20.0690 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 163 | val loss 2.1120 val acc 20.9010 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 164 | val loss 2.0975 val acc 22.8693 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 165 | val loss 2.1521 val acc 18.2427 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 166 | val loss 2.1089 val acc 21.6924 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 167 | val loss 2.1293 val acc 20.3734 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 168 | val loss 2.1028 val acc 21.9765 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 169 | val loss 2.2068 val acc 15.7062 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 170 | val loss 2.1872 val acc 17.5122 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 2 e 171 | val loss 2.1819 val acc 17.3701 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 172 | val loss 2.0725 val acc 21.6924 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 173 | val loss 2.0348 val acc 22.1794 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 174 | val loss 2.0233 val acc 20.2313 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 175 | val loss 2.1644 val acc 17.5933 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 176 | val loss 2.0869 val acc 20.0487 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 177 | val loss 2.1306 val acc 21.6112 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 178 | val loss 4.7493 val acc 11.2216 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 179 | val loss 2.3275 val acc 11.5463 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 180 | val loss 2.2730 val acc 12.0536 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 181 | val loss 2.3267 val acc 12.1347 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 182 | val loss 2.2970 val acc 10.8360 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 183 | val loss 2.2780 val acc 11.2622 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 184 | val loss 2.2543 val acc 12.4391 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 185 | val loss 2.2120 val acc 14.0828 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 186 | val loss 2.3328 val acc 11.2825 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 187 | val loss 2.3128 val acc 9.7606 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 188 | val loss 2.3068 val acc 9.9229 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 189 | val loss 2.2991 val acc 10.4505 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 190 | val loss 2.2874 val acc 11.2013 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 191 | val loss 2.2760 val acc 11.4448 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 192 | val loss 2.2638 val acc 12.0536 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 8 e 193 | val loss 2.2521 val acc 13.9002 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 194 | val loss 2.2325 val acc 16.1323 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 195 | val loss 2.2190 val acc 15.8482 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 196 | val loss 2.2095 val acc 16.9846 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 197 | val loss 2.1830 val acc 19.0950 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 198 | val loss 2.1930 val acc 18.3036 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 199 | val loss 2.2647 val acc 19.1558 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 200 | val loss 2.3078 val acc 13.2914 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 201 | val loss 2.2967 val acc 11.7492 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 202 | val loss 2.2774 val acc 13.8190 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 8 e 203 | val loss 2.2637 val acc 14.3466 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 8 e 204 | val loss 2.2457 val acc 14.4886 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 205 | val loss 2.2268 val acc 17.1266 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 206 | val loss 2.2069 val acc 17.5122 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 207 | val loss 2.1947 val acc 18.9732 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 208 | val loss 2.1810 val acc 17.7354 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 209 | val loss 2.1711 val acc 20.2719 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 210 | val loss 2.1677 val acc 20.4140 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 211 | val loss 2.2382 val acc 20.4545 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 8 e 212 | val loss 2.2672 val acc 16.0106 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 213 | val loss 2.2325 val acc 18.1006 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 214 | val loss 2.2578 val acc 15.3206 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 215 | val loss 2.2367 val acc 17.8774 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 216 | val loss 2.2133 val acc 16.1729 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 217 | val loss 2.2915 val acc 16.2338 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 8 e 218 | val loss 2.2990 val acc 12.0536 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 219 | val loss 2.2367 val acc 16.3352 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 220 | val loss 2.2391 val acc 18.3036 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 221 | val loss 2.3006 val acc 12.0536 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 222 | val loss 2.2498 val acc 14.7321 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 223 | val loss 2.1747 val acc 21.2865 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 224 | val loss 2.1533 val acc 20.0893 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 225 | val loss 2.1333 val acc 21.0227 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 226 | val loss 2.1332 val acc 21.2662 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 227 | val loss 2.1955 val acc 17.7557 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 228 | val loss 2.1697 val acc 20.1502 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 229 | val loss 2.3054 val acc 11.8101 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 230 | val loss 2.2365 val acc 16.0308 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 231 | val loss 2.1807 val acc 18.6080 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 232 | val loss 2.2277 val acc 16.2946 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 233 | val loss 2.1384 val acc 20.7183 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 234 | val loss 2.1012 val acc 21.7735 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 235 | val loss 2.0865 val acc 21.2865 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 236 | val loss 2.0790 val acc 22.8693 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 237 | val loss 2.0872 val acc 22.2403 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 238 | val loss 2.1637 val acc 16.2946 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 239 | val loss 2.1024 val acc 20.2313 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 240 | val loss 2.0646 val acc 22.6867 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 241 | val loss 2.0548 val acc 24.5942 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 242 | val loss 2.0657 val acc 21.5300 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 243 | val loss 2.3106 val acc 19.8864 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 244 | val loss 2.3759 val acc 9.9229 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 245 | val loss 2.3723 val acc 8.1778 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 246 | val loss 2.3604 val acc 9.9635 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 247 | val loss 2.3605 val acc 9.3141 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 248 | val loss 2.3481 val acc 10.0852 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 249 | val loss 2.3425 val acc 9.2330 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 250 | val loss 2.3367 val acc 9.8823 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 251 | val loss 2.3302 val acc 10.0852 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 252 | val loss 2.3236 val acc 7.6907 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 253 | val loss 2.3151 val acc 8.5227 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 254 | val loss 2.3056 val acc 10.0041 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 255 | val loss 2.2850 val acc 11.5666 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 256 | val loss 2.2478 val acc 15.0365 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 257 | val loss 2.2791 val acc 13.9813 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 258 | val loss 2.1704 val acc 18.6080 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 259 | val loss 2.2008 val acc 19.8661 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 260 | val loss 2.2928 val acc 11.6883 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 261 | val loss 2.2291 val acc 14.5901 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 262 | val loss 2.2833 val acc 16.7005 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 263 | val loss 2.2784 val acc 12.3985 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 264 | val loss 2.2152 val acc 16.7411 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 265 | val loss 2.2005 val acc 16.7411 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 266 | val loss 2.1854 val acc 17.1266 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 2 e 267 | val loss 2.1706 val acc 18.6688 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 268 | val loss 2.1570 val acc 16.5990 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 269 | val loss 2.1443 val acc 17.8166 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 270 | val loss 2.1601 val acc 19.3182 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 3 e 271 | val loss 2.1812 val acc 16.6396 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 272 | val loss 2.1634 val acc 20.8604 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 4 e 273 | val loss 2.1063 val acc 21.4286 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 274 | val loss 2.1316 val acc 20.7792 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 275 | val loss 2.1937 val acc 16.3758 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 276 | val loss 2.0899 val acc 21.3880 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 277 | val loss 2.0751 val acc 22.8490 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 6 e 278 | val loss 2.0971 val acc 20.6575 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 279 | val loss 2.0647 val acc 24.4927 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 5 e 280 | val loss 2.0868 val acc 21.6924 best val_acc 26.684253
# mkrum: at min-max n_at 10 n_mal_sel 7 e 281 | val loss 2.0234 val acc 27.9627 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 282 | val loss 2.0319 val acc 24.7971 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 283 | val loss 2.2590 val acc 24.4521 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 284 | val loss 2.3675 val acc 9.9432 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 285 | val loss 2.3662 val acc 9.2735 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 286 | val loss 2.3215 val acc 11.4245 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 287 | val loss 2.3227 val acc 12.6420 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 288 | val loss 2.2313 val acc 14.1031 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 289 | val loss 2.2105 val acc 15.8076 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 290 | val loss 2.1850 val acc 18.3036 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 291 | val loss 2.1766 val acc 17.2687 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 292 | val loss 2.1741 val acc 20.4951 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 293 | val loss 2.2476 val acc 21.1648 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 294 | val loss 2.3179 val acc 11.7492 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 295 | val loss 2.3012 val acc 12.9261 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 296 | val loss 2.2538 val acc 15.7468 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 297 | val loss 2.1852 val acc 19.6429 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 298 | val loss 2.1551 val acc 22.1591 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 299 | val loss 2.2191 val acc 14.4886 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 300 | val loss 2.1135 val acc 17.8977 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 301 | val loss 2.0889 val acc 22.0170 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 302 | val loss 2.0678 val acc 24.2492 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 303 | val loss 2.0964 val acc 23.6810 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 304 | val loss 2.1025 val acc 23.1737 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 305 | val loss 2.1978 val acc 17.5933 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 306 | val loss 2.2287 val acc 18.0398 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 307 | val loss 2.2509 val acc 13.4537 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 308 | val loss 2.2077 val acc 16.1120 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 309 | val loss 2.1710 val acc 16.7411 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 310 | val loss 2.1777 val acc 21.1039 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 311 | val loss 2.2567 val acc 13.1088 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 312 | val loss 2.1675 val acc 16.3758 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 313 | val loss 2.1215 val acc 19.4602 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 314 | val loss 2.1334 val acc 15.8888 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 315 | val loss 2.1876 val acc 17.1875 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 316 | val loss 2.2272 val acc 16.2338 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 317 | val loss 2.0935 val acc 20.7792 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 318 | val loss 2.1483 val acc 17.2890 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 319 | val loss 2.2426 val acc 14.7524 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 320 | val loss 2.1938 val acc 16.8019 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 321 | val loss 2.2030 val acc 14.4075 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 322 | val loss 2.0814 val acc 20.2110 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 323 | val loss 2.0799 val acc 19.1356 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 324 | val loss 2.0805 val acc 19.7646 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 325 | val loss 2.2172 val acc 14.1843 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 326 | val loss 2.1949 val acc 19.1356 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 327 | val loss 2.2557 val acc 12.8450 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 328 | val loss 2.1301 val acc 18.1209 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 329 | val loss 2.0813 val acc 20.1705 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 330 | val loss 2.1338 val acc 17.8166 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 331 | val loss 2.1029 val acc 21.6721 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 332 | val loss 2.2317 val acc 14.4886 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 333 | val loss 2.0873 val acc 20.4140 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 334 | val loss 2.0157 val acc 25.0000 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 335 | val loss 1.9944 val acc 25.0000 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 336 | val loss 1.9929 val acc 27.2321 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 337 | val loss 2.0765 val acc 19.8052 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 338 | val loss 2.0359 val acc 24.3506 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 339 | val loss 2.1015 val acc 20.1299 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 340 | val loss 2.4309 val acc 21.7330 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 341 | val loss 2.4176 val acc 9.9229 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 342 | val loss 2.4010 val acc 9.2532 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 343 | val loss 2.3837 val acc 8.4416 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 344 | val loss 2.3570 val acc 11.1404 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 345 | val loss 2.7144 val acc 8.5633 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 346 | val loss 2.3248 val acc 11.8912 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 347 | val loss 2.6195 val acc 7.8734 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 348 | val loss 2.3730 val acc 9.9229 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 349 | val loss 2.3216 val acc 12.8044 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 350 | val loss 2.2285 val acc 16.0308 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 351 | val loss 2.2094 val acc 17.9586 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 352 | val loss 2.2005 val acc 16.4976 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 353 | val loss 2.2399 val acc 18.9529 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 354 | val loss 2.3341 val acc 11.2013 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 355 | val loss 2.2759 val acc 14.1437 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 356 | val loss 2.1860 val acc 17.4919 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 357 | val loss 2.1448 val acc 19.2979 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 358 | val loss 2.1453 val acc 19.0544 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 359 | val loss 2.2033 val acc 21.6721 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 360 | val loss 2.3370 val acc 10.2476 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 361 | val loss 2.3012 val acc 11.4042 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 362 | val loss 2.2375 val acc 14.4481 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 363 | val loss 2.2063 val acc 17.2890 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 364 | val loss 2.2717 val acc 13.3117 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 365 | val loss 2.1774 val acc 19.0747 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 366 | val loss 2.1433 val acc 21.3677 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 367 | val loss 2.1398 val acc 19.0544 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 368 | val loss 2.1209 val acc 22.0373 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 369 | val loss 2.2910 val acc 19.9878 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 370 | val loss 2.2477 val acc 15.1786 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 371 | val loss 2.2360 val acc 17.4919 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 372 | val loss 2.2277 val acc 14.9554 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 373 | val loss 2.6883 val acc 9.9432 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 374 | val loss 2.3335 val acc 10.7549 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 375 | val loss 2.2643 val acc 13.9205 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 376 | val loss 2.2427 val acc 15.8888 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 377 | val loss 2.2364 val acc 16.1120 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 378 | val loss 2.2268 val acc 15.8076 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 379 | val loss 2.2162 val acc 15.6656 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 380 | val loss 2.2090 val acc 17.0455 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 381 | val loss 2.2006 val acc 16.1526 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 382 | val loss 2.1977 val acc 17.8571 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 383 | val loss 2.1937 val acc 15.8482 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 384 | val loss 2.1850 val acc 16.1526 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 385 | val loss 2.1914 val acc 14.8539 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 386 | val loss 2.1697 val acc 17.8977 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 387 | val loss 2.1706 val acc 17.4107 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 388 | val loss 2.2179 val acc 14.2654 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 389 | val loss 2.2251 val acc 13.9002 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 390 | val loss 2.1724 val acc 16.4367 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 391 | val loss 2.1604 val acc 16.7005 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 392 | val loss 2.1517 val acc 16.7208 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 393 | val loss 2.1457 val acc 17.4107 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 394 | val loss 2.1590 val acc 15.6047 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 395 | val loss 2.1434 val acc 16.4164 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 396 | val loss 2.0953 val acc 18.7703 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 397 | val loss 2.2433 val acc 17.8369 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 398 | val loss 2.3734 val acc 9.9635 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 399 | val loss 2.3567 val acc 7.9343 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 400 | val loss 2.3298 val acc 10.6737 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 401 | val loss 2.3040 val acc 9.2938 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 402 | val loss 2.2703 val acc 11.7289 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 403 | val loss 2.2482 val acc 12.8044 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 404 | val loss 2.2251 val acc 15.9497 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 405 | val loss 2.2087 val acc 15.3409 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 406 | val loss 2.2027 val acc 15.5844 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 407 | val loss 2.2185 val acc 14.3669 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 408 | val loss 2.1814 val acc 16.0917 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 409 | val loss 2.1779 val acc 16.7817 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 410 | val loss 2.1761 val acc 16.6599 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 411 | val loss 2.1978 val acc 15.5032 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 412 | val loss 2.1498 val acc 15.0162 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 413 | val loss 2.1376 val acc 17.8774 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 414 | val loss 2.1307 val acc 19.5211 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 415 | val loss 2.1423 val acc 17.4310 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 416 | val loss 2.1062 val acc 19.9878 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 417 | val loss 2.1734 val acc 17.5933 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 2 e 418 | val loss 2.7348 val acc 16.4164 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 419 | val loss 2.3645 val acc 9.9026 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 420 | val loss 2.3559 val acc 9.9026 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 421 | val loss 2.3473 val acc 9.9838 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 422 | val loss 2.3556 val acc 9.6185 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 423 | val loss 2.3356 val acc 9.9838 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 424 | val loss 2.3308 val acc 9.8823 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 425 | val loss 2.3317 val acc 9.7200 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 426 | val loss 2.3232 val acc 10.6534 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 427 | val loss 2.3222 val acc 9.7403 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 428 | val loss 2.3175 val acc 9.6388 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 429 | val loss 2.3185 val acc 9.6388 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 430 | val loss 2.3134 val acc 9.6388 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 431 | val loss 2.3168 val acc 12.3985 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 432 | val loss 2.3102 val acc 9.6388 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 433 | val loss 2.3086 val acc 9.6388 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 434 | val loss 2.3074 val acc 9.6591 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 435 | val loss 2.3082 val acc 9.9635 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 436 | val loss 2.3043 val acc 9.8823 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 437 | val loss 2.3061 val acc 10.2273 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 438 | val loss 2.2987 val acc 10.3084 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 7 e 439 | val loss 2.2924 val acc 10.4708 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 440 | val loss 2.2789 val acc 11.8101 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 441 | val loss 2.3784 val acc 10.5722 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 442 | val loss 2.2766 val acc 11.1607 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 443 | val loss 2.2679 val acc 14.4278 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 444 | val loss 2.2620 val acc 14.0422 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 445 | val loss 2.2633 val acc 13.0682 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 446 | val loss 2.2527 val acc 14.1843 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 447 | val loss 2.2479 val acc 13.8393 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 448 | val loss 2.2493 val acc 14.2045 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 449 | val loss 2.2367 val acc 14.7119 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 450 | val loss 2.2392 val acc 15.8076 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 451 | val loss 2.2555 val acc 11.3433 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 452 | val loss 2.2342 val acc 15.6453 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 453 | val loss 2.2124 val acc 15.2800 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 454 | val loss 2.2371 val acc 16.9846 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 455 | val loss 2.3033 val acc 10.0446 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 456 | val loss 2.2630 val acc 13.5958 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 457 | val loss 2.2013 val acc 14.0016 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 458 | val loss 2.2008 val acc 17.3904 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 459 | val loss 2.2891 val acc 11.5869 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 460 | val loss 2.2415 val acc 12.0739 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 461 | val loss 2.2111 val acc 15.8076 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 462 | val loss 2.1938 val acc 16.1323 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 463 | val loss 2.1830 val acc 16.5990 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 464 | val loss 2.1721 val acc 16.6396 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 465 | val loss 2.1986 val acc 17.7963 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 466 | val loss 2.2877 val acc 12.9667 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 467 | val loss 2.2051 val acc 16.1932 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 468 | val loss 2.1864 val acc 18.6891 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 469 | val loss 2.2662 val acc 11.6071 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 470 | val loss 2.2047 val acc 15.0771 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 4 e 471 | val loss 2.1948 val acc 16.3352 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 3 e 472 | val loss 2.2026 val acc 13.7987 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 473 | val loss 2.1721 val acc 17.4310 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 5 e 474 | val loss 2.1635 val acc 14.7727 best val_acc 27.962662
# mkrum: at min-max n_at 10 n_mal_sel 6 e 475 | val loss 2.1826 val acc 18.4253 best val_acc 27.962662
# ...
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1044 | val loss 2.3121 val acc 10.6128 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1045 | val loss 2.3129 val acc 10.5114 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1046 | val loss 2.3131 val acc 10.5519 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1047 | val loss 2.3127 val acc 10.5722 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1048 | val loss 2.3110 val acc 10.6331 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1049 | val loss 2.3125 val acc 9.0706 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1050 | val loss 2.3093 val acc 10.6331 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1051 | val loss 2.3132 val acc 7.9140 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1052 | val loss 2.3025 val acc 10.1867 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1053 | val loss 2.3026 val acc 10.2070 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1054 | val loss 2.3029 val acc 10.1055 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1055 | val loss 2.3033 val acc 10.2476 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1056 | val loss 2.3038 val acc 10.2476 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1057 | val loss 2.3047 val acc 10.5925 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1058 | val loss 2.3069 val acc 10.5114 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1059 | val loss 2.3087 val acc 11.0390 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1060 | val loss 2.3077 val acc 11.0187 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1061 | val loss 2.3047 val acc 10.4099 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1062 | val loss 2.3066 val acc 10.6737 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1063 | val loss 2.3080 val acc 12.0130 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1064 | val loss 4.9130 val acc 9.6591 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1065 | val loss 2.3676 val acc 6.9399 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1066 | val loss 2.3129 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1067 | val loss 2.3144 val acc 9.3750 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1068 | val loss 2.3183 val acc 9.8620 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1069 | val loss 2.3064 val acc 12.7638 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1070 | val loss 2.3739 val acc 7.8531 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1071 | val loss 2.3181 val acc 9.8011 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1072 | val loss 2.3152 val acc 9.9229 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1073 | val loss 2.3127 val acc 10.0649 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1074 | val loss 2.3087 val acc 12.2971 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1075 | val loss 2.3107 val acc 13.7987 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1076 | val loss 2.3114 val acc 10.0649 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1077 | val loss 2.3103 val acc 10.0852 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1078 | val loss 2.3086 val acc 10.7955 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1079 | val loss 2.2989 val acc 16.9846 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1080 | val loss 2.3062 val acc 10.3693 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1081 | val loss 2.3103 val acc 10.2070 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1082 | val loss 2.3104 val acc 10.2476 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1083 | val loss 2.3095 val acc 10.2679 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1084 | val loss 2.3078 val acc 10.2679 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1085 | val loss 2.3056 val acc 11.7695 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1086 | val loss 2.2952 val acc 9.2735 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1087 | val loss 2.2997 val acc 10.5925 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1088 | val loss 2.3063 val acc 10.3084 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1089 | val loss 2.3045 val acc 10.2070 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1090 | val loss 2.2998 val acc 12.2768 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1091 | val loss 2.3140 val acc 12.9261 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1092 | val loss 2.3044 val acc 10.2881 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1093 | val loss 2.2900 val acc 16.7208 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1094 | val loss 2.3960 val acc 12.9870 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1095 | val loss 2.2980 val acc 16.9643 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1096 | val loss 2.2881 val acc 10.5925 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1097 | val loss 2.2688 val acc 15.8888 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1098 | val loss 2.4573 val acc 10.7549 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1099 | val loss 2.3999 val acc 10.5317 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1100 | val loss 2.3108 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1101 | val loss 2.3094 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1102 | val loss 2.3082 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1103 | val loss 2.3072 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1104 | val loss 2.3064 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1105 | val loss 2.3056 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1106 | val loss 2.3046 val acc 9.9838 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1107 | val loss 2.3022 val acc 10.1258 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1108 | val loss 2.2883 val acc 11.5666 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1109 | val loss 2.2808 val acc 11.5057 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1110 | val loss 2.2952 val acc 13.4537 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1111 | val loss 2.3160 val acc 10.3896 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1112 | val loss 2.3066 val acc 10.0649 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1113 | val loss 2.3058 val acc 10.0852 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1114 | val loss 2.3050 val acc 10.0649 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1115 | val loss 2.3045 val acc 10.0649 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1116 | val loss 2.3039 val acc 10.1055 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1117 | val loss 2.3034 val acc 10.0852 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1118 | val loss 2.3030 val acc 10.0852 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1119 | val loss 2.3026 val acc 10.1055 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1120 | val loss 2.3022 val acc 10.1055 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1121 | val loss 2.3014 val acc 10.2273 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1122 | val loss 2.2962 val acc 11.2622 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1123 | val loss 2.2884 val acc 11.0593 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1124 | val loss 2.2772 val acc 15.8279 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1125 | val loss 2.3103 val acc 10.5114 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1126 | val loss 2.2992 val acc 10.3490 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1127 | val loss 2.2734 val acc 17.5528 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1128 | val loss 2.2484 val acc 14.4278 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1129 | val loss 2.2779 val acc 18.0398 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1130 | val loss 2.2733 val acc 16.1323 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1131 | val loss 2.2742 val acc 13.8190 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1132 | val loss 2.2997 val acc 13.5349 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1133 | val loss 2.2720 val acc 17.6948 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1134 | val loss 2.2453 val acc 16.8831 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1135 | val loss 2.7544 val acc 12.3174 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1136 | val loss 2.7718 val acc 9.9635 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1137 | val loss 2.3362 val acc 15.0771 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1138 | val loss 2.3161 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1139 | val loss 2.3137 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1140 | val loss 2.3116 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1141 | val loss 2.3100 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1142 | val loss 2.3084 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1143 | val loss 2.3062 val acc 9.9026 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1144 | val loss 2.2917 val acc 12.8450 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1145 | val loss 2.2935 val acc 11.0187 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1146 | val loss 2.2819 val acc 14.4481 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1147 | val loss 2.4479 val acc 9.8620 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1148 | val loss 2.3108 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1149 | val loss 2.3093 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1150 | val loss 2.3080 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1151 | val loss 2.3070 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1152 | val loss 2.3061 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1153 | val loss 2.3054 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1154 | val loss 2.3046 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1155 | val loss 2.3040 val acc 9.9635 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1156 | val loss 2.3031 val acc 9.9432 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1157 | val loss 2.3022 val acc 10.1867 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1158 | val loss 2.3004 val acc 10.4505 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1159 | val loss 2.2962 val acc 13.3117 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1160 | val loss 2.2895 val acc 14.1437 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1161 | val loss 2.2821 val acc 15.0771 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1162 | val loss 2.2850 val acc 14.1234 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1163 | val loss 2.2703 val acc 15.1989 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1164 | val loss 2.3133 val acc 12.1956 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1165 | val loss 2.3032 val acc 10.1867 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1166 | val loss 2.2926 val acc 12.9667 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1167 | val loss 2.2641 val acc 16.7817 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1168 | val loss 2.2603 val acc 15.9700 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 3 e 1169 | val loss 2.2747 val acc 17.0860 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1170 | val loss 2.2415 val acc 15.6656 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1171 | val loss 2.2276 val acc 18.5674 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1172 | val loss 2.2744 val acc 15.1380 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1173 | val loss 2.3088 val acc 12.7841 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1174 | val loss 2.2977 val acc 12.4188 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1175 | val loss 2.2907 val acc 12.8653 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1176 | val loss 2.2592 val acc 15.0365 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1177 | val loss 2.2333 val acc 18.0804 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1178 | val loss 2.2136 val acc 18.1818 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1179 | val loss 2.2102 val acc 17.8774 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1180 | val loss 2.1944 val acc 19.2370 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1181 | val loss 2.3134 val acc 15.7062 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1182 | val loss 2.3447 val acc 13.0073 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1183 | val loss 2.3105 val acc 11.2825 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 4 e 1184 | val loss 2.2974 val acc 12.6015 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1185 | val loss 2.2908 val acc 13.0682 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1186 | val loss 2.2882 val acc 12.9870 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1187 | val loss 2.2856 val acc 13.0479 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1188 | val loss 2.2799 val acc 13.5755 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1189 | val loss 2.2751 val acc 14.4886 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1190 | val loss 2.2696 val acc 14.9554 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1191 | val loss 2.2653 val acc 15.5844 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1192 | val loss 2.2564 val acc 16.0106 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1193 | val loss 2.2518 val acc 16.0106 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1194 | val loss 2.2414 val acc 17.3093 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1195 | val loss 2.2622 val acc 14.7930 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1196 | val loss 2.2855 val acc 12.2159 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1197 | val loss 2.2445 val acc 14.3263 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 6 e 1198 | val loss 2.2433 val acc 16.3555 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 7 e 1199 | val loss 2.2101 val acc 17.0657 best val_acc 29.058442
# mkrum: at min-max n_at 10 n_mal_sel 5 e 1200 | val loss 2.1920 val acc 18.9529 best val_acc 29.058442

# %%
'''
MIN-SUM attack
'''

def our_attack_score(all_updates, model_re, n_attackers, dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)  # unit vector, dir opp to good dir
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)
    
    lamda = torch.Tensor([10.0]).float().cuda()
    # print(lamda)
    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0
    
    distances = []
    for update in all_updates:
        distance = torch.norm((all_updates - update), dim=1) ** 2
        distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)
    
    scores = torch.sum(distances, dim=1)
    min_score = torch.min(scores)
    del distances

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        distance = torch.norm((all_updates - mal_update), dim=1) ** 2
        score = torch.sum(distance)
        
        if score <= min_score:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    # print(lamda_succ)
    mal_update = (model_re - lamda_succ * deviation)
    
    return mal_update

# %%
batch_size=250
resume=0
nepochs=1200
schedule=[1000]
nbatches = user_tr_len//batch_size

gamma=.5
opt = 'sgd'
fed_lr=0.5
criterion=nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()

aggregation='mkrum'
multi_k = False
candidates = []

at_type='min-sum'
dev_type ='std'
z=0
n_attackers=[10]

arch='alexnet'
chkpt='./'+aggregation

for n_attacker in n_attackers:
    candidates = []

    epoch_num = 0
    best_global_acc = 0
    best_global_te_acc = 0

    fed_model, _ = return_model(arch, 0.1, 0.9, parallel=False)
    optimizer_fed = SGD(fed_model.parameters(), lr=fed_lr)

    torch.cuda.empty_cache()
    r=np.arange(user_tr_len)

    while epoch_num <= nepochs:
        user_grads=[]
        if not epoch_num and epoch_num%nbatches == 0:
            np.random.shuffle(r)
            for i in range(nusers):
                user_tr_data_tensors[i]=user_tr_data_tensors[i][r]
                user_tr_label_tensors[i]=user_tr_label_tensors[i][r]

        for i in range(n_attacker, nusers):

            inputs = user_tr_data_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]
            targets = user_tr_label_tensors[i][(epoch_num%nbatches)*batch_size:((epoch_num%nbatches) + 1) * batch_size]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            fed_model.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None, :] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]), 0)

        malicious_grads = user_grads

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        if n_attacker > 0:
            if at_type == 'lie':
                malicious_grads = get_malicious_updates_lie(malicious_grads, n_attacker, z, epoch_num)
            elif at_type == 'fang':
                agg_grads = torch.mean(malicious_grads, 0)
                deviation = torch.sign(agg_grads)
                malicious_grads = get_malicious_updates_fang(malicious_grads, agg_grads, deviation, n_attacker)
            elif at_type == 'our-agr':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_median(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-max':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_dist(malicious_grads, agg_grads, n_attacker, dev_type)
            elif at_type == 'min-sum':
                agg_grads = torch.mean(malicious_grads, 0)
                mal_update = our_attack_score(malicious_grads, agg_grads, n_attacker, dev_type)

            mal_updates = torch.stack([mal_update] * n_attacker)
            malicious_grads = torch.cat((mal_updates, user_grads), 0)

        if epoch_num==0: print('malicious_grads shape ', malicious_grads.shape)

        if aggregation=='median':
            agg_grads=torch.median(malicious_grads,dim=0)[0]

        elif aggregation=='average':
            agg_grads=torch.mean(malicious_grads,dim=0)

        elif aggregation=='krum' or aggregation=='mkrum':
            multi_k = True if aggregation == 'mkrum' else False
            if epoch_num == 0: print('multi krum is ', multi_k)
            agg_grads, krum_candidate = multi_krum(malicious_grads, n_attacker, multi_k=multi_k)

        elif aggregation=='bulyan':
            agg_grads, krum_candidate=bulyan(malicious_grads, n_attacker)

        del user_grads

        start_idx=0

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num%1==0 or epoch_num==nepochs-1:
            print('%s: at %s n_at %d n_mal_sel %d e %d | val loss %.4f val acc %.4f best val_acc %f'%(aggregation, at_type, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc))

        if val_loss > 1000:
            print('val loss %f too high'%val_loss)
            break
            
        epoch_num+=1
# Out:
# malicious_grads shape  torch.Size([50, 2472266])
# multi krum is  True
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 0 | val loss 2.3025 val acc 10.1461 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 1 | val loss 2.3021 val acc 10.0852 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 2 | val loss 2.3016 val acc 10.0446 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 3 | val loss 2.3011 val acc 10.0446 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 4 | val loss 2.3005 val acc 10.1055 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 5 | val loss 2.2998 val acc 10.1258 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 6 | val loss 2.2991 val acc 10.0446 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 7 | val loss 2.2982 val acc 10.0446 best val_acc 10.146104
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 8 | val loss 2.2971 val acc 10.6737 best val_acc 10.673701
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 9 | val loss 2.2957 val acc 11.2013 best val_acc 11.201299
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 10 | val loss 2.2940 val acc 12.1144 best val_acc 12.114448
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 11 | val loss 2.2916 val acc 12.4594 best val_acc 12.459416
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 12 | val loss 2.2886 val acc 14.7727 best val_acc 14.772727
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 13 | val loss 2.2843 val acc 15.0974 best val_acc 15.097403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 14 | val loss 2.2785 val acc 16.5179 best val_acc 16.517857
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 15 | val loss 2.2702 val acc 17.1266 best val_acc 17.126623
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 16 | val loss 2.2589 val acc 18.5268 best val_acc 18.526786
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 17 | val loss 2.2464 val acc 18.3644 best val_acc 18.526786
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 18 | val loss 2.2291 val acc 18.1209 best val_acc 18.526786
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 19 | val loss 2.2122 val acc 21.9765 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 20 | val loss 2.1895 val acc 21.1242 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 21 | val loss 2.2883 val acc 19.5617 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 22 | val loss 2.5184 val acc 9.9432 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 23 | val loss 2.3042 val acc 9.3750 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 24 | val loss 2.3037 val acc 9.7200 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 25 | val loss 2.3032 val acc 9.9026 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 26 | val loss 2.3028 val acc 9.5170 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 27 | val loss 2.3024 val acc 9.1721 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 28 | val loss 2.3019 val acc 9.4156 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 29 | val loss 2.3014 val acc 10.4708 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 30 | val loss 2.3010 val acc 10.4505 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 31 | val loss 2.3005 val acc 11.2013 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 32 | val loss 2.2999 val acc 11.2216 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 33 | val loss 2.2992 val acc 10.7143 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 34 | val loss 2.2986 val acc 10.8360 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 35 | val loss 2.2978 val acc 10.7752 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 36 | val loss 2.2968 val acc 10.3490 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 37 | val loss 2.2956 val acc 10.0244 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 38 | val loss 2.2944 val acc 10.2881 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 39 | val loss 2.2927 val acc 10.8766 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 40 | val loss 2.2904 val acc 10.2881 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 41 | val loss 2.2877 val acc 10.2476 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 42 | val loss 2.2845 val acc 10.7752 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 43 | val loss 2.2801 val acc 13.0479 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 44 | val loss 2.2741 val acc 13.0479 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 45 | val loss 2.2669 val acc 14.3060 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 46 | val loss 2.2590 val acc 15.3815 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 47 | val loss 2.2495 val acc 15.0162 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 48 | val loss 2.2386 val acc 14.9148 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 49 | val loss 2.2280 val acc 16.2744 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 50 | val loss 2.2172 val acc 17.5933 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 51 | val loss 2.2050 val acc 17.3701 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 52 | val loss 2.1925 val acc 18.3442 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 53 | val loss 2.1797 val acc 18.7500 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 54 | val loss 2.1600 val acc 19.7240 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 55 | val loss 2.1465 val acc 20.2516 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 56 | val loss 2.2124 val acc 18.8312 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 57 | val loss 2.5345 val acc 9.9026 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 58 | val loss 2.3124 val acc 10.8563 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 59 | val loss 2.3102 val acc 11.2419 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 60 | val loss 2.3081 val acc 11.2216 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 61 | val loss 2.3063 val acc 11.6680 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 62 | val loss 2.3049 val acc 11.8304 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 63 | val loss 2.3033 val acc 13.2305 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 64 | val loss 2.3013 val acc 13.4334 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 65 | val loss 2.2994 val acc 14.9148 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 66 | val loss 2.2972 val acc 15.5235 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 67 | val loss 2.2945 val acc 16.9034 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 68 | val loss 2.2907 val acc 17.1672 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 69 | val loss 2.2862 val acc 17.7963 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 70 | val loss 2.2802 val acc 18.8312 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 71 | val loss 2.2721 val acc 19.0950 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 72 | val loss 2.2609 val acc 20.6169 best val_acc 21.976461
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 73 | val loss 2.2476 val acc 22.7679 best val_acc 22.767857
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 74 | val loss 2.2311 val acc 23.5390 best val_acc 23.538961
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 75 | val loss 2.2128 val acc 23.3360 best val_acc 23.538961
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 76 | val loss 2.1900 val acc 22.9505 best val_acc 23.538961
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 77 | val loss 2.1749 val acc 22.5446 best val_acc 23.538961
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 78 | val loss 2.1433 val acc 23.8231 best val_acc 23.823052
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 79 | val loss 2.1392 val acc 24.2289 best val_acc 24.228896
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 80 | val loss 2.1162 val acc 22.5041 best val_acc 24.228896
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 81 | val loss 2.2916 val acc 13.2711 best val_acc 24.228896
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 82 | val loss 2.1371 val acc 22.5852 best val_acc 24.228896
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 83 | val loss 2.0877 val acc 21.4894 best val_acc 24.228896
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 84 | val loss 2.0406 val acc 25.9943 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 85 | val loss 2.0998 val acc 20.2516 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 86 | val loss 2.6131 val acc 13.9610 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 87 | val loss 2.7887 val acc 9.7200 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 88 | val loss 2.2987 val acc 11.7898 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 89 | val loss 2.2904 val acc 14.6510 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 90 | val loss 2.2840 val acc 14.8539 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 91 | val loss 2.2768 val acc 15.0162 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 92 | val loss 2.2711 val acc 15.1989 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 93 | val loss 2.2620 val acc 17.6136 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 94 | val loss 2.2586 val acc 15.7670 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 95 | val loss 2.2578 val acc 16.7817 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 96 | val loss 2.2610 val acc 17.5731 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 97 | val loss 2.2795 val acc 12.5406 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 98 | val loss 2.2245 val acc 18.1818 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 99 | val loss 2.2117 val acc 18.7297 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 100 | val loss 2.1942 val acc 20.1502 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 101 | val loss 2.1839 val acc 20.1502 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 102 | val loss 2.2087 val acc 15.5235 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 103 | val loss 2.4100 val acc 15.8685 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 104 | val loss 2.3168 val acc 9.9026 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 105 | val loss 2.3103 val acc 9.9026 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 106 | val loss 2.3029 val acc 9.9026 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 107 | val loss 2.2938 val acc 10.0041 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 108 | val loss 2.2848 val acc 10.9172 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 109 | val loss 2.2745 val acc 9.9026 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 110 | val loss 2.2633 val acc 10.1055 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 111 | val loss 2.2530 val acc 10.1055 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 112 | val loss 2.2409 val acc 10.5722 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 113 | val loss 2.2415 val acc 10.0852 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 114 | val loss 2.2519 val acc 12.1550 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 115 | val loss 2.2203 val acc 10.0244 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 116 | val loss 2.2228 val acc 12.8856 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 117 | val loss 2.2252 val acc 10.3896 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 118 | val loss 2.2626 val acc 15.9091 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 119 | val loss 2.1883 val acc 15.5032 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 120 | val loss 2.1750 val acc 15.7670 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 121 | val loss 2.1616 val acc 19.7849 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 122 | val loss 2.1811 val acc 16.2541 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 123 | val loss 2.2734 val acc 13.7581 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 124 | val loss 2.1773 val acc 18.8515 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 125 | val loss 2.1574 val acc 18.1615 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 126 | val loss 2.2198 val acc 16.6396 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 127 | val loss 2.1065 val acc 18.8515 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 128 | val loss 2.0969 val acc 17.1469 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 129 | val loss 2.2595 val acc 19.1153 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 130 | val loss 2.3022 val acc 9.3547 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 131 | val loss 2.2852 val acc 9.1924 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 132 | val loss 2.2714 val acc 8.7865 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 133 | val loss 2.2568 val acc 9.3750 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 134 | val loss 2.2411 val acc 10.4505 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 135 | val loss 2.2203 val acc 14.2451 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 136 | val loss 2.1924 val acc 14.6713 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 137 | val loss 2.1508 val acc 16.2135 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 138 | val loss 2.1089 val acc 19.8052 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 139 | val loss 2.0720 val acc 19.7849 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 140 | val loss 2.0472 val acc 21.3068 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 141 | val loss 2.0605 val acc 22.9505 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 142 | val loss 2.0334 val acc 24.4115 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 143 | val loss 2.1642 val acc 20.3937 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 144 | val loss 2.6062 val acc 14.1843 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 145 | val loss 2.2849 val acc 10.4911 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 146 | val loss 2.2677 val acc 11.4651 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 147 | val loss 2.2472 val acc 11.4448 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 148 | val loss 2.2236 val acc 11.5463 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 149 | val loss 2.2072 val acc 11.4448 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 150 | val loss 2.1937 val acc 18.9326 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 151 | val loss 2.1803 val acc 19.9067 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 152 | val loss 2.1688 val acc 21.2662 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 153 | val loss 2.1547 val acc 23.0925 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 154 | val loss 2.1384 val acc 22.6664 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 155 | val loss 2.1249 val acc 24.1274 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 156 | val loss 2.2034 val acc 19.1964 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 157 | val loss 2.3601 val acc 18.1006 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 158 | val loss 2.3152 val acc 9.9229 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 159 | val loss 2.3112 val acc 9.9229 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 160 | val loss 2.3068 val acc 9.9838 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 161 | val loss 2.3021 val acc 10.0852 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 162 | val loss 2.2970 val acc 10.2070 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 163 | val loss 2.2902 val acc 10.2881 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 164 | val loss 2.2814 val acc 10.5722 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 165 | val loss 2.2694 val acc 9.9026 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 166 | val loss 2.2535 val acc 11.4651 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 167 | val loss 2.2310 val acc 14.6307 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 168 | val loss 2.2003 val acc 16.5787 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 169 | val loss 2.1689 val acc 18.3239 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 170 | val loss 2.1684 val acc 17.4919 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 171 | val loss 2.3856 val acc 15.7670 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 172 | val loss 2.2168 val acc 16.5381 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 173 | val loss 2.1882 val acc 16.4367 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 174 | val loss 2.1689 val acc 18.3036 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 175 | val loss 2.1553 val acc 17.9992 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 176 | val loss 2.1449 val acc 18.2630 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 177 | val loss 2.1368 val acc 17.9992 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 178 | val loss 2.1201 val acc 18.2630 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 179 | val loss 2.1151 val acc 17.6542 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 180 | val loss 2.0958 val acc 18.4253 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 181 | val loss 2.1573 val acc 14.2248 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 182 | val loss 2.1116 val acc 17.0252 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 183 | val loss 2.1909 val acc 13.9407 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 184 | val loss 2.0988 val acc 17.7151 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 185 | val loss 2.0716 val acc 18.7094 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 186 | val loss 2.0459 val acc 18.5674 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 187 | val loss 2.0425 val acc 18.1818 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 188 | val loss 2.0662 val acc 18.9732 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 189 | val loss 2.2957 val acc 12.9667 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 190 | val loss 2.3214 val acc 11.7898 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 191 | val loss 2.2180 val acc 16.1120 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 192 | val loss 2.1900 val acc 16.8019 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 193 | val loss 2.1694 val acc 17.2890 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 194 | val loss 2.1504 val acc 18.0804 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 195 | val loss 2.1290 val acc 19.4805 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 196 | val loss 2.1046 val acc 19.9878 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 197 | val loss 2.0770 val acc 19.1153 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 198 | val loss 2.0518 val acc 18.0804 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 199 | val loss 2.0380 val acc 18.9123 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 200 | val loss 2.0432 val acc 19.5414 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 201 | val loss 2.0811 val acc 15.8076 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 202 | val loss 2.0443 val acc 22.0982 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 203 | val loss 2.0915 val acc 18.4253 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 204 | val loss 2.2335 val acc 14.6510 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 205 | val loss 2.1874 val acc 16.0511 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 206 | val loss 2.1021 val acc 18.5877 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 207 | val loss 2.0589 val acc 20.2516 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 208 | val loss 2.0302 val acc 21.0024 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 209 | val loss 2.0107 val acc 21.4692 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 210 | val loss 1.9978 val acc 21.9562 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 211 | val loss 2.0058 val acc 23.4172 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 212 | val loss 2.0530 val acc 22.0170 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 213 | val loss 2.2079 val acc 14.5901 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 214 | val loss 2.2117 val acc 12.8450 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 215 | val loss 2.1135 val acc 21.7735 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 216 | val loss 2.0360 val acc 22.1591 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 217 | val loss 2.0026 val acc 22.8693 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 218 | val loss 1.9959 val acc 22.6867 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 219 | val loss 2.0745 val acc 20.5763 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 220 | val loss 2.2679 val acc 16.4773 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 221 | val loss 2.2065 val acc 17.6339 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 222 | val loss 2.1075 val acc 20.7792 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 223 | val loss 2.0498 val acc 22.4229 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 224 | val loss 2.0089 val acc 24.4115 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 225 | val loss 1.9853 val acc 24.2695 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 226 | val loss 2.0059 val acc 22.5446 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 227 | val loss 2.0871 val acc 21.5097 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 228 | val loss 2.3188 val acc 15.0365 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 229 | val loss 2.2172 val acc 14.1031 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 230 | val loss 2.1221 val acc 19.7037 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 231 | val loss 2.0482 val acc 22.7476 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 232 | val loss 1.9798 val acc 25.4058 best val_acc 25.994318
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 233 | val loss 1.9723 val acc 26.6843 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 234 | val loss 2.0994 val acc 23.0925 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 235 | val loss 2.1371 val acc 21.1039 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 236 | val loss 2.0882 val acc 18.4050 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 237 | val loss 2.1082 val acc 20.0081 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 238 | val loss 2.1081 val acc 21.7532 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 239 | val loss 1.9899 val acc 23.5998 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 240 | val loss 1.9403 val acc 23.3969 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 241 | val loss 1.9168 val acc 25.6291 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 242 | val loss 1.9187 val acc 26.3393 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 243 | val loss 1.9798 val acc 22.8896 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 244 | val loss 2.0215 val acc 24.9594 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 245 | val loss 2.0821 val acc 21.2865 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 246 | val loss 2.1967 val acc 20.3328 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 247 | val loss 2.0693 val acc 23.2143 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 248 | val loss 1.9994 val acc 22.9099 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 249 | val loss 1.9237 val acc 25.1218 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 250 | val loss 1.9400 val acc 25.8117 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 251 | val loss 2.1131 val acc 23.1128 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 252 | val loss 2.0855 val acc 19.1153 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 253 | val loss 2.0342 val acc 23.3766 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 254 | val loss 2.0728 val acc 19.9878 best val_acc 26.684253
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 255 | val loss 1.9465 val acc 27.0089 best val_acc 27.008929
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 256 | val loss 1.8928 val acc 26.6437 best val_acc 27.008929
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 257 | val loss 1.9444 val acc 25.8929 best val_acc 27.008929
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 258 | val loss 1.8687 val acc 30.0528 best val_acc 30.052760
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 259 | val loss 1.8311 val acc 29.3019 best val_acc 30.052760
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 260 | val loss 1.8456 val acc 30.7224 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 261 | val loss 1.9467 val acc 26.2175 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 262 | val loss 2.1762 val acc 24.3912 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 263 | val loss 2.1764 val acc 15.8076 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 264 | val loss 2.2213 val acc 15.2394 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 265 | val loss 2.1768 val acc 22.7070 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 266 | val loss 2.0146 val acc 25.8320 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 267 | val loss 1.9115 val acc 27.3539 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 268 | val loss 1.9331 val acc 27.1104 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 269 | val loss 2.1043 val acc 18.9326 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 270 | val loss 2.2283 val acc 18.9529 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 271 | val loss 2.2642 val acc 20.7792 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 272 | val loss 2.0964 val acc 18.5674 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 273 | val loss 2.0593 val acc 22.2606 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 274 | val loss 2.0450 val acc 22.2403 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 275 | val loss 2.0357 val acc 23.7825 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 276 | val loss 2.2064 val acc 17.7557 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 277 | val loss 2.0979 val acc 20.8198 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 278 | val loss 2.0216 val acc 27.0089 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 279 | val loss 1.9892 val acc 24.2695 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 280 | val loss 2.0043 val acc 25.4667 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 281 | val loss 2.2420 val acc 20.6778 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 282 | val loss 2.2857 val acc 14.2248 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 283 | val loss 2.2305 val acc 20.2110 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 284 | val loss 2.1089 val acc 23.7216 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 285 | val loss 2.0312 val acc 21.5300 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 286 | val loss 1.9994 val acc 26.1972 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 287 | val loss 2.0438 val acc 24.6550 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 288 | val loss 2.3861 val acc 16.6396 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 289 | val loss 2.2250 val acc 20.7995 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 290 | val loss 2.1299 val acc 24.7159 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 291 | val loss 2.0366 val acc 27.6583 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 292 | val loss 1.9581 val acc 27.6380 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 293 | val loss 1.9150 val acc 28.4700 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 294 | val loss 1.9646 val acc 24.6144 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 295 | val loss 2.1899 val acc 20.7995 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 296 | val loss 2.5059 val acc 12.4797 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 297 | val loss 2.3019 val acc 10.3896 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 298 | val loss 2.2540 val acc 13.2711 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 299 | val loss 2.1808 val acc 16.2135 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 300 | val loss 2.1153 val acc 17.8369 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 301 | val loss 2.0643 val acc 20.3125 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 302 | val loss 2.0279 val acc 19.1356 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 303 | val loss 2.0231 val acc 23.3969 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 304 | val loss 2.0070 val acc 19.7240 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 305 | val loss 2.0504 val acc 17.4513 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 306 | val loss 1.9525 val acc 23.5998 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 307 | val loss 2.6565 val acc 13.3523 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 308 | val loss 2.3447 val acc 12.9058 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 309 | val loss 2.2229 val acc 14.0625 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 310 | val loss 2.1295 val acc 18.9326 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 311 | val loss 2.0719 val acc 22.5446 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 312 | val loss 2.0330 val acc 25.1623 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 313 | val loss 1.9997 val acc 24.1680 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 314 | val loss 1.9663 val acc 28.3279 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 315 | val loss 1.9347 val acc 28.1656 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 316 | val loss 1.9120 val acc 29.6266 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 317 | val loss 1.8998 val acc 29.7890 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 318 | val loss 1.9576 val acc 25.8929 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 319 | val loss 1.9205 val acc 24.0463 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 320 | val loss 1.9953 val acc 25.1015 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 321 | val loss 1.8800 val acc 30.4586 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 322 | val loss 1.8664 val acc 29.7890 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 323 | val loss 2.0276 val acc 27.0495 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 324 | val loss 2.3513 val acc 20.5154 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 325 | val loss 2.2781 val acc 15.1989 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 326 | val loss 2.1132 val acc 22.6664 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 327 | val loss 2.1557 val acc 20.9821 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 328 | val loss 2.1963 val acc 17.2484 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 329 | val loss 2.0986 val acc 17.2890 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 330 | val loss 2.0307 val acc 17.8774 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 331 | val loss 2.0320 val acc 17.1672 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 332 | val loss 2.8194 val acc 10.7143 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 333 | val loss 2.5379 val acc 9.9635 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 334 | val loss 2.3047 val acc 10.0446 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 335 | val loss 2.2964 val acc 10.0244 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 336 | val loss 2.2752 val acc 10.3287 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 337 | val loss 2.2224 val acc 14.9756 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 338 | val loss 2.1839 val acc 17.1875 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 339 | val loss 2.1563 val acc 21.8141 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 340 | val loss 2.2277 val acc 15.8685 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 341 | val loss 2.2645 val acc 11.4042 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 342 | val loss 2.2222 val acc 13.8190 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 343 | val loss 2.1600 val acc 17.5122 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 344 | val loss 2.0745 val acc 20.1096 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 345 | val loss 2.0151 val acc 21.7127 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 346 | val loss 1.9804 val acc 22.5852 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 347 | val loss 1.9828 val acc 22.8896 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 348 | val loss 2.0805 val acc 21.3474 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 349 | val loss 2.5795 val acc 12.6420 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 350 | val loss 2.2634 val acc 14.0625 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 351 | val loss 2.2197 val acc 15.9497 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 352 | val loss 2.1675 val acc 18.8515 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 353 | val loss 2.1258 val acc 20.8401 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 354 | val loss 2.0908 val acc 22.7273 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 355 | val loss 2.0642 val acc 23.1331 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 356 | val loss 2.0457 val acc 22.3011 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 357 | val loss 2.0498 val acc 22.8084 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 358 | val loss 2.1056 val acc 20.2922 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 359 | val loss 2.1877 val acc 16.4367 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 360 | val loss 2.0613 val acc 23.8231 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 361 | val loss 1.9956 val acc 24.7362 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 362 | val loss 1.9508 val acc 26.0146 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 363 | val loss 1.9573 val acc 23.8636 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 364 | val loss 2.0948 val acc 25.2638 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 365 | val loss 2.2968 val acc 14.1640 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 366 | val loss 2.0992 val acc 18.6891 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 367 | val loss 2.0140 val acc 21.5503 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 368 | val loss 1.9504 val acc 25.6899 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 369 | val loss 1.8947 val acc 28.3076 best val_acc 30.722403
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 370 | val loss 1.8692 val acc 30.7630 best val_acc 30.762987
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 371 | val loss 1.9125 val acc 25.3450 best val_acc 30.762987
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 372 | val loss 1.9057 val acc 27.1713 best val_acc 30.762987
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 373 | val loss 1.9941 val acc 23.9245 best val_acc 30.762987
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 374 | val loss 2.1069 val acc 27.8815 best val_acc 30.762987
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 375 | val loss 1.9605 val acc 26.1364 best val_acc 30.762987
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 376 | val loss 1.8798 val acc 26.1769 best val_acc 30.762987
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 377 | val loss 1.8997 val acc 30.8239 best val_acc 30.823864
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 378 | val loss 2.0572 val acc 25.6899 best val_acc 30.823864
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 379 | val loss 1.9848 val acc 25.8726 best val_acc 30.823864
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 380 | val loss 1.9408 val acc 27.8612 best val_acc 30.823864
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 381 | val loss 1.8739 val acc 29.6672 best val_acc 30.823864
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 382 | val loss 1.9498 val acc 29.2411 best val_acc 30.823864
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 383 | val loss 1.9248 val acc 26.2784 best val_acc 30.823864
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 384 | val loss 1.8337 val acc 32.3661 best val_acc 32.366071
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 385 | val loss 1.7908 val acc 33.4416 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 386 | val loss 2.0855 val acc 25.7914 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 387 | val loss 2.2226 val acc 23.2346 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 388 | val loss 2.1177 val acc 19.1761 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 389 | val loss 2.1670 val acc 18.7094 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 390 | val loss 2.2913 val acc 14.3060 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 391 | val loss 2.1139 val acc 22.0779 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 392 | val loss 1.9992 val acc 26.5219 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 393 | val loss 1.9282 val acc 28.5714 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 394 | val loss 1.8724 val acc 30.6006 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 395 | val loss 1.8578 val acc 27.6989 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 396 | val loss 1.9999 val acc 24.4724 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 397 | val loss 2.4315 val acc 20.3328 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 398 | val loss 2.2519 val acc 15.2800 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 399 | val loss 2.1683 val acc 18.4253 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 400 | val loss 2.0747 val acc 24.4724 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 401 | val loss 1.9994 val acc 25.1420 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 402 | val loss 2.0364 val acc 23.2955 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 403 | val loss 2.2241 val acc 20.7995 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 404 | val loss 2.1552 val acc 24.1680 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 405 | val loss 2.0481 val acc 23.4172 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 406 | val loss 1.9719 val acc 26.2378 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 407 | val loss 1.9582 val acc 25.3044 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 408 | val loss 2.0875 val acc 19.4805 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 409 | val loss 1.9418 val acc 31.9602 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 410 | val loss 1.8864 val acc 26.6640 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 411 | val loss 1.8510 val acc 31.0471 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 412 | val loss 1.8908 val acc 27.6177 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 413 | val loss 2.0254 val acc 26.9075 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 414 | val loss 2.0500 val acc 24.4115 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 415 | val loss 1.9135 val acc 27.9627 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 416 | val loss 1.8410 val acc 33.2995 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 417 | val loss 1.8599 val acc 28.9976 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 418 | val loss 1.9972 val acc 23.8636 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 419 | val loss 1.9171 val acc 29.2005 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 420 | val loss 1.9764 val acc 29.6469 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 421 | val loss 2.7181 val acc 14.0422 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 422 | val loss 2.3298 val acc 18.8312 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 423 | val loss 2.2202 val acc 14.7119 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 424 | val loss 2.5786 val acc 14.3466 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 425 | val loss 2.9612 val acc 9.5779 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 426 | val loss 2.2962 val acc 10.2273 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 427 | val loss 2.2172 val acc 16.7208 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 428 | val loss 2.1661 val acc 18.8718 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 429 | val loss 2.1258 val acc 20.6981 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 430 | val loss 2.0948 val acc 23.3360 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 431 | val loss 2.0991 val acc 20.7995 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 432 | val loss 2.0252 val acc 24.8377 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 433 | val loss 1.9986 val acc 26.2581 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e 434 | val loss 1.9923 val acc 23.8231 best val_acc 33.441558
# mkrum: at min-sum n_at 10 n_mal_sel 10 e