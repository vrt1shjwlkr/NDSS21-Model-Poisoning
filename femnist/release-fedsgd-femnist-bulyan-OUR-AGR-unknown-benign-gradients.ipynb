# %% [markdown]
# # The notebook contains
# ### Code for _Bulyan_ aggregation algorithm, *when gradient updates of benign clients are unknown to adversary*
# ### Evaluation of our SOTA AGR-tailored attack on Bulyan

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from __future__ import print_function
import argparse, os, sys, csv, shutil, time, random, operator, pickle, ast, math, json
import numpy as np
import pandas as pd
from torch.optim import Optimizer
import torch.nn.functional as F
import torch
import pickle
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torch.multiprocessing as mp

sys.path.insert(0,'./../utils/')
from logger import *
from eval import *
from misc import *

from femnist_normal_train import *
from femnist_util import *
from adam import Adam
from sgd import SGD
import torchvision.transforms as transforms
import torchvision.datasets as datasets

# %% [markdown]
# ## Get the FEMNIST dataset; we use [LEAF framework](https://leaf.cmu.edu/)

# %%
user_tr_data = []
user_tr_labels = []

for i in range(34):
    f = '/mnt/nfs/work1/amir/vshejwalkar/leaf/data/femnist/data/train/all_data_%d_niid_0_keep_0_train_9.json'%i
    with open(f, 'r') as myfile:
        data=myfile.read()
    obj = json.loads(data)
    
    for user in obj['users']:
        user_tr_data.append(obj['user_data'][user]['x'])
        user_tr_labels.append(obj['user_data'][user]['y'])

user_te_data = []
user_te_labels = []

for i in range(34):
    f = '/mnt/nfs/work1/amir/vshejwalkar/leaf/data/femnist/data/test/all_data_%d_niid_0_keep_0_test_9.json'%i
    with open(f, 'r') as myfile:
        data=myfile.read()
    obj = json.loads(data)
    
    for user in obj['users']:
        user_te_data.append(obj['user_data'][user]['x'])
        user_te_labels.append(obj['user_data'][user]['y'])

# %%
user_tr_data_tensors=[]
user_tr_label_tensors=[]

for i in range(len(user_tr_data)):
    
    user_tr_data_tensor=torch.from_numpy(np.array(user_tr_data[i])).type(torch.FloatTensor)
    user_tr_label_tensor=torch.from_numpy(np.array(user_tr_labels[i])).type(torch.LongTensor)

    user_tr_data_tensors.append(user_tr_data_tensor)
    user_tr_label_tensors.append(user_tr_label_tensor)
    
    # print('user %d tr len %d'%(i,len(user_tr_data_tensor)))
print("number of clients: ", len(user_tr_data_tensors))
# Out:
# number of clients:  3400

# %%
te_data = np.concatenate(user_te_data, 0)
te_labels = np.concatenate(user_te_labels)
te_len = len(te_labels)

te_data_tensor = torch.from_numpy(te_data[:(te_len//2)]).type(torch.FloatTensor)
te_label_tensor = torch.from_numpy(te_labels[:(te_len//2)]).type(torch.LongTensor)

val_data_tensor = torch.from_numpy(te_data[(te_len//2):]).type(torch.FloatTensor)
val_label_tensor = torch.from_numpy(te_labels[(te_len//2):]).type(torch.LongTensor)

# %% [markdown]
# ## Code for Multi-krum aggregation algorithm

# %%
def multi_krum(all_updates, n_attackers, multi_k=False):
    nusers = all_updates.shape[0]
    candidates = []
    candidate_indices = []
    remaining_updates = all_updates
    all_indices = np.arange(len(all_updates))

    while len(remaining_updates) > 2 * n_attackers + 2:
        distances = []
        for update in remaining_updates:
            distance = torch.norm((remaining_updates - update), dim=1) ** 2
            distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)

        distances = torch.sort(distances, dim=1)[0]
        scores = torch.sum(distances[:, :len(remaining_updates) - 2 - n_attackers], dim=1)
        indices = torch.argsort(scores)[:len(remaining_updates) - 2 - n_attackers]

        candidate_indices.append(all_indices[indices[0].cpu().numpy()])
        all_indices = np.delete(all_indices, indices[0].cpu().numpy())
        candidates = remaining_updates[indices[0]][None, :] if not len(candidates) else torch.cat((candidates, remaining_updates[indices[0]][None, :]), 0)
        remaining_updates = torch.cat((remaining_updates[:indices[0]], remaining_updates[indices[0] + 1:]), 0)
        if not multi_k:
            break
    # print(len(remaining_updates))
    aggregate = torch.mean(candidates, dim=0)
    return aggregate, np.array(candidate_indices)

# %% [markdown]
# ## Code for Bulyan aggregation algorithm

# %%
def bulyan(all_updates, n_attackers):
    nusers = all_updates.shape[0]
    bulyan_cluster = []
    candidate_indices = []
    remaining_updates = all_updates
    all_indices = np.arange(len(all_updates))

    while len(bulyan_cluster) < (nusers - 2 * n_attackers):
        distances = []
        for update in remaining_updates:
            distance = torch.norm((remaining_updates - update), dim=1) ** 2
            distances = distance[None, :] if not len(distances) else torch.cat((distances, distance[None, :]), 0)

        distances = torch.sort(distances, dim=1)[0]

        scores = torch.sum(distances[:, :len(remaining_updates) - 2 - n_attackers], dim=1)
        indices = torch.argsort(scores)[:len(remaining_updates) - 2 - n_attackers]

        candidate_indices.append(all_indices[indices[0].cpu().numpy()])
        all_indices = np.delete(all_indices, indices[0].cpu().numpy())
        bulyan_cluster = remaining_updates[indices[0]][None, :] if not len(bulyan_cluster) else torch.cat((bulyan_cluster, remaining_updates[indices[0]][None, :]), 0)
        remaining_updates = torch.cat((remaining_updates[:indices[0]], remaining_updates[indices[0] + 1:]), 0)

    # print('dim of bulyan cluster ', bulyan_cluster.shape)

    n, d = bulyan_cluster.shape
    param_med = torch.median(bulyan_cluster, dim=0)[0]
    sort_idx = torch.argsort(torch.abs(bulyan_cluster - param_med), dim=0)
    sorted_params = bulyan_cluster[sort_idx, torch.arange(d)[None, :]]

    return torch.mean(sorted_params[:n - 2 * n_attackers], dim=0), np.array(candidate_indices)

# %% [markdown]
# ## Code for Fang attack on Bulyan
# ### Fang attacks on MKrum and Bulyan are the same

# %%
def our_attack_mkrum(all_updates, model_re, n_attackers,dev_type='unit_vec'):

    if dev_type == 'unit_vec':
        deviation = model_re / torch.norm(model_re)  # unit vector, dir opp to good dir
    elif dev_type == 'sign':
        deviation = torch.sign(model_re)
    elif dev_type == 'std':
        deviation = torch.std(all_updates, 0)
        
    lamda = torch.Tensor([20.0]).cuda() #compute_lambda_our(all_updates, model_re, n_attackers)
    # print(lamda)
    threshold_diff = 1e-5
    lamda_fail = lamda
    lamda_succ = 0

    while torch.abs(lamda_succ - lamda) > threshold_diff:
        mal_update = (model_re - lamda * deviation)
        mal_updates = torch.stack([mal_update] * n_attackers)
        mal_updates = torch.cat((mal_updates, all_updates), 0)

        agg_grads, krum_candidate = multi_krum(mal_updates, n_attackers, multi_k=True)

        if np.sum(krum_candidate < n_attackers) == n_attackers:
            # print('successful lamda is ', lamda)
            lamda_succ = lamda
            lamda = lamda + lamda_fail / 2
        else:
            lamda = lamda - lamda_fail / 2

        lamda_fail = lamda_fail / 2

    mal_update = (model_re - lamda_succ * deviation)

    return mal_update

# %%
resume=0
nepochs=1500
gamma=.1
fed_lr=0.001

criterion = nn.CrossEntropyLoss()
use_cuda = torch.cuda.is_available()
batch_size = 100
schedule = [2000]

aggregation = 'bulyan'
at_type = 'our-agr'
chkpt = './' + aggregation
epoch_num = 0

at_fractions = [20]

for at_fraction in at_fractions:

    fed_model = mnist_conv().cuda()
    fed_model.apply(weights_init)
    optimizer_fed = Adam(fed_model.parameters(), lr=fed_lr)

    print('==> Initializing global model')
    epoch_num = 0
    best_global_acc=0
    best_global_te_acc=0

    while epoch_num <= nepochs:
        user_grads = []
        
        round_users = np.random.choice(3400, 60)
        n_attacker = np.sum(round_users < (34*at_fraction))

        if n_attacker > 14:
            print ('n_attackers actual %d adjusted 14' % n_attacker)
            n_attacker = 14

        at_idx = []
        attacker_count = 0
        for i in round_users:
            if i < (34*at_fraction) and attacker_count < n_attacker:
                at_idx.append(i)
                attacker_count += 1
                continue

            inputs = user_tr_data_tensors[i]
            targets = user_tr_label_tensors[i]

            inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

            outputs = fed_model(inputs)
            loss = criterion(outputs, targets)
            optimizer_fed.zero_grad()
            loss.backward(retain_graph=True)

            param_grad=[]
            for param in fed_model.parameters():
                param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

            user_grads=param_grad[None,:] if len(user_grads)==0 else torch.cat((user_grads,param_grad[None,:]),0)    

        if n_attacker > 0:
            attacker_grads = []
            n_attacker_ = max(1, n_attacker**2//60)
            for i in at_idx:

                inputs = user_tr_data_tensors[i]
                targets = user_tr_label_tensors[i]

                inputs, targets = inputs.cuda(), targets.cuda()
                inputs, targets = torch.autograd.Variable(inputs), torch.autograd.Variable(targets)

                outputs = fed_model(inputs)
                loss = criterion(outputs, targets)
                optimizer_fed.zero_grad()
                loss.backward(retain_graph=True)

                param_grad=[]
                for param in fed_model.parameters():
                    param_grad=param.grad.data.view(-1) if not len(param_grad) else torch.cat((param_grad,param.grad.view(-1)))

                attacker_grads=param_grad[None,:] if len(attacker_grads)==0 else torch.cat((attacker_grads,param_grad[None,:]),0)

            mal_updates = []
            if at_type == 'fang':
                agg_grads = torch.mean(attacker_grads, 0)
                deviation = torch.sign(agg_grads)
                mal_update = get_malicious_updates_fang(attacker_grads, agg_grads, deviation, n_attacker_)

            elif at_type == 'our-agr':
                agg_grads = torch.mean(attacker_grads, 0)
                mal_update = our_attack_mkrum(attacker_grads, agg_grads, n_attacker_, dev_type='sign')
            
        if not len(mal_updates):
            mal_updates = torch.stack([mal_update] * n_attacker)
        malicious_grads = torch.cat((mal_updates, user_grads), 0)    
        
        if malicious_grads.shape[0] != 60: 
            print('malicious grads shape ', malicious_grads.shape)
            sys.exit()

        agg_grads, krum_candidate = bulyan(malicious_grads, n_attacker)
            
        start_idx=0

        if epoch_num in schedule:
            for param_group in optimizer_fed.param_groups:
                param_group['lr'] *= gamma
                print('New learnin rate ', param_group['lr'])

        optimizer_fed.zero_grad()

        model_grads=[]

        for i, param in enumerate(fed_model.parameters()):
            param_=agg_grads[start_idx:start_idx+len(param.data.view(-1))].reshape(param.data.shape)
            start_idx=start_idx+len(param.data.view(-1))
            param_=param_.cuda()
            model_grads.append(param_)

        optimizer_fed.step(model_grads)

        val_loss, val_acc = test(val_data_tensor,val_label_tensor,fed_model,criterion,use_cuda)
        te_loss, te_acc = test(te_data_tensor,te_label_tensor, fed_model, criterion, use_cuda)

        is_best = best_global_acc < val_acc

        best_global_acc = max(best_global_acc, val_acc)

        if is_best:
            best_global_te_acc = te_acc

        if epoch_num % 20 == 0:
            print('%s: at %s at_frac %.1f n_at %d n_mal_sel %d e %d fed_model val loss %.4f val acc %.4f best val_acc %f te_acc %f'%(aggregation, at_type, at_fraction, n_attacker, np.sum(krum_candidate < n_attacker), epoch_num, val_loss, val_acc, best_global_acc,best_global_te_acc))

        epoch_num+=1
# Out:
# ==> Initializing global model
# bulyan: at our-agr at_frac 20.0 n_at 8 n_mal_sel 7 e 0 fed_model val loss 3.9522 val acc 4.6824 best val_acc 4.682352 te_acc 5.341330
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 8 e 20 fed_model val loss 3.7876 val acc 5.4031 best val_acc 10.494749 te_acc 11.593904
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 12 e 40 fed_model val loss 3.6317 val acc 29.3992 best val_acc 30.637356 te_acc 34.825474
# n_attackers actual 17 adjusted 14
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 10 e 60 fed_model val loss 3.2731 val acc 32.5165 best val_acc 34.169069 te_acc 38.416392
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 11 e 80 fed_model val loss 2.9888 val acc 33.8602 best val_acc 35.569399 te_acc 39.675144
# n_attackers actual 20 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 13 n_mal_sel 11 e 100 fed_model val loss 2.6565 val acc 34.6710 best val_acc 36.928542 te_acc 40.836079
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 21 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 14 e 120 fed_model val loss 2.6216 val acc 36.3751 best val_acc 38.128089 te_acc 42.182352
# n_attackers actual 15 adjusted 14
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 11 e 140 fed_model val loss 2.4904 val acc 38.5554 best val_acc 39.567030 te_acc 43.451400
# n_attackers actual 21 adjusted 14
# n_attackers actual 20 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 21 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 7 n_mal_sel 5 e 160 fed_model val loss 2.5310 val acc 37.0933 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 9 n_mal_sel 6 e 180 fed_model val loss 2.6646 val acc 35.4484 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 22 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 12 e 200 fed_model val loss 2.7722 val acc 34.0610 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 20 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 220 fed_model val loss 3.0443 val acc 31.2423 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 10 n_mal_sel 7 e 240 fed_model val loss 2.8885 val acc 35.0108 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 11 e 260 fed_model val loss 2.8483 val acc 33.2578 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 17 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 8 n_mal_sel 6 e 280 fed_model val loss 3.2761 val acc 26.3952 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 21 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 13 n_mal_sel 11 e 300 fed_model val loss 3.1368 val acc 32.2694 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 19 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 13 e 320 fed_model val loss 3.6303 val acc 32.2024 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 9 e 340 fed_model val loss 3.1761 val acc 31.8781 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 360 fed_model val loss 3.4330 val acc 29.1006 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 10 e 380 fed_model val loss 3.5062 val acc 33.4123 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 10 e 400 fed_model val loss 3.8406 val acc 30.9591 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 19 adjusted 14
# n_attackers actual 22 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 8 n_mal_sel 7 e 420 fed_model val loss 3.6562 val acc 29.0388 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 9 n_mal_sel 8 e 440 fed_model val loss 3.2249 val acc 31.3349 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 9 e 460 fed_model val loss 3.6240 val acc 26.2047 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 13 e 480 fed_model val loss 3.6606 val acc 34.6685 best val_acc 39.914539 te_acc 43.307249
# bulyan: at our-agr at_frac 20.0 n_at 8 n_mal_sel 8 e 500 fed_model val loss 4.0202 val acc 29.9964 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 13 e 520 fed_model val loss 3.6102 val acc 23.0591 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 12 e 540 fed_model val loss 4.4235 val acc 14.5619 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 5 n_mal_sel 5 e 560 fed_model val loss 3.6563 val acc 31.6876 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 8 e 580 fed_model val loss 3.7404 val acc 33.8138 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 10 e 600 fed_model val loss 3.2827 val acc 32.6323 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 620 fed_model val loss 3.1394 val acc 32.8537 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 20 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 12 e 640 fed_model val loss 3.0924 val acc 28.2794 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 17 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 10 e 660 fed_model val loss 3.4246 val acc 35.5874 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 9 n_mal_sel 7 e 680 fed_model val loss 3.2003 val acc 33.7083 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 21 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 13 n_mal_sel 11 e 700 fed_model val loss 3.0560 val acc 29.2988 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 19 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 22 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 14 e 720 fed_model val loss 3.1732 val acc 30.8562 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 18 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 7 n_mal_sel 7 e 740 fed_model val loss 3.2857 val acc 33.5333 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 17 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 12 e 760 fed_model val loss 3.2224 val acc 28.4287 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 7 n_mal_sel 5 e 780 fed_model val loss 3.3493 val acc 33.0596 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 19 adjusted 14
# n_attackers actual 19 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 10 n_mal_sel 7 e 800 fed_model val loss 4.0086 val acc 25.9550 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 20 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 10 e 820 fed_model val loss 3.5951 val acc 28.9024 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 7 e 840 fed_model val loss 3.6401 val acc 30.3542 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 9 e 860 fed_model val loss 3.6341 val acc 32.5911 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 12 e 880 fed_model val loss 3.2101 val acc 30.6631 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 10 n_mal_sel 7 e 900 fed_model val loss 3.9270 val acc 31.7674 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 13 e 920 fed_model val loss 3.5507 val acc 32.9772 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 10 e 940 fed_model val loss 3.2388 val acc 32.4290 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 9 e 960 fed_model val loss 3.2022 val acc 29.2010 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 21 adjusted 14
# n_attackers actual 18 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 8 n_mal_sel 6 e 980 fed_model val loss 3.0993 val acc 32.6272 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 14 e 1000 fed_model val loss 2.9649 val acc 31.3246 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 18 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 8 n_mal_sel 8 e 1020 fed_model val loss 3.9078 val acc 28.9436 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 11 e 1040 fed_model val loss 3.0576 val acc 32.4444 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 14 e 1060 fed_model val loss 3.1489 val acc 34.6993 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 9 n_mal_sel 7 e 1080 fed_model val loss 3.2238 val acc 31.2809 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 19 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 11 e 1100 fed_model val loss 3.0040 val acc 30.1508 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 19 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 1120 fed_model val loss 3.4921 val acc 27.1546 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 12 e 1140 fed_model val loss 3.8965 val acc 32.0737 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 19 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 8 n_mal_sel 6 e 1160 fed_model val loss 4.6100 val acc 34.2180 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 17 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 11 e 1180 fed_model val loss 3.3753 val acc 33.4792 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 10 e 1200 fed_model val loss 3.5348 val acc 36.6840 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 20 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 9 e 1220 fed_model val loss 3.1469 val acc 28.7814 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 10 n_mal_sel 10 e 1240 fed_model val loss 3.0822 val acc 35.9504 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 16 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 1260 fed_model val loss 3.0520 val acc 34.9181 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 1280 fed_model val loss 3.0282 val acc 33.4921 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 12 e 1300 fed_model val loss 2.8966 val acc 34.6427 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 18 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 10 e 1320 fed_model val loss 3.2799 val acc 34.3338 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 9 n_mal_sel 7 e 1340 fed_model val loss 3.0017 val acc 36.2207 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 10 e 1360 fed_model val loss 2.8898 val acc 36.7123 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 17 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 11 e 1380 fed_model val loss 3.0048 val acc 32.8974 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 18 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 1400 fed_model val loss 2.9834 val acc 33.6568 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 11 n_mal_sel 11 e 1420 fed_model val loss 3.0083 val acc 36.9028 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 17 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 14 n_mal_sel 11 e 1440 fed_model val loss 3.1805 val acc 34.6813 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 19 adjusted 14
# n_attackers actual 20 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 12 n_mal_sel 11 e 1460 fed_model val loss 3.0958 val acc 32.0197 best val_acc 39.914539 te_acc 43.307249
# n_attackers actual 15 adjusted 14
# n_attackers actual 16 adjusted 14
# n_attackers actual 15 adjusted 14
# bulyan: at our-agr at_frac 20.0 n_at 10 n_mal_sel 7 e 1500 fed_model val loss 3.1493 val acc 33.5950 best val_acc 39.914539 te_acc 43.307249
